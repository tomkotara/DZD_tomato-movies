# %% [markdown]
# ## Data import

# %%
import pandas as pd
from tqdm.notebook import tqdm_notebook, tqdm
import numpy as np
from cleverminer import cleverminer

# %%
# movies
movies = pd.read_csv('../data/rotten_tomatoes_movies.csv', index_col = 'rotten_tomatoes_link')

# %%
# rotten_tomatoes_critic_reviews was too big it had to be split to be uploaded to GITHub
filenames = ['rotten_tomatoes_critic_reviews.csv', 'rotten_tomato_reviews_1.csv', 'rotten_tomato_reviews_2.csv', 'rotten_tomato_reviews_3.csv', 'rotten_tomato_reviews_4.csv', 'rotten_tomato_reviews_5.csv']
reviews_list = []

for filename in filenames:
    review = pd.read_csv(f'../data/{filename}', index_col='rotten_tomatoes_link')
    reviews_list.append(review)

# combining the critics review dataset back together
reviews = pd.concat(reviews_list)

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### movies

# %%
# deleting useless columna movies_info, critics_consensus containing long strings
movies.drop('movie_info', axis=1, inplace=True)
movies.drop('critics_consensus', axis=1, inplace=True)

# %% [markdown]
# ### reviews

# %%
# dropping rows with missing review_score values
reviews = reviews[reviews['review_score'].notna()]

# deleting useless column review_cotent containing long strings
reviews = reviews.drop('review_content', axis=1)

# %%
#unique values in review_score 
# unq = reviews['review_score'].unique()
# unq.sort()
# unq

#moje poznamky co napsat do zpravy
#FILTROVANI DAT NA ZAKLADE CRITICS_SCORE
# DLE RAUCHA JE TO OK..
# --- vime o tom a vysledek muze byt timto zpusobem zkreslen

# %%
# deleting reviews with non-numeric review scores (approx 80 000 values)
reviews = reviews[reviews['review_score'].str.contains('[A-Za-z]') == False]

# splitting review scores into columns
split = reviews['review_score'].str.split('/')

 #calculating percentage scores
scores =  pd.to_numeric(split.str.get(0)) / pd.to_numeric(split.str.get(1))
scores = scores*100

# assigning calculated values to the reviews scores column
reviews['review_score'] = scores

# %% [markdown]
# ## Final dataset

# %%
#Merging the two datasets - reviews and movies
data = pd.merge(movies, reviews, how='inner', on = 'rotten_tomatoes_link')

# %%
# data['actors'] = data['actors'].str.split(', ')

# remove rows with missing values
data = data[data['actors'].isnull() == False]
data = data[data['review_score'].isnull() == False]
data = data[np.isinf(data['review_score']) == False]
data = data[data['production_company'].isnull() == False]

# %%
## Rauch říkal, že by bylo moc práce to rozdělovat, pro naší SP stačí použít kategorie tak jak jsou...
## do zpravy je treba napsat, ze nam to takto rekl
## /--- se souhlasem cviciho
## muzeme pouzit kategorie tak jak jsou

#

# %%
data['genres'] = data['genres'].str.split(', ')
data = data[data['genres'].isnull() == False]

# %% [markdown]
# ### New columns

# %%
# new column with review score intervals
def review_score_interval(row):
    if row['review_score'] >= 90:
        return '>90'
    elif row['review_score'] >= 70:
        return '70-90'
    elif row['review_score'] >= 50:
        return '50-70'
    elif row['review_score'] >= 30:
        return '30-50'
    else:
        return '<30'

data["review_score_interval"] = data.apply(review_score_interval, axis=1)

# %%
# new column with review score intervals
def audience_rating_interval(row):
    if row['audience_rating'] >= 90:
        return '>90'
    elif row['audience_rating'] >= 70:
        return '70-90'
    elif row['audience_rating'] >= 50:
        return '50-70'
    elif row['audience_rating'] >= 30:
        return '30-50'
    else:
        return '<30'

data["audience_rating_interval"] = data.apply(audience_rating_interval, axis=1)

# %%
# new column with tomatometer rating interval
def tomatometer_rating_interval(row):
    if row['tomatometer_rating'] >= 90:
        return '>90'
    elif row['tomatometer_rating'] >= 70:
        return '70-90'
    elif row['tomatometer_rating'] >= 50:
        return '50-70'
    elif row['tomatometer_rating'] >= 30:
        return '30-50'
    else:
        return '<30'

data["tomatometer_rating_interval"] = data.apply(tomatometer_rating_interval, axis=1)

# %%
# new column with runtime intervals
def runtime_interval(row):
    if row['runtime'] >= 150:
        return '>2.5h'
    elif row['runtime'] >= 120:
        return '2-2.5'
    elif row['runtime'] >= 105:
        return '1.75-2h'
    elif row['runtime'] >= 90:
        return '1.5-1.75h'
    else:
        return '<1.5h'

data["runtime_interval"] = data.apply(runtime_interval, axis=1)

# %%
# new column with release interval
data = data[data['original_release_date'].notnull()]

def release_decade_interval(row):
    split = row["original_release_date"].split('-')
    year = split[0]
    interval =  str(pd.to_numeric(year)//10*10) + '\'s'
    return interval

data["release_decade_interval"] = data.apply(release_decade_interval, axis=1)

# %%
def is_horror(row):
    if 'Horror' in row['genres']:
        return True
    else: return False
data["Horror"] = data.apply(is_horror, axis=1)

# %% [markdown]
# ## top genres

# %%
genres_scores = dict()
for row in tqdm(range(data.shape[0])):
    value = data['review_score'][row]
    for genre in data['genres'][row]:
        if genre not in genres_scores.keys():
            genres_scores[genre] = [value]
        else:
            genres_scores[genre].append(value)
# Out:
#   0%|          | 0/670411 [00:00<?, ?it/s]

# %%
# calculating average scores for each actor
final_genres_scores = {}
for key in tqdm(genres_scores.keys()):
    # add only actors with 3000+ reviews 
    if len(genres_scores[key]) > 100:
        mean = np.mean(genres_scores[key])
        final_genres_scores[key] = round(mean, 1)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
final_genres_scores
genres_rating = sorted(final_genres_scores.items(), key=lambda x: x[1], reverse=True)
genres_rating
# Out:
# [('Classics', 75.7),
#  ('Documentary', 71.5),
#  ('Special Interest', 70.4),
#  ('Art House & International', 69.5),
#  ('Anime & Manga', 69.3),
#  ('Sports & Fitness', 67.4),
#  ('Animation', 66.8),
#  ('Television', 66.8),
#  ('Musical & Performing Arts', 66.3),
#  ('Western', 66.1),
#  ('Drama', 65.7),
#  ('Cult Movies', 65.2),
#  ('Gay & Lesbian', 63.9),
#  ('Science Fiction & Fantasy', 62.6),
#  ('Romance', 62.5),
#  ('Kids & Family', 62.0),
#  ('Faith & Spirituality', 61.7),
#  ('Mystery & Suspense', 61.4),
#  ('Action & Adventure', 60.7),
#  ('Comedy', 60.2),
#  ('Horror', 57.2)]

# %% [markdown]
# ## TOP10 actors
#
# ### Kterých top 10 herců/hereček má nejlepší skóre kritiky

# %%
# creating dict with following annotation actor: [scores]
data['actors'] = data['actors'].str.split(', ')

actor_scores = dict()
for row in tqdm(range(data.shape[0])):
    value = data['review_score'][row]
    for actor in data['actors'][row]:
        if actor not in actor_scores.keys():
            actor_scores[actor] = [value]
        else:
            actor_scores[actor].append(value)
# Out:
#   0%|          | 0/670411 [00:00<?, ?it/s]

# %%
# calculating average scores for each actor
final_scores = {}
for key in tqdm(actor_scores.keys()):
    
    # add only actors with 3000+ reviews 
    if len(actor_scores[key]) > 3000:
        mean = np.mean(actor_scores[key])
        final_scores[key] = round(mean, 1)
# Out:
#   0%|          | 0/197331 [00:00<?, ?it/s]

# %%
top10 = sorted(final_scores.items(), key=lambda x: x[1], reverse=True)
top10[0:10]
# Out:
# [('John Ratzenberger', 78.6),
#  ('Adam Driver', 75.3),
#  ('Michael Stuhlbarg', 75.2),
#  ('Andy Serkis', 75.0),
#  ('Leonardo DiCaprio', 74.1),
#  ('Anthony Daniels', 73.1),
#  ('Domhnall Gleeson', 72.5),
#  ('Warwick Davis', 72.5),
#  ('Tom Holland (II)', 72.3),
#  ('Tilda Swinton', 72.0)]

# %%
pd.set_option('display.max_columns', None)
data.head(1)
# Out:
#                                                             movie_title  \
# rotten_tomatoes_link
# m/0814255             Percy Jackson & the Olympians: The Lightning T...
#
#                      content_rating  \
# rotten_tomatoes_link
# m/0814255                        PG
#
#                                                                  genres  \
# rotten_tomatoes_link
# m/0814255             [Action & Adventure, Comedy, Drama, Science Fi...
#
#                            directors  \
# rotten_tomatoes_link
# m/0814255             Chris Columbus
#
#                                                          authors  \
# rotten_tomatoes_link
# m/0814255             Craig Titley, Chris Columbus, Rick Riordan
#
#                                                                  actors  \
# rotten_tomatoes_link
# m/0814255             [Logan Lerman, Brandon T. Jackson, Alexandra D...
#
#                      original_release_date streaming_release_date  runtime  \
# rotten_tomatoes_link
# m/0814255                       2010-02-12             2015-11-25    119.0
#
#                      production_company tomatometer_status  \
# rotten_tomatoes_link
# m/0814255              20th Century Fox             Rotten
#
#                       tomatometer_rating  tomatometer_count audience_status  \
# rotten_tomatoes_link
# m/0814255                           49.0              149.0         Spilled
#
#                       audience_rating  audience_count  \
# rotten_tomatoes_link
# m/0814255                        53.0        254421.0
#
#                       tomatometer_top_critics_count  \
# rotten_tomatoes_link
# m/0814255                                        43
#
#                       tomatometer_fresh_critics_count  \
# rotten_tomatoes_link
# m/0814255                                          73
#
#                       tomatometer_rotten_critics_count   critic_name  \
# rotten_tomatoes_link
# m/0814255                                           76  Ben McEachen
#
#                       top_critic           publisher_name review_type  \
# rotten_tomatoes_link
# m/0814255                  False  Sunday Mail (Australia)       Fresh
#
#                       review_score review_date review_score_interval  \
# rotten_tomatoes_link
# m/0814255                     70.0  2010-02-09                 70-90
#
#                      audience_rating_interval tomatometer_rating_interval  \
# rotten_tomatoes_link
# m/0814255                               50-70                       30-50
#
#                      runtime_interval release_decade_interval  Horror
# rotten_tomatoes_link
# m/0814255                     1.75-2h                  2010's   False

# %% [markdown]
# ### histogram pro hodnocení filmů dle režiséra a production company, release decade a content rating

# %%
df = data
df = df.loc[:, ('directors', 'release_decade_interval', 'review_score_interval', 'production_company', 'tomatometer_status', 'tomatometer_top_critics_count', 'content_rating')]



clm = cleverminer(df=df,target='review_score_interval',proc='CFMiner',
               quantifiers= {'S_Up':2, 'Base':750},
                cond={
                    'attributes':[
                        {'name': 'directors', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'release_decade_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'content_rating', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':3, 'maxlen':4, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  CFMiner
# Starting to mine rules.
# Done. Total verifications : 212, rules 131,control number:0, times: prep 15.669250011444092, processing 14.093694925308228
#
# CleverMiner task processing summary:
#
# Task type : CFMiner
# Number of verifications : 212
# Number of rules : 131
# Total time needed : 00h 00m 29s
# Time of data preparation : 00h 00m 15s
# Time of rule mining : 00h 00m 14s
#
#
# List of rules:
# RULEID BASE  S_UP  S_DOWN Condition
#      1   810     2     1 directors(Anthony Russo) & release_decade_interval(2010's) & content_rating(PG-13)
#      2   863     2     1 directors(Bryan Singer) & production_company(20th Century Fox) & content_rating(PG-13)
#      3   890     2     1 directors(Christopher Nolan) & production_company(Warner Bros. Pictures) & content_rating(PG-13)
#      4   929     2     1 directors(Christopher Nolan) & release_decade_interval(2010's) & content_rating(PG-13)
#      5   758     2     1 directors(Clint Eastwood) & release_decade_interval(2000's) & content_rating(R)
#      6   797     2     1 directors(Danny Boyle) & production_company(Fox Searchlight Pictures) & release_decade_interval(2000's)
#      7   762     2     1 directors(Danny Boyle) & release_decade_interval(2000's) & content_rating(R)
#      8   788     2     1 directors(Danny Boyle) & release_decade_interval(2010's) & content_rating(R)
#      9   985     2     2 directors(David Gordon Green) & release_decade_interval(2010's) & content_rating(R)
#     10   807     2     1 directors(David Yates (II)) & production_company(Warner Bros. Pictures) & release_decade_interval(2010's)
#     11   807     2     1 directors(David Yates (II)) & production_company(Warner Bros. Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#     12   967     2     1 directors(David Yates (II)) & production_company(Warner Bros. Pictures) & content_rating(PG-13)
#     13   969     2     1 directors(David Yates (II)) & release_decade_interval(2010's) & content_rating(PG-13)
#     14  1030     2     1 directors(Denis Villeneuve) & release_decade_interval(2010's) & content_rating(R)
#     15  1090     2     1 directors(J.J. Abrams) & production_company(Walt Disney Pictures) & release_decade_interval(2010's)
#     16  1090     2     1 directors(J.J. Abrams) & production_company(Walt Disney Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#     17  1090     2     1 directors(J.J. Abrams) & production_company(Walt Disney Pictures) & content_rating(PG-13)
#     18  1848     2     1 directors(J.J. Abrams) & release_decade_interval(2010's) & content_rating(PG-13)
#     19   990     2     1 directors(Jon Watts) & production_company(Sony Pictures) & release_decade_interval(2010's)
#     20   990     2     1 directors(Jon Watts) & production_company(Sony Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#     21   990     2     1 directors(Jon Watts) & production_company(Sony Pictures) & content_rating(PG-13)
#     22   990     2     1 directors(Jon Watts) & release_decade_interval(2010's) & content_rating(PG-13)
#     23   890     2     1 directors(Martin Scorsese) & release_decade_interval(2010's) & content_rating(R)
#     24   771     2     1 directors(Paul Feig) & release_decade_interval(2010's) & content_rating(R)
#     25   793     2     1 directors(Rian Johnson) & release_decade_interval(2010's) & content_rating(PG-13)
#     26  1080     2     1 directors(Ridley Scott) & production_company(20th Century Fox) & release_decade_interval(2010's)
#     27   754     2     1 directors(Ridley Scott) & production_company(20th Century Fox) & release_decade_interval(2010's) & content_rating(R)
#     28   948     2     1 directors(Ridley Scott) & production_company(20th Century Fox) & content_rating(R)
#     29   898     2     1 directors(Ridley Scott) & release_decade_interval(2010's) & content_rating(R)
#     30   785     2     1 directors(Sam Mendes) & release_decade_interval(2000's) & content_rating(R)
#     31   860     2     1 directors(Sam Mendes) & release_decade_interval(2010's) & content_rating(PG-13)
#     32  1117     2     1 directors(Sam Raimi) & release_decade_interval(2000's) & content_rating(PG-13)
#     33   811     2     1 directors(Steven Spielberg) & release_decade_interval(2000's) & content_rating(PG-13)
#     34  1242     2     1 directors(Steven Spielberg) & release_decade_interval(2010's) & content_rating(PG-13)
#     35  1027     2     2 directors(nan) & release_decade_interval(2000's) & content_rating(R)
#     36  1106     2     1 directors(nan) & release_decade_interval(2010's) & content_rating(R)
#     37   927     2     1 production_company(20th Century Fox) & release_decade_interval(1990's) & content_rating(R)
#     38  6161     2     1 production_company(20th Century Fox) & release_decade_interval(2010's) & content_rating(R)
#     39  3485     2     1 production_company(A24) & release_decade_interval(2010's) & content_rating(R)
#     40  2187     2     1 production_company(A24 Films) & release_decade_interval(2010's) & content_rating(R)
#     41  1051     2     2 production_company(A24 and DIRECTV) & release_decade_interval(2010's) & content_rating(R)
#     42   982     2     1 production_company(Amazon Studios) & release_decade_interval(2010's) & content_rating(R)
#     43  1228     2     1 production_company(Annapurna Pictures) & release_decade_interval(2010's) & content_rating(R)
#     44   949     2     2 production_company(Artisan Entertainment) & release_decade_interval(2000's) & content_rating(R)
#     45  1118     2     1 production_company(Buena Vista Pictures) & release_decade_interval(2000's) & content_rating(PG)
#     46  1123     2     1 production_company(CBS Films) & release_decade_interval(2010's) & content_rating(R)
#     47  1048     2     1 production_company(Columbia Pictures) & release_decade_interval(1990's) & content_rating(R)
#     48  1595     2     2 production_company(Columbia Pictures) & release_decade_interval(2000's) & content_rating(R)
#     49   772     2     1 production_company(Disney/Pixar) & release_decade_interval(2010's) & content_rating(PG)
#     50   837     2     1 production_company(Drafthouse Films) & release_decade_interval(2010's) & content_rating(NR)
#     51   805     2     1 production_company(DreamWorks SKG) & release_decade_interval(2000's) & content_rating(R)
#     52  1162     2     1 production_company(Dreamworks) & release_decade_interval(2000's) & content_rating(PG)
#     53  1097     2     1 production_company(Dreamworks) & release_decade_interval(2000's) & content_rating(PG-13)
#     54  3809     2     1 production_company(Focus Features) & release_decade_interval(2000's) & content_rating(R)
#     55   787     2     1 production_company(Focus Features) & release_decade_interval(2010's) & content_rating(PG)
#     56  2964     2     1 production_company(Focus Features) & release_decade_interval(2010's) & content_rating(PG-13)
#     57  5514     2     1 production_company(Focus Features) & release_decade_interval(2010's) & content_rating(R)
#     58  1272     2     1 production_company(Fox Searchlight) & release_decade_interval(2000's) & content_rating(R)
#     59   948     2     1 production_company(Fox Searchlight) & release_decade_interval(2010's) & content_rating(PG-13)
#     60  2331     2     1 production_company(Fox Searchlight) & release_decade_interval(2010's) & content_rating(R)
#     61  1633     2     1 production_company(Fox Searchlight Pictures) & release_decade_interval(2000's) & content_rating(PG-13)
#     62  3254     2     1 production_company(Fox Searchlight Pictures) & release_decade_interval(2000's) & content_rating(R)
#     63  1032     2     1 production_company(Fox Searchlight Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#     64  2287     2     1 production_company(Fox Searchlight Pictures) & release_decade_interval(2010's) & content_rating(R)
#     65  1016     2     1 production_company(IFC Films) & release_decade_interval(2000's) & content_rating(NR)
#     66  2331     2     1 production_company(IFC Films) & release_decade_interval(2000's) & content_rating(R)
#     67  4297     2     1 production_company(IFC Films) & release_decade_interval(2010's) & content_rating(NR)
#     68  1303     2     1 production_company(IFC Films) & release_decade_interval(2010's) & content_rating(PG-13)
#     69  2593     2     2 production_company(Lions Gate Films) & release_decade_interval(2000's) & content_rating(R)
#     70  2815     2     2 production_company(Lionsgate) & release_decade_interval(2010's) & content_rating(R)
#     71  1470     2     2 production_company(Lionsgate Films) & release_decade_interval(2000's) & content_rating(R)
#     72   962     2     1 production_company(MGM) & release_decade_interval(2010's) & content_rating(PG-13)
#     73  2775     2     1 production_company(Magnolia Pictures) & release_decade_interval(2000's) & content_rating(R)
#     74  5633     2     1 production_company(Magnolia Pictures) & release_decade_interval(2010's) & content_rating(R)
#     75   885     2     1 production_company(Marvel Studios) & release_decade_interval(2010's) & content_rating(PG-13)
#     76  1541     2     1 production_company(Miramax) & release_decade_interval(1990's) & content_rating(R)
#     77   769     2     1 production_company(Miramax) & release_decade_interval(2000's) & content_rating(PG-13)
#     78  1515     2     2 production_company(Miramax) & release_decade_interval(2000's) & content_rating(R)
#     79  1323     2     1 production_company(Miramax Films) & release_decade_interval(1990's) & content_rating(R)
#     80   765     2     1 production_company(Miramax Films) & release_decade_interval(2000's) & content_rating(PG)
#     81  2976     2     1 production_company(Miramax Films) & release_decade_interval(2000's) & content_rating(PG-13)
#     82  4335     2     1 production_company(Miramax Films) & release_decade_interval(2000's) & content_rating(R)
#     83  1192     2     1 production_company(Music Box Films) & release_decade_interval(2010's) & content_rating(NR)
#     84  1018     2     1 production_company(Music Box Films) & release_decade_interval(2010's) & content_rating(R)
#     85  1674     2     1 production_company(NEON) & release_decade_interval(2010's) & content_rating(R)
#     86  1670     2     1 production_company(Netflix) & release_decade_interval(2010's) & content_rating(NR)
#     87  2081     2     1 production_company(Netflix) & release_decade_interval(2010's) & content_rating(R)
#     88  1273     2     2 production_company(New Line Cinema) & release_decade_interval(2010's) & content_rating(PG-13)
#     89  3178     2     1 production_company(Open Road Films) & release_decade_interval(2010's) & content_rating(R)
#     90  1370     2     1 production_company(Paramount Classics) & release_decade_interval(2000's) & content_rating(R)
#     91   767     2     1 production_company(Paramount Pictures) & release_decade_interval(1980's) & content_rating(PG)
#     92   827     2     1 production_company(Paramount Pictures) & release_decade_interval(1990's) & content_rating(PG-13)
#     93  1286     2     1 production_company(Paramount Pictures) & release_decade_interval(1990's) & content_rating(R)
#     94  3408     2     1 production_company(Paramount Pictures) & release_decade_interval(2000's) & content_rating(R)
#     95   908     2     2 production_company(Paramount Pictures) & release_decade_interval(2010's) & content_rating(PG)
#     96  6155     2     1 production_company(Paramount Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#     97  4740     2     1 production_company(Paramount Pictures) & release_decade_interval(2010's) & content_rating(R)
#     98  1130     2     1 production_company(Paramount Vantage) & release_decade_interval(2000's) & content_rating(R)
#     99   874     2     1 production_company(Picturehouse) & release_decade_interval(2000's) & content_rating(R)
#    100  1504     2     1 production_company(Radius-TWC) & release_decade_interval(2010's) & content_rating(R)
#    101   753     2     1 production_company(Roadside Attractions) & release_decade_interval(2000's) & content_rating(R)
#    102  1258     2     1 production_company(Roadside Attractions) & release_decade_interval(2010's) & content_rating(PG-13)
#    103  2381     2     1 production_company(Roadside Attractions) & release_decade_interval(2010's) & content_rating(R)
#    104   780     2     2 production_company(STXfilms) & release_decade_interval(2010's) & content_rating(R)
#    105  1105     2     2 production_company(Samuel Goldwyn Films) & release_decade_interval(2000's) & content_rating(R)
#    106  3877     2     1 production_company(Sony Pictures) & release_decade_interval(2010's) & content_rating(R)
#    107  2707     2     1 production_company(Sony Pictures Classics) & release_decade_interval(2000's) & content_rating(PG-13)
#    108  5600     2     1 production_company(Sony Pictures Classics) & release_decade_interval(2000's) & content_rating(R)
#    109  2822     2     1 production_company(Sony Pictures Classics) & release_decade_interval(2010's) & content_rating(PG-13)
#    110  6403     2     1 production_company(Sony Pictures Classics) & release_decade_interval(2010's) & content_rating(R)
#    111   766     2     1 production_company(Sony Pictures Home Entertainment) & release_decade_interval(1990's) & content_rating(PG)
#    112  1008     2     1 production_company(Strand Releasing) & release_decade_interval(2010's) & content_rating(NR)
#    113  1511     2     2 production_company(Summit Entertainment) & release_decade_interval(2010's) & content_rating(R)
#    114  1382     2     1 production_company(The Weinstein Company) & release_decade_interval(2000's) & content_rating(R)
#    115  2153     2     1 production_company(The Weinstein Company) & release_decade_interval(2010's) & content_rating(PG-13)
#    116  3521     2     1 production_company(The Weinstein Company) & release_decade_interval(2010's) & content_rating(R)
#    117  1245     2     1 production_company(ThinkFilm) & release_decade_interval(2000's) & content_rating(R)
#    118  1259     2     1 production_company(Universal Pictures) & release_decade_interval(1990's) & content_rating(R)
#    119  5453     2     1 production_company(Universal Pictures) & release_decade_interval(2000's) & content_rating(R)
#    120   780     2     1 production_company(Universal Pictures) & release_decade_interval(2020's) & content_rating(R)
#    121  1087     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2000's) & content_rating(G)
#    122  1741     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2000's) & content_rating(PG)
#    123   790     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2010's) & content_rating(G)
#    124  5977     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2010's) & content_rating(PG)
#    125  7270     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#    126  1170     2     1 production_company(Warner Bros.) & release_decade_interval(2010's) & content_rating(R)
#    127   773     2     1 production_company(Warner Bros. Pictures) & release_decade_interval(1980's) & content_rating(R)
#    128   968     2     1 production_company(Warner Bros. Pictures) & release_decade_interval(1990's) & content_rating(R)
#    129  2021     2     1 production_company(Warner Bros. Pictures) & release_decade_interval(2010's) & content_rating(PG)
#    130   812     2     1 production_company(Warner Home Video) & release_decade_interval(1980's) & content_rating(R)
#    131   815     2     1 production_company(Warner Independent Pictures) & release_decade_interval(2000's) & content_rating(R)
#
#
#
# Rule id : 2
#
# Base :   863  Relative base : 0.001  Steps UP (consecutive) :     2  Steps DOWN (consecutive) :     1  Steps UP (any) :     3  Steps DOWN (any) :     1  Histogram maximum :   388  Histogram minimum :    17  Histogram relative maximum : 0.450 Histogram relative minimum : 0.020
#
# Condition  : directors(Bryan Singer) & production_company(20th Century Fox) & content_rating(PG-13)
#
# Histogram [85, 294, 388, 17, 79]

# %% [markdown]
# ### histogram pro hodnocení filmů dle kritika a publishera, typu review a je-li kritik top-kritik

# %%
df = data
df = df.loc[:, ('critic_name', 'release_decade_interval', 'review_score_interval', 'publisher_name', 'review_type', 'top_critic')]



clm = cleverminer(df=df,target='review_score_interval',proc='CFMiner',
               quantifiers= {'S_Up':2, 'Base':500},
                cond={
                    'attributes':[
                        {'name': 'critic_name', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'publisher_name', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'review_type', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':3, 'maxlen':4, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  CFMiner
# Starting to mine rules.
# Done. Total verifications : 1514, rules 828,control number:0, times: prep 11.32285475730896, processing 25.42260503768921
#
# CleverMiner task processing summary:
#
# Task type : CFMiner
# Number of verifications : 1514
# Number of rules : 828
# Total time needed : 00h 00m 36s
# Time of data preparation : 00h 00m 11s
# Time of rule mining : 00h 00m 25s
#
#
# List of rules:
# RULEID BASE  S_UP  S_DOWN Condition
#      1   867     2     1 critic_name(A.O. Scott) & publisher_name(New York Times) & review_type(Fresh)
#      2   867     2     1 critic_name(A.O. Scott) & publisher_name(New York Times) & review_type(Fresh) & top_critic(True)
#      3  1383     2     1 critic_name(A.O. Scott) & publisher_name(New York Times) & top_critic(True)
#      4   867     2     1 critic_name(A.O. Scott) & review_type(Fresh) & top_critic(True)
#      5   795     2     1 critic_name(Alistair Harkness) & publisher_name(Scotsman) & review_type(Fresh)
#      6   795     2     1 critic_name(Alistair Harkness) & publisher_name(Scotsman) & review_type(Fresh) & top_critic(False)
#      7   795     2     1 critic_name(Alistair Harkness) & review_type(Fresh) & top_critic(False)
#      8  1075     2     1 critic_name(Allan Hunter) & review_type(Fresh) & top_critic(False)
#      9   593     2     1 critic_name(Amber Wilkinson) & publisher_name(Eye for Film) & review_type(Fresh)
#     10   593     2     1 critic_name(Amber Wilkinson) & publisher_name(Eye for Film) & review_type(Fresh) & top_critic(False)
#     11   734     2     1 critic_name(Amber Wilkinson) & publisher_name(Eye for Film) & top_critic(False)
#     12   598     2     1 critic_name(Amber Wilkinson) & review_type(Fresh) & top_critic(False)
#     13   617     2     1 critic_name(Amy Biancolli) & publisher_name(Houston Chronicle) & top_critic(True)
#     14  1076     2     1 critic_name(Andrea Chase) & publisher_name(Killer Movie Reviews) & review_type(Fresh)
#     15  1076     2     1 critic_name(Andrea Chase) & publisher_name(Killer Movie Reviews) & review_type(Fresh) & top_critic(False)
#     16  1076     2     1 critic_name(Andrea Chase) & review_type(Fresh) & top_critic(False)
#     17   665     2     1 critic_name(Ann Hornaday) & publisher_name(Washington Post) & review_type(Fresh)
#     18   665     2     1 critic_name(Ann Hornaday) & publisher_name(Washington Post) & review_type(Fresh) & top_critic(True)
#     19   952     2     1 critic_name(Ann Hornaday) & publisher_name(Washington Post) & top_critic(True)
#     20   665     2     1 critic_name(Ann Hornaday) & review_type(Fresh) & top_critic(True)
#     21   808     2     1 critic_name(Avi Offer) & publisher_name(NYC Movie Guru) & review_type(Fresh)
#     22   808     2     1 critic_name(Avi Offer) & publisher_name(NYC Movie Guru) & review_type(Fresh) & top_critic(False)
#     23  1274     2     1 critic_name(Avi Offer) & publisher_name(NYC Movie Guru) & top_critic(False)
#     24   808     2     1 critic_name(Avi Offer) & review_type(Fresh) & top_critic(False)
#     25   524     2     2 critic_name(Betsy Sharkey) & publisher_name(Los Angeles Times) & top_critic(True)
#     26   512     2     1 critic_name(Bill Gibron) & publisher_name(PopMatters) & review_type(Fresh)
#     27   512     2     1 critic_name(Bill Gibron) & publisher_name(PopMatters) & review_type(Fresh) & top_critic(False)
#     28   721     2     1 critic_name(Bill Gibron) & publisher_name(PopMatters) & top_critic(False)
#     29   902     2     1 critic_name(Bill Gibron) & review_type(Fresh) & top_critic(False)
#     30  1422     2     1 critic_name(Bill Goodykoontz) & publisher_name(Arizona Republic) & review_type(Fresh)
#     31  1422     2     1 critic_name(Bill Goodykoontz) & publisher_name(Arizona Republic) & review_type(Fresh) & top_critic(True)
#     32  1915     2     1 critic_name(Bill Goodykoontz) & publisher_name(Arizona Republic) & top_critic(True)
#     33  1422     2     1 critic_name(Bill Goodykoontz) & review_type(Fresh) & top_critic(True)
#     34   679     2     1 critic_name(Bill Muller) & publisher_name(Arizona Republic) & top_critic(True)
#     35   510     2     1 critic_name(Blake Howard) & review_type(Fresh) & top_critic(False)
#     36  1048     2     1 critic_name(Bob Bloom) & publisher_name(Journal and Courier (Lafayette, IN)) & review_type(Fresh)
#     37  1048     2     1 critic_name(Bob Bloom) & publisher_name(Journal and Courier (Lafayette, IN)) & review_type(Fresh) & top_critic(False)
#     38  1507     2     2 critic_name(Bob Bloom) & publisher_name(Journal and Courier (Lafayette, IN)) & top_critic(False)
#     39  1170     2     1 critic_name(Bob Bloom) & review_type(Fresh) & top_critic(False)
#     40   603     2     1 critic_name(Brian Mckay) & publisher_name(eFilmCritic.com) & top_critic(False)
#     41   850     2     1 critic_name(Brian Webster) & publisher_name(Apollo Guide) & review_type(Fresh)
#     42   850     2     1 critic_name(Brian Webster) & publisher_name(Apollo Guide) & review_type(Fresh) & top_critic(False)
#     43  1428     2     1 critic_name(Brian Webster) & publisher_name(Apollo Guide) & top_critic(False)
#     44   850     2     1 critic_name(Brian Webster) & review_type(Fresh) & top_critic(False)
#     45   652     2     1 critic_name(Bruce Kirkland) & publisher_name(Jam! Movies) & top_critic(False)
#     46   569     2     1 critic_name(CJ Johnson) & publisher_name(Film Mafia) & top_critic(False)
#     47  1723     2     1 critic_name(Carol Cling) & publisher_name(Las Vegas Review-Journal) & review_type(Fresh)
#     48  1723     2     1 critic_name(Carol Cling) & publisher_name(Las Vegas Review-Journal) & review_type(Fresh) & top_critic(False)
#     49  1982     2     1 critic_name(Carol Cling) & publisher_name(Las Vegas Review-Journal) & top_critic(False)
#     50  1723     2     1 critic_name(Carol Cling) & review_type(Fresh) & top_critic(False)
#     51   787     2     1 critic_name(Carrie Rickey) & publisher_name(Philadelphia Inquirer) & review_type(Fresh)
#     52   787     2     1 critic_name(Carrie Rickey) & publisher_name(Philadelphia Inquirer) & review_type(Fresh) & top_critic(True)
#     53  1202     2     1 critic_name(Carrie Rickey) & publisher_name(Philadelphia Inquirer) & top_critic(True)
#     54   787     2     1 critic_name(Carrie Rickey) & review_type(Fresh) & top_critic(True)
#     55   687     2     1 critic_name(Charles Koplinski) & publisher_name(Illinois Times) & top_critic(False)
#     56   534     2     1 critic_name(Charlotte O'Sullivan) & publisher_name(London Evening Standard) & review_type(Fresh)
#     57   534     2     1 critic_name(Charlotte O'Sullivan) & publisher_name(London Evening Standard) & review_type(Fresh) & top_critic(True)
#     58   534     2     1 critic_name(Charlotte O'Sullivan) & review_type(Fresh) & top_critic(True)
#     59  1439     2     1 critic_name(Cherryl Dawson and Leigh Ann Palone) & publisher_name(TheMovieChicks.com) & top_critic(False)
#     60   518     2     1 critic_name(Chris Barsanti) & review_type(Fresh) & top_critic(False)
#     61   909     2     1 critic_name(Chris Bumbray) & publisher_name(JoBlo's Movie Network) & review_type(Fresh)
#     62   909     2     1 critic_name(Chris Bumbray) & publisher_name(JoBlo's Movie Network) & review_type(Fresh) & top_critic(False)
#     63  1238     2     1 critic_name(Chris Bumbray) & publisher_name(JoBlo's Movie Network) & top_critic(False)
#     64   917     2     1 critic_name(Chris Bumbray) & review_type(Fresh) & top_critic(False)
#     65   566     2     1 critic_name(Chris Cabin) & publisher_name(Filmcritic.com) & top_critic(False)
#     66  2179     2     1 critic_name(Chris Hewitt) & publisher_name(St. Paul Pioneer Press) & review_type(Fresh)
#     67  2179     2     1 critic_name(Chris Hewitt) & publisher_name(St. Paul Pioneer Press) & review_type(Fresh) & top_critic(False)
#     68  3422     2     2 critic_name(Chris Hewitt) & publisher_name(St. Paul Pioneer Press) & top_critic(False)
#     69  2179     2     1 critic_name(Chris Hewitt) & review_type(Fresh) & top_critic(False)
#     70   826     2     1 critic_name(Chris Knight) & publisher_name(National Post) & review_type(Fresh)
#     71   826     2     1 critic_name(Chris Knight) & publisher_name(National Post) & review_type(Fresh) & top_critic(False)
#     72  1153     2     1 critic_name(Chris Knight) & publisher_name(National Post) & top_critic(False)
#     73   826     2     1 critic_name(Chris Knight) & review_type(Fresh) & top_critic(False)
#     74   512     2     2 critic_name(Christian Toto) & publisher_name(HollywoodInToto.com) & top_critic(False)
#     75   790     2     1 critic_name(Christian Toto) & review_type(Fresh) & top_critic(False)
#     76  1528     2     1 critic_name(Christopher Null) & publisher_name(Filmcritic.com) & review_type(Fresh)
#     77  1528     2     1 critic_name(Christopher Null) & publisher_name(Filmcritic.com) & review_type(Fresh) & top_critic(False)
#     78  2717     2     1 critic_name(Christopher Null) & publisher_name(Filmcritic.com) & top_critic(False)
#     79  1550     2     1 critic_name(Christopher Null) & review_type(Fresh) & top_critic(False)
#     80  1095     2     1 critic_name(Claudia Puig) & publisher_name(USA Today) & review_type(Fresh)
#     81  1095     2     1 critic_name(Claudia Puig) & publisher_name(USA Today) & review_type(Fresh) & top_critic(True)
#     82  1110     2     1 critic_name(Claudia Puig) & review_type(Fresh) & top_critic(True)
#     83  1055     2     1 critic_name(Cole Smithey) & publisher_name(ColeSmithey.com) & review_type(Fresh)
#     84  1055     2     1 critic_name(Cole Smithey) & publisher_name(ColeSmithey.com) & review_type(Fresh) & top_critic(False)
#     85  1169     2     1 critic_name(Cole Smithey) & publisher_name(ColeSmithey.com) & top_critic(False)
#     86  1055     2     1 critic_name(Cole Smithey) & review_type(Fresh) & top_critic(False)
#     87   556     2     1 critic_name(Dan Jardine) & publisher_name(Apollo Guide) & top_critic(False)
#     88   637     2     1 critic_name(Dan Jardine) & review_type(Fresh) & top_critic(False)
#     89   718     2     1 critic_name(Dan Lybarger) & review_type(Fresh) & top_critic(False)
#     90   610     2     1 critic_name(Daniel M. Kimmel) & publisher_name(North Shore Movies) & review_type(Fresh)
#     91   610     2     1 critic_name(Daniel M. Kimmel) & publisher_name(North Shore Movies) & review_type(Fresh) & top_critic(False)
#     92  1148     2     1 critic_name(Daniel M. Kimmel) & publisher_name(Worcester Telegram & Gazette) & review_type(Fresh)
#     93  1148     2     1 critic_name(Daniel M. Kimmel) & publisher_name(Worcester Telegram & Gazette) & review_type(Fresh) & top_critic(False)
#     94  1826     2     1 critic_name(Daniel M. Kimmel) & review_type(Fresh) & top_critic(False)
#     95   581     2     1 critic_name(Dave White) & publisher_name(Movies.com) & review_type(Fresh)
#     96   581     2     1 critic_name(Dave White) & publisher_name(Movies.com) & review_type(Fresh) & top_critic(False)
#     97   589     2     1 critic_name(Dave White) & review_type(Fresh) & top_critic(False)
#     98   545     2     1 critic_name(David Cornelius) & publisher_name(eFilmCritic.com) & top_critic(False)
#     99   604     2     1 critic_name(David Edwards) & publisher_name(Daily Mirror (UK)) & review_type(Fresh)
#    100   604     2     1 critic_name(David Edwards) & publisher_name(Daily Mirror (UK)) & review_type(Fresh) & top_critic(False)
#    101   632     2     1 critic_name(David Edwards) & review_type(Fresh) & top_critic(False)
#    102   602     2     1 critic_name(David Keyes) & publisher_name(Cinemaphile.org) & review_type(Fresh)
#    103   602     2     1 critic_name(David Keyes) & publisher_name(Cinemaphile.org) & review_type(Fresh) & top_critic(False)
#    104  1037     2     2 critic_name(David Keyes) & publisher_name(Cinemaphile.org) & top_critic(False)
#    105   607     2     1 critic_name(David Keyes) & review_type(Fresh) & top_critic(False)
#    106   523     2     1 critic_name(David N. Butterworth) & review_type(Fresh) & top_critic(False)
#    107  2677     2     1 critic_name(David Nusair) & publisher_name(Reel Film Reviews) & review_type(Fresh)
#    108  2677     2     1 critic_name(David Nusair) & publisher_name(Reel Film Reviews) & review_type(Fresh) & top_critic(False)
#    109  2690     2     1 critic_name(David Nusair) & review_type(Fresh) & top_critic(False)
#    110   703     2     1 critic_name(David Parkinson) & review_type(Fresh) & top_critic(False)
#    111   502     2     1 critic_name(David Sterritt) & publisher_name(Christian Science Monitor) & review_type(Fresh)
#    112   502     2     1 critic_name(David Sterritt) & publisher_name(Christian Science Monitor) & review_type(Fresh) & top_critic(False)
#    113   858     2     1 critic_name(David Sterritt) & publisher_name(Christian Science Monitor) & top_critic(False)
#    114   502     2     1 critic_name(David Sterritt) & review_type(Fresh) & top_critic(False)
#    115   767     2     1 critic_name(David Stratton) & review_type(Fresh) & top_critic(False)
#    116   860     2     1 critic_name(Duane Dudek) & publisher_name(Milwaukee Journal Sentinel) & review_type(Fresh)
#    117   860     2     1 critic_name(Duane Dudek) & publisher_name(Milwaukee Journal Sentinel) & review_type(Fresh) & top_critic(False)
#    118  1245     2     1 critic_name(Duane Dudek) & publisher_name(Milwaukee Journal Sentinel) & top_critic(False)
#    119   860     2     1 critic_name(Duane Dudek) & review_type(Fresh) & top_critic(False)
#    120  1716     2     1 critic_name(Dustin Putman) & publisher_name(TheFilmFile.com) & review_type(Fresh)
#    121  1716     2     1 critic_name(Dustin Putman) & publisher_name(TheFilmFile.com) & review_type(Fresh) & top_critic(False)
#    122  1844     2     1 critic_name(Dustin Putman) & review_type(Fresh) & top_critic(False)
#    123   619     2     1 critic_name(Ed Gonzalez) & publisher_name(Slant Magazine) & review_type(Fresh)
#    124   619     2     1 critic_name(Ed Gonzalez) & publisher_name(Slant Magazine) & review_type(Fresh) & top_critic(False)
#    125   635     2     1 critic_name(Ed Gonzalez) & review_type(Fresh) & top_critic(False)
#    126  1132     2     1 critic_name(Edward Douglas) & publisher_name(ComingSoon.net) & review_type(Fresh)
#    127  1132     2     1 critic_name(Edward Douglas) & publisher_name(ComingSoon.net) & review_type(Fresh) & top_critic(False)
#    128  1702     2     1 critic_name(Edward Douglas) & publisher_name(ComingSoon.net) & top_critic(False)
#    129  1330     2     1 critic_name(Edward Douglas) & review_type(Fresh) & top_critic(False)
#    130   503     2     1 critic_name(Edward Johnson-Ott) & publisher_name(NUVO Newsweekly) & top_critic(False)
#    131   503     2     1 critic_name(Emily Blunt) & publisher_name(Blunt Review) & top_critic(False)
#    132   592     2     1 critic_name(Eric Melin) & publisher_name(Scene-Stealers.com) & review_type(Fresh)
#    133   592     2     1 critic_name(Eric Melin) & publisher_name(Scene-Stealers.com) & review_type(Fresh) & top_critic(False)
#    134   857     2     2 critic_name(Eric Melin) & publisher_name(Scene-Stealers.com) & top_critic(False)
#    135   776     2     1 critic_name(Eric Melin) & review_type(Fresh) & top_critic(False)
#    136   619     2     1 critic_name(Erik Childress) & publisher_name(eFilmCritic.com) & review_type(Fresh)
#    137   619     2     1 critic_name(Erik Childress) & publisher_name(eFilmCritic.com) & review_type(Fresh) & top_critic(False)
#    138  1205     2     2 critic_name(Erik Childress) & publisher_name(eFilmCritic.com) & top_critic(False)
#    139   636     2     1 critic_name(Erik Childress) & review_type(Fresh) & top_critic(False)
#    140   580     2     1 critic_name(Frank Ochieng) & review_type(Fresh) & top_critic(False)
#    141  2523     2     1 critic_name(Frederic and Mary Ann Brussat) & publisher_name(Spirituality & Practice) & review_type(Fresh)
#    142  2523     2     1 critic_name(Frederic and Mary Ann Brussat) & publisher_name(Spirituality & Practice) & review_type(Fresh) & top_critic(False)
#    143  3118     2     1 critic_name(Frederic and Mary Ann Brussat) & publisher_name(Spirituality & Practice) & top_critic(False)
#    144  2523     2     1 critic_name(Frederic and Mary Ann Brussat) & review_type(Fresh) & top_critic(False)
#    145   605     2     1 critic_name(Gary Wolcott) & publisher_name(Tri-City Herald) & review_type(Fresh)
#    146   605     2     1 critic_name(Gary Wolcott) & publisher_name(Tri-City Herald) & review_type(Fresh) & top_critic(False)
#    147  1013     2     1 critic_name(Gary Wolcott) & publisher_name(Tri-City Herald) & top_critic(False)
#    148   665     2     1 critic_name(Gary Wolcott) & review_type(Fresh) & top_critic(False)
#    149   724     2     2 critic_name(Glenn Whipp) & publisher_name(Los Angeles Daily News) & top_critic(False)
#    150   624     2     1 critic_name(Graham Young) & review_type(Fresh) & top_critic(False)
#    151   668     2     2 critic_name(Greg Maki) & publisher_name(Star-Democrat (Easton, MD)) & top_critic(False)
#    152   711     2     1 critic_name(Harvey S. Karten) & publisher_name(Compuserve) & review_type(Fresh)
#    153   711     2     1 critic_name(Harvey S. Karten) & publisher_name(Compuserve) & review_type(Fresh) & top_critic(False)
#    154   929     2     1 critic_name(Harvey S. Karten) & publisher_name(Compuserve) & top_critic(False)
#    155   712     2     1 critic_name(Harvey S. Karten) & review_type(Fresh) & top_critic(False)
#    156   694     2     1 critic_name(Ian Mantgani) & publisher_name(UK Critic) & top_critic(False)
#    157   727     2     1 critic_name(J. Olson) & publisher_name(Cinemixtape) & top_critic(False)
#    158  1182     2     1 critic_name(Jack Garner) & publisher_name(Rochester Democrat and Chronicle) & review_type(Fresh)
#    159  1182     2     1 critic_name(Jack Garner) & publisher_name(Rochester Democrat and Chronicle) & review_type(Fresh) & top_critic(False)
#    160  1582     2     1 critic_name(Jack Garner) & publisher_name(Rochester Democrat and Chronicle) & top_critic(False)
#    161  1205     2     1 critic_name(Jack Garner) & review_type(Fresh) & top_critic(False)
#    162   704     2     1 critic_name(Jackie K. Cooper) & publisher_name(jackiekcooper.com) & review_type(Fresh)
#    163   704     2     1 critic_name(Jackie K. Cooper) & publisher_name(jackiekcooper.com) & review_type(Fresh) & top_critic(False)
#    164   765     2     1 critic_name(Jackie K. Cooper) & review_type(Fresh) & top_critic(False)
#    165  2679     2     1 critic_name(James Berardinelli) & publisher_name(ReelViews) & review_type(Fresh)
#    166  2679     2     1 critic_name(James Berardinelli) & publisher_name(ReelViews) & review_type(Fresh) & top_critic(True)
#    167  5166     2     2 critic_name(James Berardinelli) & publisher_name(ReelViews) & top_critic(True)
#    168  2679     2     1 critic_name(James Berardinelli) & review_type(Fresh) & top_critic(True)
#    169  1759     2     1 critic_name(James Kendrick) & publisher_name(Q Network Film Desk) & review_type(Fresh)
#    170  1759     2     1 critic_name(James Kendrick) & publisher_name(Q Network Film Desk) & review_type(Fresh) & top_critic(False)
#    171  2705     2     1 critic_name(James Kendrick) & publisher_name(Q Network Film Desk) & top_critic(False)
#    172  1759     2     1 critic_name(James Kendrick) & review_type(Fresh) & top_critic(False)
#    173   585     2     1 critic_name(James Mottram) & review_type(Fresh) & top_critic(False)
#    174   794     2     1 critic_name(James Rocchi) & publisher_name(Netflix) & review_type(Fresh)
#    175   794     2     1 critic_name(James Rocchi) & publisher_name(Netflix) & review_type(Fresh) & top_critic(False)
#    176   998     2     1 critic_name(James Rocchi) & publisher_name(Netflix) & top_critic(False)
#    177  1012     2     1 critic_name(James Rocchi) & review_type(Fresh) & top_critic(False)
#    178   511     2     1 critic_name(James Sanford) & publisher_name(Kalamazoo Gazette) & review_type(Fresh)
#    179   511     2     1 critic_name(James Sanford) & publisher_name(Kalamazoo Gazette) & review_type(Fresh) & top_critic(False)
#    180   850     2     2 critic_name(James Sanford) & publisher_name(Kalamazoo Gazette) & top_critic(False)
#    181   523     2     1 critic_name(James Sanford) & review_type(Fresh) & top_critic(False)
#    182   527     2     1 critic_name(James Verniere) & publisher_name(Boston Herald) & top_critic(False)
#    183   585     2     1 critic_name(Janet Maslin) & publisher_name(New York Times) & top_critic(True)
#    184   582     2     2 critic_name(Jason Zingale) & publisher_name(Bullz-Eye.com) & top_critic(False)
#    185   802     2     1 critic_name(Jeanne Aufmuth) & publisher_name(Palo Alto Weekly) & review_type(Fresh)
#    186   802     2     1 critic_name(Jeanne Aufmuth) & publisher_name(Palo Alto Weekly) & review_type(Fresh) & top_critic(False)
#    187  1212     2     1 critic_name(Jeanne Aufmuth) & publisher_name(Palo Alto Weekly) & top_critic(False)
#    188   826     2     1 critic_name(Jeanne Aufmuth) & review_type(Fresh) & top_critic(False)
#    189   971     2     1 critic_name(Jeff Vice) & publisher_name(Deseret News (Salt Lake City)) & review_type(Fresh)
#    190   971     2     1 critic_name(Jeff Vice) & publisher_name(Deseret News (Salt Lake City)) & review_type(Fresh) & top_critic(False)
#    191   985     2     1 critic_name(Jeff Vice) & review_type(Fresh) & top_critic(False)
#    192   623     2     1 critic_name(Jeffrey Chen) & publisher_name(Window to the Movies) & review_type(Fresh)
#    193   623     2     1 critic_name(Jeffrey Chen) & publisher_name(Window to the Movies) & review_type(Fresh) & top_critic(False)
#    194   914     2     1 critic_name(Jeffrey Chen) & publisher_name(Window to the Movies) & top_critic(False)
#    195   804     2     1 critic_name(Jeffrey Chen) & review_type(Fresh) & top_critic(False)
#    196   514     2     1 critic_name(Jeffrey Lyles) & publisher_name(Lyles' Movie Files) & review_type(Fresh)
#    197   514     2     1 critic_name(Jeffrey Lyles) & publisher_name(Lyles' Movie Files) & review_type(Fresh) & top_critic(False)
#    198   734     2     1 critic_name(Jeffrey Lyles) & publisher_name(Lyles' Movie Files) & top_critic(False)
#    199   612     2     1 critic_name(Jeffrey Lyles) & review_type(Fresh) & top_critic(False)
#    200  2144     2     1 critic_name(Jeffrey M. Anderson) & publisher_name(Combustible Celluloid) & review_type(Fresh)
#    201  2144     2     1 critic_name(Jeffrey M. Anderson) & publisher_name(Combustible Celluloid) & review_type(Fresh) & top_critic(False)
#    202  3062     2     1 critic_name(Jeffrey M. Anderson) & publisher_name(Combustible Celluloid) & top_critic(False)
#    203  3113     2     1 critic_name(Jeffrey M. Anderson) & review_type(Fresh) & top_critic(False)
#    204  1594     2     1 critic_name(Jeffrey Westhoff) & publisher_name(Northwest Herald (Crystal Lake, IL)) & review_type(Fresh)
#    205  1594     2     1 critic_name(Jeffrey Westhoff) & publisher_name(Northwest Herald (Crystal Lake, IL)) & review_type(Fresh) & top_critic(False)
#    206  1594     2     1 critic_name(Jeffrey Westhoff) & review_type(Fresh) & top_critic(False)
#    207   784     2     1 critic_name(Jennie Kermode) & publisher_name(Eye for Film) & review_type(Fresh)
#    208   784     2     1 critic_name(Jennie Kermode) & publisher_name(Eye for Film) & review_type(Fresh) & top_critic(False)
#    209   952     2     1 critic_name(Jennie Kermode) & publisher_name(Eye for Film) & top_critic(False)
#    210   788     2     1 critic_name(Jennie Kermode) & review_type(Fresh) & top_critic(False)
#    211   778     2     2 critic_name(Jim Slotek) & publisher_name(Jam! Movies) & top_critic(False)
#    212   965     2     1 critic_name(JoBlo) & publisher_name(JoBlo's Movie Network) & review_type(Fresh)
#    213   965     2     1 critic_name(JoBlo) & publisher_name(JoBlo's Movie Network) & review_type(Fresh) & top_critic(False)
#    214  1423     2     1 critic_name(JoBlo) & publisher_name(JoBlo's Movie Network) & top_critic(False)
#    215   965     2     1 critic_name(JoBlo) & review_type(Fresh) & top_critic(False)
#    216   584     2     1 critic_name(Joe Baltake) & publisher_name(Sacramento Bee) & top_critic(False)
#    217   521     2     1 critic_name(Joe Lozito) & publisher_name(Big Picture Big Sound) & review_type(Fresh)
#    218   521     2     1 critic_name(Joe Lozito) & publisher_name(Big Picture Big Sound) & review_type(Fresh) & top_critic(False)
#    219   954     2     2 critic_name(Joe Lozito) & publisher_name(Big Picture Big Sound) & top_critic(False)
#    220   521     2     1 critic_name(Joe Lozito) & review_type(Fresh) & top_critic(False)
#    221   553     2     1 critic_name(Joe Williams) & publisher_name(St. Louis Post-Dispatch) & review_type(Fresh)
#    222   553     2     1 critic_name(Joe Williams) & publisher_name(St. Louis Post-Dispatch) & review_type(Fresh) & top_critic(True)
#    223   907     2     1 critic_name(Joe Williams) & publisher_name(St. Louis Post-Dispatch) & top_critic(True)
#    224   553     2     1 critic_name(Joe Williams) & review_type(Fresh) & top_critic(True)
#    225   825     2     1 critic_name(John Anderson) & publisher_name(Newsday) & top_critic(True)
#    226  1581     2     1 critic_name(John Beifuss) & publisher_name(Commercial Appeal (Memphis, TN)) & review_type(Fresh)
#    227  1581     2     1 critic_name(John Beifuss) & publisher_name(Commercial Appeal (Memphis, TN)) & review_type(Fresh) & top_critic(False)
#    228  2609     2     1 critic_name(John Beifuss) & publisher_name(Commercial Appeal (Memphis, TN)) & top_critic(False)
#    229  1581     2     1 critic_name(John Beifuss) & review_type(Fresh) & top_critic(False)
#    230   618     2     1 critic_name(John Hartl) & publisher_name(Seattle Times) & top_critic(True)
#    231  1069     2     1 critic_name(John J. Puccio) & publisher_name(Movie Metropolis) & review_type(Fresh)
#    232  1069     2     1 critic_name(John J. Puccio) & publisher_name(Movie Metropolis) & review_type(Fresh) & top_critic(False)
#    233  1963     2     1 critic_name(John J. Puccio) & publisher_name(Movie Metropolis) & top_critic(False)
#    234  1069     2     1 critic_name(John J. Puccio) & review_type(Fresh) & top_critic(False)
#    235   543     2     1 critic_name(John Lui) & publisher_name(The Straits Times (Singapore)) & top_critic(False)
#    236   515     2     1 critic_name(John R. McEwen) & publisher_name(Film Quips Online) & review_type(Fresh)
#    237   515     2     1 critic_name(John R. McEwen) & publisher_name(Film Quips Online) & review_type(Fresh) & top_critic(False)
#    238   783     2     1 critic_name(John R. McEwen) & publisher_name(Film Quips Online) & top_critic(False)
#    239   515     2     1 critic_name(John R. McEwen) & review_type(Fresh) & top_critic(False)
#    240   525     2     1 critic_name(John Serba) & publisher_name(MLive.com) & top_critic(False)
#    241   608     2     1 critic_name(John Urbancich) & publisher_name(Your Movies (cleveland.com)) & top_critic(False)
#    242   730     2     1 critic_name(John Wirt) & publisher_name(Advocate (Baton Rouge, LA)) & top_critic(False)
#    243   513     2     1 critic_name(Jon Niccum) & publisher_name(Lawrence Journal-World) & review_type(Fresh)
#    244   513     2     1 critic_name(Jon Niccum) & publisher_name(Lawrence Journal-World) & review_type(Fresh) & top_critic(False)
#    245   736     2     1 critic_name(Jon Niccum) & review_type(Fresh) & top_critic(False)
#    246   751     2     1 critic_name(Jon Popick) & publisher_name(Planet S Magazine) & top_critic(False)
#    247   575     2     1 critic_name(Jonathan W. Hickman) & review_type(Fresh) & top_critic(False)
#    248   663     2     1 critic_name(Josh Bell) & publisher_name(Las Vegas Weekly) & review_type(Fresh)
#    249   663     2     1 critic_name(Josh Bell) & publisher_name(Las Vegas Weekly) & review_type(Fresh) & top_critic(False)
#    250   739     2     1 critic_name(Josh Bell) & review_type(Fresh) & top_critic(False)
#    251  1053     2     1 critic_name(Josh Larsen) & publisher_name(LarsenOnFilm) & review_type(Fresh)
#    252  1053     2     1 critic_name(Josh Larsen) & publisher_name(LarsenOnFilm) & review_type(Fresh) & top_critic(False)
#    253  1454     2     1 critic_name(Josh Larsen) & publisher_name(LarsenOnFilm) & top_critic(False)
#    254   994     2     2 critic_name(Josh Larsen) & publisher_name(Sun Publications (Chicago, IL)) & top_critic(False)
#    255  1558     2     1 critic_name(Josh Larsen) & review_type(Fresh) & top_critic(False)
#    256   539     2     1 critic_name(Josh Terry) & publisher_name(Deseret News (Salt Lake City)) & top_critic(False)
#    257   776     2     1 critic_name(Joshua Rothkopf) & publisher_name(Time Out) & review_type(Fresh)
#    258   776     2     1 critic_name(Joshua Rothkopf) & publisher_name(Time Out) & review_type(Fresh) & top_critic(True)
#    259   776     2     1 critic_name(Joshua Rothkopf) & review_type(Fresh) & top_critic(True)
#    260   814     2     1 critic_name(Joshua Tyler) & publisher_name(CinemaBlend) & top_critic(False)
#    261   515     2     1 critic_name(Joshua Tyler) & review_type(Fresh) & top_critic(False)
#    262  1258     2     1 critic_name(Jules Brenner) & publisher_name(Cinema Signals) & review_type(Fresh)
#    263  1258     2     1 critic_name(Jules Brenner) & publisher_name(Cinema Signals) & review_type(Fresh) & top_critic(False)
#    264  1773     2     1 critic_name(Jules Brenner) & publisher_name(Cinema Signals) & top_critic(False)
#    265  1301     2     1 critic_name(Jules Brenner) & review_type(Fresh) & top_critic(False)
#    266   544     2     1 critic_name(Julian Roman) & publisher_name(MovieWeb) & review_type(Fresh)
#    267   544     2     1 critic_name(Julian Roman) & publisher_name(MovieWeb) & review_type(Fresh) & top_critic(False)
#    268   546     2     1 critic_name(Julian Roman) & review_type(Fresh) & top_critic(False)
#    269   514     2     1 critic_name(Kam Williams) & publisher_name(Baret News) & top_critic(False)
#    270   545     2     1 critic_name(Kam Williams) & publisher_name(NewsBlaze) & top_critic(False)
#    271  1546     2     1 critic_name(Kam Williams) & review_type(Fresh) & top_critic(False)
#    272   646     2     1 critic_name(Karina Montgomery) & publisher_name(Cinerina) & review_type(Fresh)
#    273   646     2     1 critic_name(Karina Montgomery) & publisher_name(Cinerina) & review_type(Fresh) & top_critic(False)
#    274   847     2     1 critic_name(Karina Montgomery) & publisher_name(Cinerina) & top_critic(False)
#    275   672     2     1 critic_name(Karina Montgomery) & review_type(Fresh) & top_critic(False)
#    276   566     2     1 critic_name(Kate Muir) & publisher_name(Times (UK)) & top_critic(True)
#    277   698     2     1 critic_name(Ken Fox) & publisher_name(TV Guide) & review_type(Fresh)
#    278   698     2     1 critic_name(Ken Fox) & publisher_name(TV Guide) & review_type(Fresh) & top_critic(False)
#    279  1040     2     1 critic_name(Ken Fox) & publisher_name(TV Guide) & top_critic(False)
#    280   698     2     1 critic_name(Ken Fox) & review_type(Fresh) & top_critic(False)
#    281  2917     2     1 critic_name(Ken Hanke) & publisher_name(Mountain Xpress (Asheville, NC)) & review_type(Fresh)
#    282  2917     2     1 critic_name(Ken Hanke) & publisher_name(Mountain Xpress (Asheville, NC)) & review_type(Fresh) & top_critic(False)
#    283  4157     2     1 critic_name(Ken Hanke) & publisher_name(Mountain Xpress (Asheville, NC)) & top_critic(False)
#    284  2917     2     1 critic_name(Ken Hanke) & review_type(Fresh) & top_critic(False)
#    285   946     2     1 critic_name(Kenneth Turan) & publisher_name(Los Angeles Times) & review_type(Fresh)
#    286   946     2     1 critic_name(Kenneth Turan) & publisher_name(Los Angeles Times) & review_type(Fresh) & top_critic(True)
#    287  1346     2     1 critic_name(Kenneth Turan) & publisher_name(Los Angeles Times) & top_critic(True)
#    288   947     2     1 critic_name(Kenneth Turan) & review_type(Fresh) & top_critic(True)
#    289   707     2     1 critic_name(Kevin A. Ranson) & publisher_name(MovieCrypt.com) & review_type(Fresh)
#    290   707     2     1 critic_name(Kevin A. Ranson) & publisher_name(MovieCrypt.com) & review_type(Fresh) & top_critic(False)
#    291   970     2     1 critic_name(Kevin A. Ranson) & publisher_name(MovieCrypt.com) & top_critic(False)
#    292   707     2     1 critic_name(Kevin A. Ranson) & review_type(Fresh) & top_critic(False)
#    293   859     2     1 critic_name(Kevin Carr) & publisher_name(7M Pictures) & review_type(Fresh)
#    294   859     2     1 critic_name(Kevin Carr) & publisher_name(7M Pictures) & review_type(Fresh) & top_critic(False)
#    295   604     2     1 critic_name(Kevin Carr) & publisher_name(Fat Guys at the Movies) & top_critic(False)
#    296  1290     2     1 critic_name(Kevin Carr) & review_type(Fresh) & top_critic(False)
#    297   731     2     1 critic_name(Kevin N. Laforest) & publisher_name(Montreal Film Journal) & review_type(Fresh)
#    298   731     2     1 critic_name(Kevin N. Laforest) & publisher_name(Montreal Film Journal) & review_type(Fresh) & top_critic(False)
#    299   950     2     1 critic_name(Kevin N. Laforest) & publisher_name(Montreal Film Journal) & top_critic(False)
#    300   734     2     1 critic_name(Kevin N. Laforest) & review_type(Fresh) & top_critic(False)
#    301   626     2     1 critic_name(Kevin Thomas) & publisher_name(Los Angeles Times) & review_type(Fresh)
#    302   626     2     1 critic_name(Kevin Thomas) & publisher_name(Los Angeles Times) & review_type(Fresh) & top_critic(True)
#    303   840     2     1 critic_name(Kevin Thomas) & publisher_name(Los Angeles Times) & top_critic(True)
#    304   627     2     1 critic_name(Kevin Thomas) & review_type(Fresh) & top_critic(True)
#    305   500     2     1 critic_name(Kim Newman) & publisher_name(Empire Magazine) & review_type(Fresh)
#    306   500     2     1 critic_name(Kim Newman) & publisher_name(Empire Magazine) & review_type(Fresh) & top_critic(False)
#    307   635     2     1 critic_name(Kim Newman) & publisher_name(Empire Magazine) & top_critic(False)
#    308   501     2     1 critic_name(Kim Newman) & review_type(Fresh) & top_critic(False)
#    309   604     2     1 critic_name(Kyle Smith) & publisher_name(New York Post) & review_type(Fresh)
#    310   604     2     1 critic_name(Kyle Smith) & publisher_name(New York Post) & review_type(Fresh) & top_critic(True)
#    311   604     2     1 critic_name(Kyle Smith) & review_type(Fresh) & top_critic(True)
#    312   505     2     1 critic_name(Larry Ratliff) & publisher_name(San Antonio Express-News) & top_critic(False)
#    313   595     2     1 critic_name(Lawrence Toppman) & publisher_name(Charlotte Observer) & review_type(Fresh)
#    314   595     2     1 critic_name(Lawrence Toppman) & publisher_name(Charlotte Observer) & review_type(Fresh) & top_critic(False)
#    315  1040     2     1 critic_name(Lawrence Toppman) & publisher_name(Charlotte Observer) & top_critic(False)
#    316   595     2     1 critic_name(Lawrence Toppman) & review_type(Fresh) & top_critic(False)
#    317  1226     2     1 critic_name(Leigh Paatsch) & publisher_name(Herald Sun (Australia)) & review_type(Fresh)
#    318  1226     2     1 critic_name(Leigh Paatsch) & publisher_name(Herald Sun (Australia)) & review_type(Fresh) & top_critic(False)
#    319  1247     2     1 critic_name(Leigh Paatsch) & review_type(Fresh) & top_critic(False)
#    320   620     2     1 critic_name(Liam Lacey) & publisher_name(Globe and Mail) & review_type(Fresh)
#    321   620     2     1 critic_name(Liam Lacey) & publisher_name(Globe and Mail) & review_type(Fresh) & top_critic(True)
#    322   620     2     1 critic_name(Liam Lacey) & review_type(Fresh) & top_critic(True)
#    323  1674     2     1 critic_name(Linda Cook) & publisher_name(Quad City Times (Davenport, IA)) & review_type(Fresh)
#    324  1674     2     1 critic_name(Linda Cook) & publisher_name(Quad City Times (Davenport, IA)) & review_type(Fresh) & top_critic(False)
#    325  2452     2     1 critic_name(Linda Cook) & publisher_name(Quad City Times (Davenport, IA)) & top_critic(False)
#    326  1877     2     1 critic_name(Linda Cook) & review_type(Fresh) & top_critic(False)
#    327   869     2     1 critic_name(Lisa Kennedy) & publisher_name(Denver Post) & review_type(Fresh)
#    328   869     2     1 critic_name(Lisa Kennedy) & publisher_name(Denver Post) & review_type(Fresh) & top_critic(True)
#    329  1157     2     1 critic_name(Lisa Kennedy) & publisher_name(Denver Post) & top_critic(True)
#    330   869     2     1 critic_name(Lisa Kennedy) & review_type(Fresh) & top_critic(True)
#    331   797     2     1 critic_name(Liz Braun) & publisher_name(Jam! Movies) & review_type(Fresh)
#    332   797     2     1 critic_name(Liz Braun) & publisher_name(Jam! Movies) & review_type(Fresh) & top_critic(False)
#    333  1165     2     2 critic_name(Liz Braun) & publisher_name(Jam! Movies) & top_critic(False)
#    334   797     2     1 critic_name(Liz Braun) & review_type(Fresh) & top_critic(False)
#    335   785     2     1 critic_name(Lori Hoffman) & publisher_name(Atlantic City Weekly) & review_type(Fresh)
#    336   785     2     1 critic_name(Lori Hoffman) & publisher_name(Atlantic City Weekly) & review_type(Fresh) & top_critic(False)
#    337   785     2     1 critic_name(Lori Hoffman) & review_type(Fresh) & top_critic(False)
#    338  1043     2     1 critic_name(Lou Lumenick) & publisher_name(New York Post) & review_type(Fresh)
#    339  1043     2     1 critic_name(Lou Lumenick) & publisher_name(New York Post) & review_type(Fresh) & top_critic(True)
#    340  2141     2     2 critic_name(Lou Lumenick) & publisher_name(New York Post) & top_critic(True)
#    341  1043     2     1 critic_name(Lou Lumenick) & review_type(Fresh) & top_critic(True)
#    342   820     2     1 critic_name(Maitland McDonagh) & publisher_name(TV Guide) & review_type(Fresh)
#    343   820     2     1 critic_name(Maitland McDonagh) & publisher_name(TV Guide) & review_type(Fresh) & top_critic(False)
#    344   827     2     1 critic_name(Maitland McDonagh) & review_type(Fresh) & top_critic(False)
#    345   534     2     1 critic_name(Manohla Dargis) & publisher_name(New York Times) & review_type(Fresh)
#    346   534     2     1 critic_name(Manohla Dargis) & publisher_name(New York Times) & review_type(Fresh) & top_critic(True)
#    347   614     2     1 critic_name(Manohla Dargis) & review_type(Fresh) & top_critic(True)
#    348  1170     2     1 critic_name(Marc Savlov) & publisher_name(Austin Chronicle) & review_type(Fresh)
#    349  1170     2     1 critic_name(Marc Savlov) & publisher_name(Austin Chronicle) & review_type(Fresh) & top_critic(False)
#    350  1173     2     1 critic_name(Marc Savlov) & review_type(Fresh) & top_critic(False)
#    351   513     2     1 critic_name(Margaret A. McGurk) & publisher_name(Cincinnati Enquirer) & top_critic(False)
#    352   533     2     1 critic_name(Margaret Pomeranz) & publisher_name(At the Movies (Australia)) & top_critic(False)
#    353   558     2     1 critic_name(Mark Kermode) & publisher_name(Observer (UK)) & review_type(Fresh)
#    354   558     2     1 critic_name(Mark Kermode) & publisher_name(Observer (UK)) & review_type(Fresh) & top_critic(False)
#    355   558     2     1 critic_name(Mark Kermode) & review_type(Fresh) & top_critic(False)
#    356   569     2     1 critic_name(Mark R. Leeper) & publisher_name(rec.arts.movies.reviews) & review_type(Fresh)
#    357   569     2     1 critic_name(Mark R. Leeper) & publisher_name(rec.arts.movies.reviews) & review_type(Fresh) & top_critic(False)
#    358   721     2     1 critic_name(Mark R. Leeper) & publisher_name(rec.arts.movies.reviews) & top_critic(False)
#    359   874     2     1 critic_name(Mark R. Leeper) & review_type(Fresh) & top_critic(False)
#    360   811     2     1 critic_name(Marty Mapes) & publisher_name(Movie Habit) & review_type(Fresh)
#    361   811     2     1 critic_name(Marty Mapes) & publisher_name(Movie Habit) & review_type(Fresh) & top_critic(False)
#    362  1119     2     1 critic_name(Marty Mapes) & publisher_name(Movie Habit) & top_critic(False)
#    363   811     2     1 critic_name(Marty Mapes) & review_type(Fresh) & top_critic(False)
#    364   591     2     1 critic_name(MaryAnn Johanson) & publisher_name(Flick Filosopher) & review_type(Fresh)
#    365   591     2     1 critic_name(MaryAnn Johanson) & publisher_name(Flick Filosopher) & review_type(Fresh) & top_critic(False)
#    366   597     2     1 critic_name(MaryAnn Johanson) & review_type(Fresh) & top_critic(False)
#    367  1757     2     1 critic_name(Matt Brunson) & publisher_name(Creative Loafing) & review_type(Fresh)
#    368  1757     2     1 critic_name(Matt Brunson) & publisher_name(Creative Loafing) & review_type(Fresh) & top_critic(False)
#    369  2886     2     1 critic_name(Matt Brunson) & publisher_name(Creative Loafing) & top_critic(False)
#    370   834     2     1 critic_name(Matt Brunson) & publisher_name(Film Frenzy) & top_critic(False)
#    371  2250     2     1 critic_name(Matt Brunson) & review_type(Fresh) & top_critic(False)
#    372   513     2     1 critic_name(Matt Donato) & publisher_name(We Got This Covered) & review_type(Fresh)
#    373   513     2     1 critic_name(Matt Donato) & publisher_name(We Got This Covered) & review_type(Fresh) & top_critic(False)
#    374   614     2     1 critic_name(Matt Donato) & review_type(Fresh) & top_critic(False)
#    375   562     2     1 critic_name(Matt Pais) & publisher_name(RedEye) & review_type(Fresh)
#    376   562     2     1 critic_name(Matt Pais) & publisher_name(RedEye) & review_type(Fresh) & top_critic(False)
#    377  1026     2     1 critic_name(Matt Pais) & review_type(Fresh) & top_critic(False)
#    378   561     2     1 critic_name(Matthew Lucas) & publisher_name(From the Front Row) & review_type(Fresh)
#    379   561     2     1 critic_name(Matthew Lucas) & publisher_name(From the Front Row) & review_type(Fresh) & top_critic(False)
#    380   703     2     1 critic_name(Matthew Lucas) & publisher_name(From the Front Row) & top_critic(False)
#    381   502     2     1 critic_name(Matthew Lucas) & publisher_name(The Dispatch (Lexington, NC)) & review_type(Fresh)
#    382   502     2     1 critic_name(Matthew Lucas) & publisher_name(The Dispatch (Lexington, NC)) & review_type(Fresh) & top_critic(False)
#    383   691     2     1 critic_name(Matthew Lucas) & publisher_name(The Dispatch (Lexington, NC)) & top_critic(False)
#    384  1063     2     1 critic_name(Matthew Lucas) & review_type(Fresh) & top_critic(False)
#    385   773     2     1 critic_name(Matthew Pejkovic) & publisher_name(Matt's Movie Reviews) & review_type(Fresh)
#    386   773     2     1 critic_name(Matthew Pejkovic) & publisher_name(Matt's Movie Reviews) & review_type(Fresh) & top_critic(False)
#    387   979     2     1 critic_name(Matthew Pejkovic) & publisher_name(Matt's Movie Reviews) & top_critic(False)
#    388   773     2     1 critic_name(Matthew Pejkovic) & review_type(Fresh) & top_critic(False)
#    389  2418     2     1 critic_name(Matthew Turner) & publisher_name(ViewLondon) & review_type(Fresh)
#    390  2418     2     1 critic_name(Matthew Turner) & publisher_name(ViewLondon) & review_type(Fresh) & top_critic(False)
#    391  3203     2     1 critic_name(Matthew Turner) & publisher_name(ViewLondon) & top_critic(False)
#    392  2762     2     1 critic_name(Matthew Turner) & review_type(Fresh) & top_critic(False)
#    393   855     2     1 critic_name(Michael A. Smith) & review_type(Fresh) & top_critic(False)
#    394  1482     2     1 critic_name(Michael Dequina) & publisher_name(TheMovieReport.com) & review_type(Fresh)
#    395  1482     2     1 critic_name(Michael Dequina) & publisher_name(TheMovieReport.com) & review_type(Fresh) & top_critic(False)
#    396  2793     2     2 critic_name(Michael Dequina) & publisher_name(TheMovieReport.com) & top_critic(False)
#    397  1532     2     1 critic_name(Michael Dequina) & review_type(Fresh) & top_critic(False)
#    398   529     2     1 critic_name(Michael O'Sullivan) & publisher_name(Washington Post) & review_type(Fresh)
#    399   529     2     1 critic_name(Michael O'Sullivan) & publisher_name(Washington Post) & review_type(Fresh) & top_critic(True)
#    400   529     2     1 critic_name(Michael O'Sullivan) & review_type(Fresh) & top_critic(True)
#    401  1399     2     1 critic_name(Michael Phillips) & publisher_name(Chicago Tribune) & review_type(Fresh)
#    402  1399     2     1 critic_name(Michael Phillips) & publisher_name(Chicago Tribune) & review_type(Fresh) & top_critic(True)
#    403  2275     2     1 critic_name(Michael Phillips) & publisher_name(Chicago Tribune) & top_critic(True)
#    404  1399     2     1 critic_name(Michael Phillips) & review_type(Fresh) & top_critic(True)
#    405   572     2     1 critic_name(Michael Smith) & publisher_name(Tulsa World) & top_critic(False)
#    406   672     2     2 critic_name(Michael Szymanski) & publisher_name(Zap2it.com) & top_critic(False)
#    407   573     2     1 critic_name(Michael Szymanski) & review_type(Fresh) & top_critic(False)
#    408   639     2     1 critic_name(Michael W. Phillips, Jr.) & publisher_name(Goatdog's Movies) & review_type(Fresh)
#    409   639     2     1 critic_name(Michael W. Phillips, Jr.) & publisher_name(Goatdog's Movies) & review_type(Fresh) & top_critic(False)
#    410   883     2     1 critic_name(Michael W. Phillips, Jr.) & publisher_name(Goatdog's Movies) & top_critic(False)
#    411   642     2     1 critic_name(Michael W. Phillips, Jr.) & review_type(Fresh) & top_critic(False)
#    412   605     2     1 critic_name(Michael Wilmington) & publisher_name(Chicago Tribune) & review_type(Fresh)
#    413   605     2     1 critic_name(Michael Wilmington) & publisher_name(Chicago Tribune) & review_type(Fresh) & top_critic(True)
#    414   846     2     1 critic_name(Michael Wilmington) & publisher_name(Chicago Tribune) & top_critic(True)
#    415   609     2     1 critic_name(Michael Wilmington) & review_type(Fresh) & top_critic(True)
#    416  1649     2     1 critic_name(Mick LaSalle) & publisher_name(San Francisco Chronicle) & review_type(Fresh)
#    417  1649     2     1 critic_name(Mick LaSalle) & publisher_name(San Francisco Chronicle) & review_type(Fresh) & top_critic(True)
#    418  2871     2     2 critic_name(Mick LaSalle) & publisher_name(San Francisco Chronicle) & top_critic(True)
#    419  1658     2     1 critic_name(Mick LaSalle) & review_type(Fresh) & top_critic(True)
#    420   801     2     1 critic_name(Mike Massie) & publisher_name(Gone With The Twins) & review_type(Fresh)
#    421   801     2     1 critic_name(Mike Massie) & publisher_name(Gone With The Twins) & review_type(Fresh) & top_critic(False)
#    422  1175     2     1 critic_name(Mike Massie) & publisher_name(Gone With The Twins) & top_critic(False)
#    423   801     2     1 critic_name(Mike Massie) & review_type(Fresh) & top_critic(False)
#    424  1828     2     1 critic_name(Mike McGranaghan) & publisher_name(Aisle Seat) & review_type(Fresh)
#    425  1828     2     1 critic_name(Mike McGranaghan) & publisher_name(Aisle Seat) & review_type(Fresh) & top_critic(False)
#    426  2883     2     1 critic_name(Mike McGranaghan) & publisher_name(Aisle Seat) & top_critic(False)
#    427  1861     2     1 critic_name(Mike McGranaghan) & review_type(Fresh) & top_critic(False)
#    428  1604     2     1 critic_name(Moira MacDonald) & publisher_name(Seattle Times) & review_type(Fresh)
#    429  1604     2     1 critic_name(Moira MacDonald) & publisher_name(Seattle Times) & review_type(Fresh) & top_critic(True)
#    430  2338     2     1 critic_name(Moira MacDonald) & publisher_name(Seattle Times) & top_critic(True)
# ...
#    673  1938     2     1 publisher_name(ComingSoon.net) & review_type(Fresh) & top_critic(False)
#    674  1581     2     1 publisher_name(Commercial Appeal (Memphis, TN)) & review_type(Fresh) & top_critic(False)
#    675   711     2     1 publisher_name(Compuserve) & review_type(Fresh) & top_critic(False)
#    676   915     2     1 publisher_name(Contactmusic.com) & review_type(Fresh) & top_critic(False)
#    677   555     2     1 publisher_name(CraveOnline) & review_type(Fresh) & top_critic(False)
#    678  1757     2     1 publisher_name(Creative Loafing) & review_type(Fresh) & top_critic(False)
#    679   973     2     1 publisher_name(Daily Mirror (UK)) & review_type(Fresh) & top_critic(False)
#    680  1232     2     1 publisher_name(Denver Post) & review_type(Fresh) & top_critic(True)
#    681  1530     2     1 publisher_name(Deseret News (Salt Lake City)) & review_type(Fresh) & top_critic(False)
#    682   826     2     1 publisher_name(Detroit Free Press) & review_type(Fresh) & top_critic(True)
#    683   704     2     1 publisher_name(Detroit News) & review_type(Fresh) & top_critic(True)
#    684  1037     2     1 publisher_name(Digital Spy) & review_type(Fresh) & top_critic(False)
#    685   653     2     1 publisher_name(Entertainment Spectrum) & review_type(Fresh) & top_critic(False)
#    686   643     2     1 publisher_name(Examiner.com) & review_type(Fresh) & top_critic(False)
#    687  1489     2     1 publisher_name(Eye for Film) & review_type(Fresh) & top_critic(False)
#    688  1574     2     1 publisher_name(Film Freak Central) & review_type(Fresh) & top_critic(False)
#    689   515     2     1 publisher_name(Film Quips Online) & review_type(Fresh) & top_critic(False)
#    690  4093     2     1 publisher_name(Film Threat) & review_type(Fresh) & top_critic(False)
#    691   863     2     1 publisher_name(Film-Forward.com) & review_type(Fresh) & top_critic(False)
#    692  1106     2     1 publisher_name(Film4) & review_type(Fresh) & top_critic(False)
#    693  3711     2     1 publisher_name(Filmcritic.com) & review_type(Fresh) & top_critic(False)
#    694   591     2     1 publisher_name(Flick Filosopher) & review_type(Fresh) & top_critic(False)
#    695   867     2     1 publisher_name(Flickering Myth) & review_type(Fresh) & top_critic(False)
#    696   561     2     1 publisher_name(From the Front Row) & review_type(Fresh) & top_critic(False)
#    697   533     2     1 publisher_name(Future Movies UK) & review_type(Fresh) & top_critic(False)
#    698  2570     2     1 publisher_name(Globe and Mail) & review_type(Fresh) & top_critic(True)
#    699   639     2     1 publisher_name(Goatdog's Movies) & review_type(Fresh) & top_critic(False)
#    700   801     2     1 publisher_name(Gone With The Twins) & review_type(Fresh) & top_critic(False)
#    701  1460     2     1 publisher_name(Groucho Reviews) & review_type(Fresh) & top_critic(False)
#    702  1228     2     1 publisher_name(Herald Sun (Australia)) & review_type(Fresh) & top_critic(False)
#    703  1324     2     1 publisher_name(HeyUGuys) & review_type(Fresh) & top_critic(False)
#    704  1273     2     1 publisher_name(Hollywood.com) & review_type(Fresh) & top_critic(False)
#    705   695     2     1 publisher_name(Houston Chronicle) & review_type(Fresh) & top_critic(True)
#    706  1670     2     1 publisher_name(IGN Movies) & review_type(Fresh) & top_critic(False)
#    707   548     2     1 publisher_name(IONCINEMA.com) & review_type(Fresh) & top_critic(False)
#    708  1327     2     1 publisher_name(Internet Reviews) & review_type(Fresh) & top_critic(False)
#    709  2371     2     1 publisher_name(Jam! Movies) & review_type(Fresh) & top_critic(False)
#    710  2266     2     1 publisher_name(JoBlo's Movie Network) & review_type(Fresh) & top_critic(False)
#    711  1048     2     1 publisher_name(Journal and Courier (Lafayette, IN)) & review_type(Fresh) & top_critic(False)
#    712   511     2     1 publisher_name(Kalamazoo Gazette) & review_type(Fresh) & top_critic(False)
#    713  1246     2     1 publisher_name(Kansas City Star) & review_type(Fresh) & top_critic(False)
#    714  1076     2     1 publisher_name(Killer Movie Reviews) & review_type(Fresh) & top_critic(False)
#    715   993     2     1 publisher_name(Laramie Movie Scope) & review_type(Fresh) & top_critic(False)
#    716  1053     2     1 publisher_name(LarsenOnFilm) & review_type(Fresh) & top_critic(False)
#    717  1723     2     1 publisher_name(Las Vegas Review-Journal) & review_type(Fresh) & top_critic(False)
#    718   669     2     1 publisher_name(Las Vegas Weekly) & review_type(Fresh) & top_critic(False)
#    719   587     2     1 publisher_name(Lawrence Journal-World) & review_type(Fresh) & top_critic(False)
#    720   933     2     1 publisher_name(Los Angeles Daily News) & review_type(Fresh) & top_critic(False)
#    721  3093     2     1 publisher_name(Los Angeles Times) & review_type(Fresh) & top_critic(True)
#    722   514     2     1 publisher_name(Lyles' Movie Files) & review_type(Fresh) & top_critic(False)
#    723  1112     2     1 publisher_name(Matt's Movie Reviews) & review_type(Fresh) & top_critic(False)
#    724   849     2     1 publisher_name(Metromix.com) & review_type(Fresh) & top_critic(False)
#    725  1483     2     1 publisher_name(Miami Herald) & review_type(Fresh) & top_critic(True)
#    726  1575     2     1 publisher_name(Milwaukee Journal Sentinel) & review_type(Fresh) & top_critic(False)
#    727   548     2     1 publisher_name(Minneapolis Star Tribune) & review_type(Fresh) & top_critic(True)
#    728   523     2     1 publisher_name(Monsters and Critics) & review_type(Fresh) & top_critic(False)
#    729   731     2     1 publisher_name(Montreal Film Journal) & review_type(Fresh) & top_critic(False)
#    730  2953     2     1 publisher_name(Mountain Xpress (Asheville, NC)) & review_type(Fresh) & top_critic(False)
#    731   811     2     1 publisher_name(Movie Habit) & review_type(Fresh) & top_critic(False)
#    732  1582     2     1 publisher_name(Movie Metropolis) & review_type(Fresh) & top_critic(False)
#    733  1086     2     1 publisher_name(Movie Mom) & review_type(Fresh) & top_critic(False)
#    734   707     2     1 publisher_name(MovieCrypt.com) & review_type(Fresh) & top_critic(False)
#    735  1519     2     1 publisher_name(MovieFreak.com) & review_type(Fresh) & top_critic(False)
#    736   565     2     1 publisher_name(MovieWeb) & review_type(Fresh) & top_critic(False)
#    737   879     2     1 publisher_name(Movies.com) & review_type(Fresh) & top_critic(False)
#    738   808     2     1 publisher_name(NYC Movie Guru) & review_type(Fresh) & top_critic(False)
#    739  1240     2     1 publisher_name(National Post) & review_type(Fresh) & top_critic(False)
#    740   591     2     1 publisher_name(Needcoffee.com) & review_type(Fresh) & top_critic(False)
#    741   794     2     1 publisher_name(Netflix) & review_type(Fresh) & top_critic(False)
#    742  2636     2     1 publisher_name(New York Daily News) & review_type(Fresh) & top_critic(True)
#    743  3030     2     1 publisher_name(New York Post) & review_type(Fresh) & top_critic(True)
#    744  4285     2     1 publisher_name(New York Times) & review_type(Fresh) & top_critic(True)
#    745   689     2     1 publisher_name(New Zealand Herald) & review_type(Fresh) & top_critic(False)
#    746  1193     2     1 publisher_name(Newark Star-Ledger) & review_type(Fresh) & top_critic(True)
#    747  1917     2     1 publisher_name(Newsday) & review_type(Fresh) & top_critic(True)
#    748   610     2     1 publisher_name(North Shore Movies) & review_type(Fresh) & top_critic(False)
#    749  1594     2     1 publisher_name(Northwest Herald (Crystal Lake, IL)) & review_type(Fresh) & top_critic(False)
#    750   544     2     1 publisher_name(Observer) & review_type(Fresh) & top_critic(True)
#    751  1053     2     1 publisher_name(Observer (UK)) & review_type(Fresh) & top_critic(False)
#    752   914     2     1 publisher_name(One Room With A View) & review_type(Fresh) & top_critic(False)
#    753  1262     2     1 publisher_name(Orlando Sentinel) & review_type(Fresh) & top_critic(True)
#    754   836     2     1 publisher_name(Orlando Weekly) & review_type(Fresh) & top_critic(False)
#    755  1445     2     1 publisher_name(Palo Alto Weekly) & review_type(Fresh) & top_critic(False)
#    756  1279     2     1 publisher_name(Paste Magazine) & review_type(Fresh) & top_critic(False)
#    757  2619     2     1 publisher_name(Philadelphia Inquirer) & review_type(Fresh) & top_critic(True)
#    758  1325     2     1 publisher_name(PopMatters) & review_type(Fresh) & top_critic(False)
#    759   580     2     1 publisher_name(Punch Drunk Critics) & review_type(Fresh) & top_critic(False)
#    760  1759     2     1 publisher_name(Q Network Film Desk) & review_type(Fresh) & top_critic(False)
#    761  1674     2     1 publisher_name(Quad City Times (Davenport, IA)) & review_type(Fresh) & top_critic(False)
#    762   672     2     1 publisher_name(Quickflix) & review_type(Fresh) & top_critic(False)
#    763   709     2     1 publisher_name(RTÉ (Ireland)) & review_type(Fresh) & top_critic(False)
#    764   612     2     1 publisher_name(RedEye) & review_type(Fresh) & top_critic(False)
#    765  2677     2     1 publisher_name(Reel Film Reviews) & review_type(Fresh) & top_critic(False)
#    766  1536     2     1 publisher_name(Reel.com) & review_type(Fresh) & top_critic(False)
#    767  2679     2     1 publisher_name(ReelViews) & review_type(Fresh) & top_critic(True)
#    768  1184     2     1 publisher_name(Rochester Democrat and Chronicle) & review_type(Fresh) & top_critic(False)
#    769  1701     2     1 publisher_name(RogerEbert.com) & review_type(Fresh) & top_critic(True)
#    770  2137     2     1 publisher_name(Rolling Stone) & review_type(Fresh) & top_critic(True)
#    771  1141     2     1 publisher_name(SPLICEDWire) & review_type(Fresh) & top_critic(False)
#    772  1245     2     1 publisher_name(SSG Syndicate) & review_type(Fresh) & top_critic(False)
#    773   772     2     1 publisher_name(Sacramento Bee) & review_type(Fresh) & top_critic(False)
#    774  1391     2     1 publisher_name(Salt Lake Tribune) & review_type(Fresh) & top_critic(False)
#    775   915     2     1 publisher_name(San Diego Union-Tribune) & review_type(Fresh) & top_critic(False)
#    776  3899     2     1 publisher_name(San Francisco Chronicle) & review_type(Fresh) & top_critic(True)
#    777   888     2     1 publisher_name(San Francisco Examiner) & review_type(Fresh) & top_critic(False)
#    778   681     2     1 publisher_name(San Jose Mercury News) & review_type(Fresh) & top_critic(True)
#    779   592     2     1 publisher_name(Scene-Stealers.com) & review_type(Fresh) & top_critic(False)
#    780   608     2     1 publisher_name(Schmoes Know) & review_type(Fresh) & top_critic(False)
#    781  1076     2     1 publisher_name(Screen Rant) & review_type(Fresh) & top_critic(False)
#    782  3223     2     1 publisher_name(Seattle Times) & review_type(Fresh) & top_critic(True)
#    783  2845     2     1 publisher_name(Shadows on the Wall) & review_type(Fresh) & top_critic(False)
#    784  3136     2     1 publisher_name(Slant Magazine) & review_type(Fresh) & top_critic(False)
#    785   510     2     1 publisher_name(South China Morning Post) & review_type(Fresh) & top_critic(False)
#    786   545     2     1 publisher_name(South Florida Sun-Sentinel) & review_type(Fresh) & top_critic(False)
#    787  2523     2     1 publisher_name(Spirituality & Practice) & review_type(Fresh) & top_critic(False)
#    788  1086     2     1 publisher_name(St. Louis Post-Dispatch) & review_type(Fresh) & top_critic(True)
#    789  2233     2     1 publisher_name(St. Paul Pioneer Press) & review_type(Fresh) & top_critic(False)
#    790   755     2     1 publisher_name(Starburst) & review_type(Fresh) & top_critic(False)
#    791  1115     2     1 publisher_name(Sydney Morning Herald) & review_type(Fresh) & top_critic(True)
#    792  3967     2     1 publisher_name(TV Guide) & review_type(Fresh) & top_critic(False)
#    793   676     2     1 publisher_name(The Age (Australia)) & review_type(Fresh) & top_critic(True)
#    794   601     2     1 publisher_name(The Arts Desk) & review_type(Fresh) & top_critic(False)
#    795   741     2     1 publisher_name(The Australian) & review_type(Fresh) & top_critic(False)
#    796   502     2     1 publisher_name(The Dispatch (Lexington, NC)) & review_type(Fresh) & top_critic(False)
#    797   795     2     1 publisher_name(The Dissolve) & review_type(Fresh) & top_critic(False)
#    798   668     2     1 publisher_name(The Film Yap) & review_type(Fresh) & top_critic(False)
#    799  1782     2     1 publisher_name(The List) & review_type(Fresh) & top_critic(False)
#    800   523     2     1 publisher_name(The Mail on Sunday (UK)) & review_type(Fresh) & top_critic(False)
#    801   758     2     1 publisher_name(The Skinny) & review_type(Fresh) & top_critic(False)
#    802   559     2     1 publisher_name(The Times of India) & review_type(Fresh) & top_critic(False)
#    803   767     2     1 publisher_name(The Young Folks) & review_type(Fresh) & top_critic(False)
#    804  1716     2     1 publisher_name(TheFilmFile.com) & review_type(Fresh) & top_critic(False)
#    805  1422     2     1 publisher_name(TheIndependentCritic.com) & review_type(Fresh) & top_critic(False)
#    806  1482     2     1 publisher_name(TheMovieReport.com) & review_type(Fresh) & top_critic(False)
#    807   855     2     1 publisher_name(Three Movie Buffs) & review_type(Fresh) & top_critic(False)
#    808  1645     2     1 publisher_name(Times (UK)) & review_type(Fresh) & top_critic(True)
#    809   516     2     1 publisher_name(Tolucan Times) & review_type(Fresh) & top_critic(False)
#    810  2704     2     1 publisher_name(Toronto Star) & review_type(Fresh) & top_critic(True)
#    811  2804     2     1 publisher_name(Total Film) & review_type(Fresh) & top_critic(False)
#    812   605     2     1 publisher_name(Tri-City Herald) & review_type(Fresh) & top_critic(False)
#    813   810     2     1 publisher_name(Tribune News Service) & review_type(Fresh) & top_critic(False)
#    814   513     2     1 publisher_name(Tulsa World) & review_type(Fresh) & top_critic(False)
#    815  1983     2     1 publisher_name(USA Today) & review_type(Fresh) & top_critic(True)
#    816   503     2     1 publisher_name(Video-Reviewmaster.com) & review_type(Fresh) & top_critic(False)
#    817  2552     2     1 publisher_name(ViewLondon) & review_type(Fresh) & top_critic(False)
#    818   935     2     1 publisher_name(WaffleMovies.com) & review_type(Fresh) & top_critic(False)
#    819  1996     2     1 publisher_name(Washington Post) & review_type(Fresh) & top_critic(True)
#    820  1435     2     1 publisher_name(We Got This Covered) & review_type(Fresh) & top_critic(False)
#    821   623     2     1 publisher_name(Window to the Movies) & review_type(Fresh) & top_critic(False)
#    822  1148     2     1 publisher_name(Worcester Telegram & Gazette) & review_type(Fresh) & top_critic(False)
#    823   641     2     1 publisher_name(Your Movies (cleveland.com)) & review_type(Fresh) & top_critic(False)
#    824   576     2     1 publisher_name(Zap2it.com) & review_type(Fresh) & top_critic(False)
#    825  5543     2     1 publisher_name(eFilmCritic.com) & review_type(Fresh) & top_critic(False)
#    826   704     2     1 publisher_name(jackiekcooper.com) & review_type(Fresh) & top_critic(False)
#    827  2341     2     1 publisher_name(rec.arts.movies.reviews) & review_type(Fresh) & top_critic(False)
#    828   630     2     1 publisher_name(www.susangranger.com) & review_type(Fresh) & top_critic(False)
#
#
#
# Rule id : 2
#
# Base :   867  Relative base : 0.001  Steps UP (consecutive) :     2  Steps DOWN (consecutive) :     1  Steps UP (any) :     3  Steps DOWN (any) :     1  Histogram maximum :   502  Histogram minimum :     0  Histogram relative maximum : 0.579 Histogram relative minimum : 0.000
#
# Condition  : critic_name(A.O. Scott) & publisher_name(New York Times) & review_type(Fresh) & top_critic(True)
#
# Histogram [1, 234, 502, 0, 130]

# %% [markdown]
# ## Otazka 7 - neni nic moc :D

# %%
df = data
df=df.loc[:, ('critic_name','top_critic', 'review_score_interval')]



clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.7, 'Base': 100},
               ante ={
                    'attributes':[
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'critic_name', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':2, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 1525, rules 3,control number:0, times: prep 8.988273859024048, processing 1.9136362075805664
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 1525
# Number of rules : 3
# Total time needed : 00h 00m 10s
# Time of data preparation : 00h 00m 08s
# Time of rule mining : 00h 00m 01s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1   120 0.779 +1.131 top_critic(False) & critic_name(Alan Ng) => review_score_interval(70-90) | ---
#      2   160 0.711 +0.944 top_critic(False) & critic_name(Anita Katz) => review_score_interval(70-90) | ---
#      3   153 0.805 +1.202 top_critic(False) & critic_name(Piers Marchant) => review_score_interval(70-90) | ---
#
#
#
# Rule id : 2
#
# Base :   160  Relative base : 0.000  CONF : 0.711  AAD : +0.944  BAD : -0.944
#
# Cedents:
#   antecedent : top_critic(False) & critic_name(Anita Katz)
#   succcedent : review_score_interval(70-90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |  160|   65|
# ----|-----|-----|
# ¬A  |245024|425162|
# ----|-----|-----|

# %% [markdown]
# ## Otazka 3

# %%
# bezi cca 2m 24s

df = data
df=df.loc[:, ('release_decade_interval', 'review_score_interval', 'genres', 'production_company')]



clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.6, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'genres', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'release_decade_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':3, 'maxlen':3, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 2969, rules 278,control number:0, times: prep 5.856578826904297, processing 35.73852205276489
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 2969
# Number of rules : 278
# Total time needed : 00h 00m 41s
# Time of data preparation : 00h 00m 05s
# Time of rule mining : 00h 00m 35s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1    78 0.634 +0.734 production_company(20th Century Fox) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      2    55 0.655 +0.790 production_company(20th Century Fox) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      3    83 0.659 +0.801 production_company(20th Century Fox) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      4    82 0.774 +7.189 production_company(20th Century Fox) & genres(['Action & Adventure', 'Drama', 'Science Fiction & Fantasy']) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#      5   176 0.642 +0.756 production_company(20th Century Fox) & genres(['Animation', 'Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      6    56 0.615 +0.683 production_company(20th Century Fox) & genres(['Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      7    90 0.652 +0.783 production_company(20th Century Fox) & genres(['Comedy', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      8   134 0.663 +0.814 production_company(20th Century Fox) & genres(['Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      9    67 0.670 +0.832 production_company(A24) & genres(['Comedy', 'Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     10    86 0.729 +0.993 production_company(A24) & genres(['Comedy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     11    92 0.605 +0.655 production_company(A24) & genres(['Drama', 'Horror']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     12    83 0.624 +0.706 production_company(A24 Films) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     13    61 0.642 +0.756 production_company(A24 Films) & genres(['Comedy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     14    83 0.610 +0.669 production_company(A24 Films) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     15   130 0.812 +1.222 production_company(A24 and DIRECTV) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     16    61 0.670 +0.833 production_company(Abramorama) & genres(['Documentary', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     17    52 0.612 +0.673 production_company(Adopt Films) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     18   108 0.639 +0.747 production_company(Amazon Studios) & genres(['Comedy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     19   104 0.623 +0.703 production_company(Annapurna Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     20    55 0.611 +0.671 production_company(Anonymous Content) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     21    61 0.616 +0.685 production_company(Artisan Entertainment) & genres(['Action & Adventure', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     22   134 0.632 +0.728 production_company(Artisan Entertainment) & genres(['Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     23    80 0.702 +0.919 production_company(Artisan Entertainment) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     24    64 0.711 +0.944 production_company(Artisan Entertainment) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     25    87 0.617 +0.687 production_company(BBC Films) & genres(['Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     26   128 0.707 +0.934 production_company(Bad Robot Productions) & genres(['Drama', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     27   108 0.688 +0.881 production_company(Big Beach Films) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     28    68 0.602 +0.645 production_company(Blumhouse Productions) & genres(['Action & Adventure', 'Horror', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     29    67 0.620 +0.900 production_company(Broad Green Pictures) & genres(['Action & Adventure', 'Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#     30    63 0.724 +0.980 production_company(Broad Green Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     31    61 0.635 +0.737 production_company(Buena Vista Pictures) & genres(['Action & Adventure', 'Comedy', 'Kids & Family', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     32    87 0.613 +0.675 production_company(Buena Vista Pictures) & genres(['Action & Adventure', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     33    57 0.640 +5.780 production_company(Buena Vista Pictures) & genres(['Animation', 'Comedy', 'Kids & Family']) & release_decade_interval(1990's) => review_score_interval(>90) | ---
#     34    54 0.675 +0.846 production_company(CG Cinéma) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     35    74 0.627 +0.715 production_company(Castle Rock Entertainment) & genres(['Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     36    67 0.615 +0.681 production_company(Cinema Guild) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     37    54 0.635 +0.946 production_company(Columbia Pictures) & genres(['Action & Adventure', 'Animation']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#     38    80 0.870 +8.205 production_company(Columbia Pictures) & genres(['Action & Adventure', 'Art House & International', 'Classics', 'Drama']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     39    79 0.669 +8.618 production_company(Columbia Pictures) & genres(['Action & Adventure', 'Comedy', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#     40    52 0.765 +9.986 production_company(Columbia Pictures) & genres(['Comedy', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#     41    50 0.633 +5.700 production_company(Columbia Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#     42   125 0.625 +0.709 production_company(Disney/Pixar) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#     43   145 0.636 +0.739 production_company(Disney/Pixar) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     44    66 0.629 +0.719 production_company(Disney/Pixar) & genres(['Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     45   108 0.643 +0.969 production_company(DreamWorks SKG) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Romance']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#     46    82 0.641 +0.752 production_company(DreamWorks SKG) & genres(['Action & Adventure', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     47    76 0.628 +0.717 production_company(DreamWorks/Paramount Distribution) & genres(['Comedy', 'Documentary', 'Science Fiction & Fantasy', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     48   100 0.629 +0.720 production_company(DreamWorks/Paramount Studios) & genres(['Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     49    73 0.619 +0.692 production_company(Dreamworks) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     50    88 0.620 +5.560 production_company(Dreamworks Distribution) & genres(['Action & Adventure', 'Drama']) & release_decade_interval(1990's) => review_score_interval(>90) | ---
#     51   113 0.604 +0.652 production_company(Dreamworks Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     52    90 0.608 +0.663 production_company(Dreamworks/Paramount) & genres(['Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     53    66 0.606 +0.656 production_company(EuropaCorp / STXfilms) & genres(['Comedy', 'Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     54   105 0.625 +0.709 production_company(Film 44) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     55   120 0.600 +0.641 production_company(Film District) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     56   188 0.635 +0.737 production_company(Film Movement) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     57    57 0.648 +0.984 production_company(Film4) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#     58   108 0.675 +0.846 production_company(FilmRise) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     59   115 0.697 +0.906 production_company(Fingerprint Releasing / Bleecker Street) & genres(['Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     60   102 0.729 +0.992 production_company(Fireworks Pictures) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     61    73 0.670 +0.831 production_company(Focus Features) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     62    70 0.625 +0.709 production_company(Focus Features) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     63   107 0.622 +0.701 production_company(Focus Features) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     64    81 0.604 +0.653 production_company(Focus Features) & genres(['Action & Adventure', 'Animation', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     65   186 0.715 +0.956 production_company(Focus Features) & genres(['Action & Adventure', 'Comedy', 'Horror', 'Science Fiction & Fantasy', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     66    66 0.667 +0.823 production_company(Focus Features) & genres(['Art House & International', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     67   114 0.659 +0.802 production_company(Focus Features) & genres(['Comedy', 'Drama', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     68    94 0.606 +0.658 production_company(Focus Features) & genres(['Drama', 'Gay & Lesbian']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     69    56 0.602 +0.646 production_company(Focus Features) & genres(['Drama', 'Musical & Performing Arts', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     70    58 0.604 +0.652 production_company(Focus Features) & genres(['Drama']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#     71    65 0.602 +0.646 production_company(Fox Searchlight) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     72    69 0.633 +0.731 production_company(Fox Searchlight) & genres(['Drama', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     73    77 0.636 +0.740 production_company(Fox Searchlight) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     74    96 0.662 +0.810 production_company(Fox Searchlight Pictures) & genres(['Drama', 'Musical & Performing Arts', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     75    68 0.607 +0.660 production_company(Fox Searchlight Pictures) & genres(['Drama', 'Mystery & Suspense', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     76   234 0.636 +0.739 production_company(Fox Searchlight Pictures) & genres(['Horror', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     77   107 0.748 +1.046 production_company(Fox Searchlight Pictures) & genres(['Horror', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     78    65 0.631 +0.726 production_company(Freestyle Releasing) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     79    72 0.655 +0.790 production_company(GKIDS) & genres(['Animation', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     80   130 0.610 +0.669 production_company(Greenwich Entertainment) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     81    61 0.678 +0.853 production_company(Gunpowder & Sky) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     82    72 0.632 +0.727 production_company(HBO Films) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     83    55 0.611 +0.671 production_company(Hurricane Films) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     84    79 0.669 +0.831 production_company(IFC) & genres(['Art House & International', 'Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     85    99 0.678 +0.854 production_company(IFC) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     86    82 0.745 +1.038 production_company(IFC Films) & genres(['Art House & International', 'Drama', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     87    84 0.667 +0.823 production_company(IFC Films) & genres(['Art House & International', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     88    75 0.620 +0.695 production_company(IFC Films) & genres(['Comedy']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#     89   108 0.730 +0.995 production_company(IFC Films) & genres(['Documentary', 'Horror', 'Television']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     90   113 0.720 +0.968 production_company(IFC Films) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     91    79 0.622 +0.701 production_company(IFC Films) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     92   331 0.604 +0.652 production_company(IFC Films) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     93   140 0.625 +0.709 production_company(IFC Films) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     94   120 0.659 +0.803 production_company(IFC Films) & genres(['Drama', 'Horror']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#     95    90 0.652 +0.783 production_company(IFC Midnight) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     96   296 0.655 +0.791 production_company(IMAX) & genres(['Action & Adventure', 'Drama', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     97   102 0.630 +0.722 production_company(Independent Pictures) & genres(['Documentary', 'Sports & Fitness']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     98    68 0.872 +8.229 production_company(Janus Films) & genres(['Action & Adventure', 'Art House & International', 'Classics', 'Drama', 'Science Fiction & Fantasy']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     99    60 0.769 +7.143 production_company(Janus Films) & genres(['Art House & International', 'Classics', 'Drama', 'Mystery & Suspense']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#    100    71 0.651 +0.781 production_company(Janus Films) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    101    64 0.640 +0.960 production_company(Keep Your Head) & genres(['Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    102    82 0.701 +0.916 production_company(Kino International) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    103    50 0.617 +0.688 production_company(Kissiki Film) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    104   174 0.696 +0.903 production_company(Likely Story) & genres(['Art House & International', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    105   128 0.640 +0.750 production_company(Lions Gate) & genres(['Art House & International', 'Comedy', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    106    82 0.683 +0.868 production_company(Lions Gate Films) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    107   138 0.690 +0.887 production_company(Lions Gate Films Inc.) & genres(['Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    108    54 0.643 +0.758 production_company(Lions Gate Releasing) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    109   125 0.665 +8.552 production_company(Lionsgate) & genres(['Action & Adventure', 'Horror']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#    110   158 0.775 +1.118 production_company(Lionsgate) & genres(['Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    111    51 0.911 +12.084 production_company(Lionsgate) & genres(['Comedy']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#    112   134 0.657 +0.796 production_company(Lionsgate) & genres(['Drama', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    113    94 0.676 +0.849 production_company(Lionsgate Films) & genres(['Action & Adventure', 'Drama', 'Western']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    114    53 0.602 +0.845 production_company(Lionsgate Films) & genres(['Drama', 'Horror', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    115   138 0.611 +0.670 production_company(Lionsgate and Roadside Attractions) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    116    85 0.739 +1.021 production_company(Lionsgate/Roadside Attractions) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    117    58 0.667 +0.823 production_company(MGM/Sidney Kimmel Entertainment) & genres(['Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    118   102 0.630 +8.046 production_company(MGM/UA Distribution Company) & genres(['Action & Adventure', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#    119    74 0.679 +0.856 production_company(MTV Films) & genres(['Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    120    75 0.620 +0.695 production_company(Magnet/Magnolia Pictures) & genres(['Art House & International', 'Drama', 'Horror']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    121    67 0.698 +0.908 production_company(Magnolia Pictures) & genres(['Action & Adventure', 'Art House & International', 'Comedy', 'Drama', 'Horror']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    122    79 0.658 +0.800 production_company(Magnolia Pictures) & genres(['Action & Adventure', 'Art House & International', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    123    57 0.770 +1.106 production_company(Magnolia Pictures) & genres(['Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    124    72 0.615 +0.683 production_company(Magnolia Pictures) & genres(['Documentary', 'Special Interest', 'Television']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    125   257 0.618 +0.689 production_company(Magnolia Pictures) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    126    53 0.609 +0.666 production_company(Magnolia Pictures) & genres(['Drama', 'Mystery & Suspense', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    127    58 0.617 +0.890 production_company(Miramax) & genres(['Action & Adventure', 'Animation', 'Musical & Performing Arts', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    128    69 0.600 +0.641 production_company(Miramax) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    129    60 0.612 +0.674 production_company(Miramax Films) & genres(['Action & Adventure', 'Animation', 'Drama', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(1990's) => review_score_interval(70-90) | ---
#    130   114 0.655 +5.935 production_company(Miramax Films) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(>90) | ---
#    131    65 0.747 +1.043 production_company(Miramax Films) & genres(['Art House & International', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    132    54 0.659 +0.801 production_company(Miramax Films) & genres(['Comedy', 'Romance']) & release_decade_interval(1990's) => review_score_interval(70-90) | ---
#    133   114 0.640 +0.751 production_company(Miramax and Roadside Attractions) & genres(['Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    134    68 0.694 +0.897 production_company(Motto Pictures) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    135   134 0.606 +0.658 production_company(Music Box Films) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    136    97 0.660 +0.804 production_company(Music Box Films) & genres(['Art House & International', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    137    56 0.602 +0.646 production_company(Music Box Films) & genres(['Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    138   170 0.780 +7.255 production_company(NEON) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(>90) | ---
#    139   105 0.705 +0.927 production_company(NEON) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    140   127 0.635 +0.736 production_company(National Geographic) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    141   187 0.649 +0.775 production_company(Netflix) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    142   107 0.641 +5.782 production_company(New Line Cinema) & genres(['Action & Adventure', 'Classics', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(>90) | ---
#    143   326 0.644 +0.762 production_company(New Line Cinema) & genres(['Action & Adventure', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    144    69 0.767 +1.096 production_company(New Line Cinema) & genres(['Art House & International', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    145    82 0.603 +7.662 production_company(New Line Cinema) & genres(['Comedy', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#    146    68 0.694 +0.897 production_company(New Video) & genres(['Art House & International', 'Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    147    67 0.720 +0.970 production_company(Newmarket Films) & genres(['Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    148    74 0.612 +5.474 production_company(Orion Pictures Corporation) & genres(['Horror', 'Mystery & Suspense']) & release_decade_interval(1990's) => review_score_interval(>90) | ---
#    149    71 0.657 +0.798 production_company(Oscilloscope Pictures) & genres(['Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    150   104 0.703 +0.921 production_company(Overture Films) & genres(['Drama', 'Horror', 'Science Fiction & Fantasy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    151    83 0.722 +0.973 production_company(Paladin Pictures) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    152    67 0.644 +0.762 production_company(Palm Pictures) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    153    77 0.688 +0.880 production_company(Palm Pictures) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    154    64 0.667 +0.823 production_company(Palm Pictures) & genres(['Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    155   166 0.610 +0.869 production_company(Paramount) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    156    98 0.645 +0.763 production_company(Paramount) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    157   256 0.667 +0.823 production_company(Paramount) & genres(['Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    158    55 0.764 +1.089 production_company(Paramount Classics) & genres(['Documentary', 'Kids & Family', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    159    61 0.616 +0.685 production_company(Paramount Classics) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    160   176 0.620 +0.695 production_company(Paramount Pictures) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    161    53 0.855 +8.049 production_company(Paramount Pictures) & genres(['Action & Adventure', 'Art House & International', 'Classics', 'Drama', 'Science Fiction & Fantasy']) & release_decade_interval(1920's) => review_score_interval(>90) | ---
#    162   103 0.602 +0.647 production_company(Paramount Pictures) & genres(['Action & Adventure', 'Drama', 'Western']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    163    83 0.790 +7.368 production_company(Paramount Pictures) & genres(['Classics', 'Drama']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#    164   154 0.720 +6.618 production_company(Paramount Pictures) & genres(['Classics', 'Horror', 'Mystery & Suspense']) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#    165    77 0.675 +6.150 production_company(Paramount Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#    166    77 0.606 +5.418 production_company(Paramount Pictures) & genres(['Drama']) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#    167    96 0.615 +0.683 production_company(Paramount Pictures) & genres(['Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    168   114 0.695 +0.901 production_company(Paramount Studios) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    169    75 0.664 +1.033 production_company(Paramount Studios) & genres(['Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    170    93 0.660 +0.803 production_company(Paramount/DWA) & genres(['Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    171    67 0.632 +0.728 production_company(Paramount/Dreamworks) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    172   120 0.632 +0.727 production_company(Petit Film) & genres(['Horror']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    173    75 0.701 +0.917 production_company(Picturehouse) & genres(['Drama', 'Horror', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    174    86 0.601 +5.366 production_company(Picturehouse) & genres(['Drama', 'Horror', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(>90) | ---
#    175    70 0.603 +0.650 production_company(Piki Films) & genres(['Action & Adventure', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    176    61 0.726 +0.986 production_company(Race Point Films) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    177    67 0.705 +0.928 production_company(Radius-TWC) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    178    94 0.644 +0.760 production_company(Radius-TWC) & genres(['Horror']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    179    75 0.615 +0.681 production_company(Radius-TWC) & genres(['Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    180   172 0.647 +0.768 production_company(Radius-TWC) & genres(['Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    181    76 0.760 +7.045 production_company(Rialto Pictures) & genres(['Action & Adventure', 'Art House & International', 'Classics', 'Drama']) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#    182   140 0.673 +0.840 production_company(Roadside Attractions) & genres(['Action & Adventure', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    183    56 0.609 +0.664 production_company(Roadside Attractions) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    184   121 0.647 +0.769 production_company(Roadside Attractions) & genres(['Art House & International', 'Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    185   127 0.641 +0.754 production_company(Roadside Attractions) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    186    81 0.628 +0.717 production_company(Roadside Attractions) & genres(['Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    187    59 0.694 +0.898 production_company(Rogue Pictures) & genres(['Comedy', 'Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    188    54 0.711 +6.521 production_company(Royal Films International) & genres(['Classics', 'Drama', 'Horror', 'Mystery & Suspense']) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#    189    93 0.762 +1.084 production_company(STX Entertainment) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    190    90 0.726 +0.985 production_company(STX Entertainment) & genres(['Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    191   122 0.601 +0.643 production_company(Scott Rudin Productions) & genres(['Action & Adventure', 'Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    192    53 0.616 +0.887 production_company(Screen Gems) & genres(['Comedy', 'Romance']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    193    50 0.602 +0.647 production_company(Shadow Distribution) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    194    96 0.686 +0.875 production_company(Shudder and NEON) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    195   109 0.690 +0.886 production_company(Sony) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    196    54 0.614 +0.678 production_company(Sony Classic Pictures) & genres(['Documentary', 'Drama', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    197    50 0.602 +0.647 production_company(Sony Classics) & genres(['Drama', 'Sports & Fitness']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    198    68 0.648 +0.771 production_company(Sony Pictures) & genres(['Action & Adventure', 'Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    199    68 0.613 +0.675 production_company(Sony Pictures) & genres(['Animation', 'Comedy', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    200   189 0.604 +0.651 production_company(Sony Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    201    74 0.638 +0.744 production_company(Sony Pictures Classics) & genres(['Action & Adventure', 'Art House & International', 'Comedy', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    202    72 0.632 +0.727 production_company(Sony Pictures Classics) & genres(['Action & Adventure', 'Art House & International', 'Drama', 'Mystery & Suspense']) & release_decade_interval(1990's) => review_score_interval(70-90) | ---
#    203    60 0.723 +6.652 production_company(Sony Pictures Classics) & genres(['Action & Adventure', 'Art House & International', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(>90) | ---
#    204   136 0.624 +0.706 production_company(Sony Pictures Classics) & genres(['Art House & International', 'Comedy', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    205    63 0.724 +0.980 production_company(Sony Pictures Classics) & genres(['Comedy', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    206    62 0.697 +0.905 production_company(Sony Pictures Classics) & genres(['Comedy', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    207   130 0.653 +0.786 production_company(Sony Pictures Classics) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    208    88 0.677 +0.851 production_company(Sony Pictures Classics) & genres(['Documentary', 'Special Interest', 'Sports & Fitness']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    209   199 0.630 +0.722 production_company(Sony Pictures Classics) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    210   158 0.615 +0.681 production_company(Sony Pictures Classics) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    211    72 0.632 +0.727 production_company(Sony Pictures Classics) & genres(['Documentary', 'Sports & Fitness']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    212   140 0.636 +0.740 production_company(Sony Pictures Classics) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    213    74 0.755 +1.065 production_company(Sony Pictures Classics) & genres(['Drama', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    214    59 0.656 +0.792 production_company(Sony Pictures Classics) & genres(['Drama', 'Sports & Fitness']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    215    84 0.651 +0.780 production_company(Sony Pictures Classics) & genres(['Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    216    76 0.608 +0.662 production_company(Sony Pictures/Screen Gems) & genres(['Comedy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    217    76 0.650 +0.776 production_company(Strand Releasing) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    218    60 0.619 +0.691 production_company(Studio Ghibli) & genres(['Animation', 'Art House & International']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    219    69 0.645 +0.763 production_company(StudioCanal) & genres(['Art House & International', 'Drama', 'Mystery & Suspense', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    220   118 0.656 +0.792 production_company(Summit Entertainment) & genres(['Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    221    73 0.646 +0.766 production_company(Sundance Selects) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    222    54 0.761 +1.080 production_company(The Orchard) & genres(['Art House & International', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    223    50 0.617 +0.688 production_company(The Weinstein Co.) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    224    65 0.625 +0.709 production_company(The Weinstein Company) & genres(['Action & Adventure', 'Comedy', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    225    66 0.846 +11.156 production_company(The Weinstein Company) & genres(['Comedy', 'Horror', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(<30) | ---
#    226    79 0.806 +1.204 production_company(The Weinstein Company) & genres(['Comedy', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    227    50 0.704 +0.926 production_company(Think Film) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    228    53 0.646 +0.767 production_company(ThinkFilm) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    229   104 0.608 +0.663 production_company(ThinkFilm) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    230   145 0.636 +0.739 production_company(ThinkFilm) & genres(['Documentary']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    231    53 0.602 +0.845 production_company(Touchstone Pictures) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Musical & Performing Arts', 'Romance']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    232    67 0.604 +0.849 production_company(Touchstone Pictures) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    233   136 0.642 +0.965 production_company(Touchstone Pictures) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    234    87 0.604 +0.652 production_company(TriStar Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    235    57 0.663 +1.030 production_company(Twentieth Century Fox) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    236    70 0.814 +7.616 production_company(United Artists) & genres(['Classics', 'Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#    237    72 0.706 +6.472 production_company(United Artists) & genres(['Drama']) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#    238    98 0.624 +0.707 production_company(Universal) & genres(['Comedy', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    239    50 0.667 +0.823 production_company(Universal) & genres(['Drama']) & release_decade_interval(1990's) => review_score_interval(70-90) | ---
#    240    67 0.620 +0.900 production_company(Universal Pictures) & genres(['Drama', 'Horror', 'Mystery & Suspense', 'Romance']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    241   190 0.629 +0.720 production_company(Universal Pictures) & genres(['Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    242   158 0.678 +0.854 production_company(Universal Pictures) & genres(['Horror', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#    243    52 0.788 +7.340 production_company(Universal Pictures) & genres(['Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#    244   119 0.661 +0.808 production_company(Universal Studios) & genres(['Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    245    54 0.600 +0.641 production_company(Variance Films) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    246   112 0.640 +0.750 production_company(Walt Disney Animation Studios) & genres(['Action & Adventure', 'Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    247   246 0.719 +0.967 production_company(Walt Disney Animation Studios) & genres(['Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    248    70 0.614 +0.679 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Animation', 'Art House & International', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    249    83 0.654 +0.787 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Animation', 'Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    250   131 0.630 +0.722 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    251    83 0.634 +0.940 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    252   137 0.688 +0.882 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    253    69 0.734 +1.007 production_company(Walt Disney Pictures) & genres(['Animation', 'Art House & International', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    254    93 0.637 +0.742 production_company(Walt Disney Pictures) & genres(['Animation', 'Comedy', 'Horror', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    255    93 0.628 +0.718 production_company(Walt Disney Pictures) & genres(['Animation', 'Comedy', 'Kids & Family', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    256    83 0.654 +0.787 production_company(Walt Disney Pictures) & genres(['Comedy', 'Kids & Family', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    257    66 0.606 +0.854 production_company(Walt Disney Pictures) & genres(['Documentary', 'Drama']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    258   137 0.688 +0.882 production_company(Walt Disney Pictures/PIXAR) & genres(['Animation']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    259   146 0.619 +0.895 production_company(Walt Disney Studios) & genres(['Action & Adventure', 'Comedy', 'Drama', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    260    77 0.658 +0.800 production_company(Warner Bros. Pictures) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    261   249 0.616 +0.685 production_company(Warner Bros. Pictures) & genres(['Action & Adventure', 'Drama', 'Kids & Family', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    262   107 0.728 +0.990 production_company(Warner Bros. Pictures) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    263   119 0.640 +0.749 production_company(Warner Bros. Pictures) & genres(['Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    264    58 0.879 +8.303 production_company(Warner Bros. Pictures) & genres(['Classics', 'Kids & Family', 'Musical & Performing Arts', 'Science Fiction & Fantasy']) & release_decade_interval(1930's) => review_score_interval(>90) | ---
#    265    88 0.647 +0.982 production_company(Warner Bros. Pictures) & genres(['Comedy', 'Drama', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    266    70 0.614 +0.881 production_company(Warner Bros. Pictures) & genres(['Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    267    66 0.600 +5.351 production_company(Warner Bros. Pictures) & genres(['Drama', 'Horror', 'Mystery & Suspense', 'Special Interest']) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#    268    59 0.615 +0.882 production_company(Warner Bros. Pictures/New Line Cinema) & genres(['Action & Adventure', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    269    69 0.616 +0.685 production_company(Warner Independent Pictures) & genres(['Documentary']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    270    51 0.689 +0.884 production_company(Weinstein Company) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    271    78 0.605 +0.653 production_company(Weinstein Company) & genres(['Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    272    84 0.706 +0.930 production_company(Well Go USA Entertainment) & genres(['Action & Adventure', 'Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    273    74 0.649 +0.775 production_company(Wellspring) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    274    50 0.667 +0.823 production_company(Zeitgeist Films) & genres(['Documentary', 'Drama', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    275    51 0.680 +0.859 production_company(Zeitgeist Films) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    276   161 0.674 +0.842 production_company(Zeitgeist Films) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    277    52 0.722 +0.975 production_company(levelFILM) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    278    83 0.716 +0.956 production_company(s) & genres(['Comedy', 'Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#
#
#
# Rule id : 2
#
# Base :    55  Relative base : 0.000  CONF : 0.655  AAD : +0.790  BAD : -0.790
#
# Cedents:
#   antecedent : production_company(20th Century Fox) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2000's)
#   succcedent : review_score_interval(70-90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |   55|   29|
# ----|-----|-----|
# ¬A  |245129|425198|
# ----|-----|-----|

# %% [markdown]
# ## Otázka 4

# %% [markdown]
# ### 4ftMiner

# %%
df = data
df=df.loc[:, ('tomatometer_rating_interval', 'release_decade_interval', 'production_company')]



clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.8, 'Base': 100},
               ante ={
                    'attributes':[
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'release_decade_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':2, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'tomatometer_rating_interval', 'type': 'one', 'value': '>90'},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 244, rules 50,control number:0, times: prep 4.065985918045044, processing 0.5615181922912598
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 244
# Number of rules : 50
# Total time needed : 00h 00m 04s
# Time of data preparation : 00h 00m 04s
# Time of rule mining : 00h 00m 00s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1   112 0.830 +3.492 production_company(20th Century Fox) & release_decade_interval(1940's) => tomatometer_rating_interval(>90) | ---
#      2   239 1.000 +4.414 production_company(21 Laps Entertainment) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#      3   181 1.000 +4.414 production_company(Bad Robot Productions) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#      4   126 0.881 +3.771 production_company(CJ Entertainment) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#      5   215 0.827 +3.477 production_company(Columbia Pictures) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#      6   104 1.000 +4.414 production_company(Criterion Collection) & release_decade_interval(1920's) => tomatometer_rating_interval(>90) | ---
#      7   107 0.915 +3.952 production_company(Criterion Collection) & release_decade_interval(1940's) => tomatometer_rating_interval(>90) | ---
#      8   199 0.816 +3.416 production_company(Criterion Collection) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#      9   448 0.848 +3.594 production_company(Criterion Collection) & release_decade_interval(1960's) => tomatometer_rating_interval(>90) | ---
#     10   423 1.000 +4.414 production_company(Disney/Pixar) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     11   900 0.870 +3.713 production_company(Disney/Pixar) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     12   120 1.000 +4.414 production_company(Drafthouse Recommends) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     13   370 1.000 +4.414 production_company(Element Pictures) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     14   168 1.000 +4.414 production_company(Film 44) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     15   165 1.000 +4.414 production_company(Fingerprint Releasing / Bleecker Street) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     16   140 1.000 +4.414 production_company(Fireworks Pictures) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     17   225 1.000 +4.414 production_company(Fox Searchlight Pictures, Film4 and Waypoint) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     18   452 1.000 +4.414 production_company(IMAX) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     19   157 1.000 +4.414 production_company(Ideaman Studios) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     20   256 1.000 +4.414 production_company(Janus Films) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#     21   109 0.813 +3.404 production_company(Janus Films) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     22   171 1.000 +4.414 production_company(June Pictures) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     23   140 1.000 +4.414 production_company(K5 International) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     24   117 0.836 +3.525 production_company(Kino International) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     25   187 0.866 +3.688 production_company(MGM) & release_decade_interval(1930's) => tomatometer_rating_interval(>90) | ---
#     26   200 1.000 +4.414 production_company(National Geographic) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     27   119 0.902 +3.881 production_company(New Video) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     28   110 0.887 +3.803 production_company(New Yorker Films) & release_decade_interval(1970's) => tomatometer_rating_interval(>90) | ---
#     29   115 1.000 +4.414 production_company(Paladin Pictures) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     30   130 0.909 +3.922 production_company(Paramount Home Video) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#     31   142 0.830 +3.496 production_company(Paramount Pictures) & release_decade_interval(1940's) => tomatometer_rating_interval(>90) | ---
#     32   141 1.000 +4.414 production_company(Paramount/DWA) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     33   190 1.000 +4.414 production_company(Petit Film) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     34   116 1.000 +4.414 production_company(Piki Films) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     35   252 0.810 +3.387 production_company(Rialto Pictures) & release_decade_interval(1960's) => tomatometer_rating_interval(>90) | ---
#     36   100 1.000 +4.414 production_company(Rialto Pictures) & release_decade_interval(1980's) => tomatometer_rating_interval(>90) | ---
#     37   192 1.000 +4.414 production_company(Roadside Attractions ) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     38   137 1.000 +4.414 production_company(Rogue Pictures/Focus Features) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     39   126 1.000 +4.414 production_company(SBS Productions) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     40   203 1.000 +4.414 production_company(Scott Rudin Productions) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     41   140 1.000 +4.414 production_company(Shudder and NEON) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     42   151 1.000 +4.414 production_company(Starburns Industries) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     43   194 1.000 +4.414 production_company(United Artists) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     44   112 0.918 +3.971 production_company(United Artists Films) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     45   191 0.834 +3.516 production_company(Universal Pictures) & release_decade_interval(1940's) => tomatometer_rating_interval(>90) | ---
#     46   102 0.850 +3.602 production_company(WARNER BROTHERS PICTURES) & release_decade_interval(1930's) => tomatometer_rating_interval(>90) | ---
#     47   100 0.909 +3.922 production_company(Warner Bros. Pictures) & release_decade_interval(1930's) => tomatometer_rating_interval(>90) | ---
#     48   307 0.819 +3.433 production_company(Warner Bros. Pictures) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#     49   203 1.000 +4.414 production_company(Warner Bros. Pictures/Legendary) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     50   116 1.000 +4.414 production_company(s) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#
#
#
# Rule id : 2
#
# Base :   239  Relative base : 0.000  CONF : 1.000  AAD : +4.414  BAD : -4.414
#
# Cedents:
#   antecedent : production_company(21 Laps Entertainment) & release_decade_interval(2010's)
#   succcedent : tomatometer_rating_interval(>90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |  239|    0|
# ----|-----|-----|
# ¬A  |123579|546593|
# ----|-----|-----|

# %% [markdown]
# ## Question X: Hledání souvislosti mezi režiséry a review score

# %% [markdown]
# ### Jak se liší hodnocení filmů na základě režiséra, doby trvání a vhodnosti obsahu

# %%
# be patient, runs approx 50secs!
df = data
df=df.loc[:, ('directors', 'runtime_interval', 'content_rating', 'review_score_interval')]

clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.8, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'directors', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'content_rating', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':3, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 9661, rules 27,control number:0, times: prep 12.900224924087524, processing 11.365200757980347
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 9661
# Number of rules : 27
# Total time needed : 00h 00m 24s
# Time of data preparation : 00h 00m 12s
# Time of rule mining : 00h 00m 11s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1    80 0.870 +8.205 directors(Akira Kurosawa) & runtime_interval(>2.5h) & content_rating(G) => review_score_interval(>90) | ---
#      2    84 0.824 +7.718 directors(Akira Kurosawa) & content_rating(G) => review_score_interval(>90) | ---
#      3    53 0.828 +7.766 directors(Carol Reed) & runtime_interval(1.5-1.75h) => review_score_interval(>90) | ---
#      4    53 0.828 +7.766 directors(Carol Reed) & runtime_interval(1.5-1.75h) & content_rating(NR) => review_score_interval(>90) | ---
#      5    53 0.855 +8.049 directors(Fritz Lang) & runtime_interval(2-2.5) & content_rating(PG-13) => review_score_interval(>90) | ---
#      6    53 0.855 +8.049 directors(Fritz Lang) & content_rating(PG-13) => review_score_interval(>90) | ---
#      7    56 0.889 +8.409 directors(Jean Renoir) & runtime_interval(1.75-2h) => review_score_interval(>90) | ---
#      8    56 0.889 +8.409 directors(Jean Renoir) & runtime_interval(1.75-2h) & content_rating(NR) => review_score_interval(>90) | ---
#      9    70 0.814 +7.616 directors(John Huston, Billy Wilder) & runtime_interval(2-2.5) => review_score_interval(>90) | ---
#     10    70 0.814 +7.616 directors(John Huston, Billy Wilder) & runtime_interval(2-2.5) & content_rating(G) => review_score_interval(>90) | ---
#     11    70 0.814 +7.616 directors(John Huston, Billy Wilder) & content_rating(G) => review_score_interval(>90) | ---
#     12   130 0.812 +1.222 directors(John M. Maclean) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#     13   130 0.812 +1.222 directors(John M. Maclean) & runtime_interval(1.5-1.75h) & content_rating(R) => review_score_interval(70-90) | ---
#     14   130 0.812 +1.222 directors(John M. Maclean) & content_rating(R) => review_score_interval(70-90) | ---
#     15    58 0.879 +8.303 directors(King Vidor, Victor Fleming) & runtime_interval(1.5-1.75h) => review_score_interval(>90) | ---
#     16    58 0.879 +8.303 directors(King Vidor, Victor Fleming) & runtime_interval(1.5-1.75h) & content_rating(G) => review_score_interval(>90) | ---
#     17    58 0.879 +8.303 directors(King Vidor, Victor Fleming) & content_rating(G) => review_score_interval(>90) | ---
#     18    54 0.806 +1.204 directors(Lauren Greenfield) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#     19    54 0.806 +1.204 directors(Lauren Greenfield) & runtime_interval(1.5-1.75h) & content_rating(PG) => review_score_interval(70-90) | ---
#     20    54 0.806 +1.204 directors(Lauren Greenfield) & content_rating(PG) => review_score_interval(70-90) | ---
#     21    79 0.806 +1.204 directors(Paul King (VII), Marcos Da Silva) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#     22    79 0.806 +1.204 directors(Paul King (VII), Marcos Da Silva) & runtime_interval(1.5-1.75h) & content_rating(PG) => review_score_interval(70-90) | ---
#     23    79 0.806 +1.204 directors(Paul King (VII), Marcos Da Silva) & content_rating(PG) => review_score_interval(70-90) | ---
#     24    53 0.803 +1.196 directors(Tobias Lindholm) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#     25    53 0.803 +1.196 directors(Tobias Lindholm) & runtime_interval(1.5-1.75h) & content_rating(R) => review_score_interval(70-90) | ---
#     26   131 0.819 +10.763 directors(Uwe Boll) & runtime_interval(1.5-1.75h) => review_score_interval(<30) | ---
#     27   131 0.819 +10.763 directors(Uwe Boll) & runtime_interval(1.5-1.75h) & content_rating(R) => review_score_interval(<30) | ---
#
#
#
# Rule id : 2
#
# Base :    84  Relative base : 0.000  CONF : 0.824  AAD : +7.718  BAD : -7.718
#
# Cedents:
#   antecedent : directors(Akira Kurosawa) & content_rating(G)
#   succcedent : review_score_interval(>90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |   84|   18|
# ----|-----|-----|
# ¬A  |63248|607061|
# ----|-----|-----|

# %% [markdown]
# ## Question Y: Hledání souvislosti mezi kritiky a review score

# %% [markdown]
# ### Jak se liší hodnocení filmů na základě kritika, zda je kritic top a  doby trvání

# %%
# be patient, runs approx 50secs!
df = data
df=df.loc[:, ('critic_name', 'runtime_interval', 'review_score', 'top_critic', 'review_score_interval')]

clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.8, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'critic_name', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':3, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 8770, rules 9,control number:0, times: prep 10.099143266677856, processing 7.239105224609375
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 8770
# Number of rules : 9
# Total time needed : 00h 00m 17s
# Time of data preparation : 00h 00m 10s
# Time of rule mining : 00h 00m 07s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1    59 0.831 +1.272 critic_name(Anita Katz) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#      2    59 0.831 +1.272 critic_name(Anita Katz) & runtime_interval(1.5-1.75h) & top_critic(False) => review_score_interval(70-90) | ---
#      3    56 0.933 +1.552 critic_name(Piers Marchant) & runtime_interval(1.75-2h) => review_score_interval(70-90) | ---
#      4    56 0.933 +1.552 critic_name(Piers Marchant) & runtime_interval(1.75-2h) & top_critic(False) => review_score_interval(70-90) | ---
#      5    51 0.850 +1.324 critic_name(Piers Marchant) & runtime_interval(2-2.5) => review_score_interval(70-90) | ---
#      6    51 0.850 +1.324 critic_name(Piers Marchant) & runtime_interval(2-2.5) & top_critic(False) => review_score_interval(70-90) | ---
#      7   153 0.805 +1.202 critic_name(Piers Marchant) & top_critic(False) => review_score_interval(70-90) | ---
#      8    58 0.806 +1.203 critic_name(Reagan Gavin Rasquinha) & runtime_interval(2-2.5) => review_score_interval(70-90) | ---
#      9    58 0.806 +1.203 critic_name(Reagan Gavin Rasquinha) & runtime_interval(2-2.5) & top_critic(False) => review_score_interval(70-90) | ---
#
#
#
# Rule id : 2
#
# Base :    59  Relative base : 0.000  CONF : 0.831  AAD : +1.272  BAD : -1.272
#
# Cedents:
#   antecedent : critic_name(Anita Katz) & runtime_interval(1.5-1.75h) & top_critic(False)
#   succcedent : review_score_interval(70-90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |   59|   12|
# ----|-----|-----|
# ¬A  |245125|425215|
# ----|-----|-----|

# %% [markdown]
# ## bonus: horror movies

# %%
horror_scores = dict()
for row in tqdm(range(data.shape[0])):
    if 'Horror' in data['genres'][row]:
        value = data['review_score'][row]
        name = data['movie_title'][row]
        if name not in horror_scores.keys():
            horror_scores[name] = [value]
        else:
            horror_scores[name].append(value)
# Out:
#   0%|          | 0/670411 [00:00<?, ?it/s]

# %%
# calculating average scores for each actor
final_horror_scores = {}
for key in tqdm(horror_scores.keys()):
    # add only actors with 3000+ reviews 
    if len(horror_scores[key]) > 50:
        mean = np.mean(horror_scores[key])
        final_horror_scores[key] = round(mean, 1)
# Out:
#   0%|          | 0/1730 [00:00<?, ?it/s]

# %%
top_horrors = sorted(final_horror_scores.items(), key=lambda x: x[1], reverse=True)
top_horrors
# Out:
# [('Repulsion', 91.1),
#  ('Aliens', 90.8),
#  ("Rosemary's Baby", 90.6),
#  ('The Silence of the Lambs', 90.2),
#  ("Pan's Labyrinth", 89.2),
#  ('The Shining', 86.5),
#  ('Seconds', 85.5),
#  ('Let the Right One In', 85.3),
#  ('Psycho', 84.7),
#  ('Get Out', 83.6),
#  ('Hereditary', 82.3),
#  ('A Quiet Place', 81.9),
#  ('The Babadook', 81.7),
#  ('Night of the Living Dead', 81.4),
#  ('It Follows', 81.3),
#  ('Under The Shadow', 81.0),
#  ('The Lighthouse', 80.5),
#  ('The Fly', 80.2),
#  ('Re-Animator', 80.2),
#  ('A Girl Walks Home Alone at Night', 80.1),
#  ('Shaun of the Dead', 80.1),
#  ('The Blair Witch Project', 79.8),
#  ('The Cabin in the Woods', 79.8),
#  ('Us', 79.8),
#  ('Raw', 78.6),
#  ('The Witch', 77.9),
#  ('The Invisible Man', 77.8),
#  ('The Love Witch', 76.9),
#  ('Drag Me to Hell', 76.6),
#  ('Green Room', 76.6),
#  ('The Host', 76.6),
#  ('The Little Stranger', 76.4),
#  ('Train to Busan (Busanhaeng)', 76.4),
#  ('Relic', 76.3),
#  ('28 Days Later', 76.1),
#  ('Midsommar', 76.1),
#  ('The Others', 76.0),
#  ('Santa Sangre', 75.7),
#  ('The Descent', 75.6),
#  ('Let Me In', 75.6),
#  ('The Endless', 75.6),
#  ('Room 237', 75.4),
#  ('The Orphanage', 75.4),
#  ('Possum', 75.3),
#  ('Frankenweenie', 75.1),
#  ('Goodnight Mommy (Ich seh, Ich seh)', 75.1),
#  ('In Fabric', 75.1),
#  ('Upgrade', 74.6),
#  ('Zombieland', 74.4),
#  ('Bone Tomahawk', 73.9),
#  ('It Comes At Night', 73.9),
#  ('Pulse (Kairo)', 73.8),
#  ('Shadow of the Vampire', 73.7),
#  ('Spring', 73.6),
#  ('It', 73.5),
#  ('The House of the Devil', 73.2),
#  ('Predator', 73.1),
#  ('Berberian Sound Studio', 73.0),
#  ("Don't Breathe", 73.0),
#  ('Cat People', 72.7),
#  ('Ready or Not', 72.7),
#  ('The Return of the Living Dead', 72.6),
#  ('The Conjuring', 72.3),
#  ('King Kong', 72.1),
#  ('The Autopsy of Jane Doe', 71.9),
#  ('Paranormal Activity', 71.6),
#  ('Paprika', 71.5),
#  ('This Is the End', 71.3),
#  ('Brick', 71.2),
#  ('Dracula', 70.9),
#  ('Bubba Ho-Tep', 70.9),
#  ('Stir of Echoes', 70.8),
#  ('Chronicle', 70.7),
#  ('Frailty', 70.6),
#  ('Tale of Tales (Il racconto dei racconti)', 70.3),
#  ('Starfish', 70.1),
#  ('American Psycho', 69.8),
#  ('Prometheus', 69.7),
#  ('Sputnik', 69.7),
#  ('Tucker and Dale vs. Evil', 69.7),
#  ('Sleepy Hollow', 69.5),
#  ('Slither', 69.4),
#  ('Bakjwi (Thirst)', 69.3),
#  ('The Mist', 69.3),
#  ('Sea Fever', 69.2),
#  ('mother!', 69.1),
#  ('Land of the Dead', 69.0),
#  ('The Rocky Horror Picture Show', 69.0),
#  ('Hellboy', 68.9),
#  ('The Eyes of My Mother', 68.7),
#  ('Monsters', 68.6),
#  ('The Ring', 68.6),
#  ('Hard Candy', 68.5),
#  ('Session 9', 68.5),
#  ('Stoker', 68.1),
#  ('Dawn of the Dead', 68.0),
#  ('Scream 2', 68.0),
#  ('Suspiria', 68.0),
#  ('The Conjuring 2', 68.0),
#  ('Open Water', 67.9),
#  ('Satanic Panic', 67.9),
#  ('Color Out of Space', 67.8),
#  ('Red Dragon', 67.7),
#  ('Splice', 67.2),
#  ('1408', 67.0),
#  ('28 Weeks Later...', 66.9),
#  ('Overlord', 66.8),
#  ('Pacific Rim', 66.3),
#  ('Crimson Peak', 66.0),
#  ('Stake Land', 66.0),
#  ('The Innkeepers', 66.0),
#  ('Halloween', 65.7),
#  ('Split', 65.7),
#  ("You're Next", 65.5),
#  ('Fright Night', 65.4),
#  ('Byzantium', 65.3),
#  ('Scary Stories to Tell in the Dark', 65.3),
#  ('Crawl', 65.1),
#  ('The Limehouse Golem', 64.9),
#  ('Goosebumps', 64.8),
#  ('Oculus', 64.6),
#  ('[Rec] 2', 64.6),
#  ('Willard', 64.5),
#  ('The Rental', 64.4),
#  ("Jacob's Ladder", 64.3),
#  ('Lights Out', 64.1),
#  ('Severance', 64.0),
#  ('Diary of the Dead', 63.9),
#  ('Frozen', 63.8),
#  ('Sinister', 63.8),
#  ('Snakes on a Plane', 63.8),
#  ('Carrie', 63.6),
#  ('The Wretched', 63.6),
#  ('Ouija: Origin of Evil', 63.3),
#  ('Serial Mom', 63.3),
#  ('Black Sheep', 63.2),
#  ('The Last Exorcism', 62.9),
#  ('The Hole in the Ground', 62.8),
#  ('It Chapter Two', 62.7),
#  ('The Woman in Black', 62.7),
#  ('Daybreakers', 62.6),
#  ('Zombieland: Double Tap', 62.5),
#  ('Blade', 62.3),
#  ('Happy Death Day 2U', 62.3),
#  ('Blade II', 62.1),
#  ('Evil Dead', 62.0),
#  ('Annabelle: Creation', 61.9),
#  ('Happy Death Day', 61.8),
#  ('Rubber', 61.7),
#  ('Day Watch', 61.6),
#  ('Piranha 3-D', 61.6),
#  ('The Signal', 61.6),
#  ('World War Z', 61.6),
#  ('Rabid', 61.3),
#  ('Red State', 61.3),
#  ('The Crazies', 61.1),
#  ('Krampus', 61.1),
#  ('Paranormal Activity 2', 61.1),
#  ('Dark Water', 60.9),
#  ('Hostel', 60.6),
#  ('The Cell', 60.6),
#  ('The Neon Demon', 60.4),
#  ('Unfriended: Dark Web', 60.1),
#  ('Mama', 60.0),
#  ('Scream 4', 60.0),
#  ('Insidious', 59.9),
#  ("The Dead Don't Die", 59.9),
#  ("Child's Play", 59.8),
#  ('Predators', 59.7),
#  ('The Next Three Days', 59.7),
#  ('The House That Jack Built', 59.7),
#  ('The Hunt', 59.7),
#  ('Final Destination 5', 59.6),
#  ('Kaboom', 59.5),
#  ('Mom and Dad', 59.5),
#  ('From Hell', 59.3),
#  ('Spree', 59.3),
#  ('My Bloody Valentine 3-D', 59.2),
#  ('Paranormal Activity 3', 59.2),
#  ('V/H/S/2', 59.2),
#  ('Pitch Black', 59.0),
#  ('Ravenous', 59.0),
#  ('Night Watch', 58.9),
#  ('Saw', 58.9),
#  ('The Visit', 58.6),
#  ('Deep Blue Sea', 58.5),
#  ('Pet Sematary', 58.5),
#  ('30 Days of Night', 58.4),
#  ("Don't Be Afraid Of The Dark", 58.4),
#  ('The Jacket', 58.3),
#  ('Orphan', 58.1),
#  ('Antiviral', 58.1),
#  ('Vacancy', 58.1),
#  ('Wolf Creek', 58.1),
#  ('Poltergeist', 58.0),
#  ('The Thing', 57.9),
#  ('Annabelle Comes Home', 57.9),
#  ('Unknown', 57.9),
#  ('Maggie', 57.8),
#  ('Quarantine', 57.7),
#  ('John Carter', 57.6),
#  ('What Lies Beneath', 57.6),
#  ('Antichrist', 57.5),
#  ('V/H/S', 57.4),
#  ('Constantine', 57.2),
#  ('Cabin Fever', 57.0),
#  ('The Exorcism of Emily Rose', 56.8),
#  ('Insidious: Chapter 3', 56.8),
#  ('Jeepers Creepers', 56.6),
#  ('Eight Legged Freaks', 56.5),
#  ('Scream 3', 56.5),
#  ('Ma', 56.3),
#  ('The Hills Have Eyes', 56.1),
#  ('Brightburn', 56.1),
#  ('The Belko Experiment', 56.1),
#  ('Scary Movie', 56.0),
#  ('Twilight', 56.0),
#  ('The First Purge', 55.9),
#  ('Tusk', 55.9),
#  ('The Awakening', 55.5),
#  ('The Haunting', 55.5),
#  ('The Ruins', 55.5),
#  ('The Purge: Anarchy', 55.4),
#  ('The Purge: Election Year', 55.0),
#  ('Femme Fatale', 54.9),
#  ('Dark Shadows', 54.9),
#  ("Jennifer's Body", 54.9),
#  ('The Mummy Returns', 54.9),
#  ('Goosebumps 2: Haunted Halloween', 54.7),
#  ("The Devil's Rejects", 54.6),
#  ('The Wicker Man', 54.5),
#  ('The Skeleton Key', 54.3),
#  ('Final Destination', 54.2),
#  ('The Human Centipede (First Sequence)', 54.0),
#  ('Pride and Prejudice and Zombies', 53.9),
#  ('The Omen', 53.8),
#  ('The Possession', 53.7),
#  ('The Stepfather', 53.4),
#  ('The Phantom of the Opera', 53.3),
#  ('Doomsday', 53.3),
#  ('The Box', 53.1),
#  ('Insidious: The Last Key', 53.1),
#  ('Silent House', 53.1),
#  ('The Meg', 53.1),
#  ('Blair Witch', 53.0),
#  ('Devil', 53.0),
#  ('[REC] 3 Genesis', 52.8),
#  ('Final Destination 3', 52.7),
#  ('Psycho II', 52.5),
#  ("Cirque du Freak: The Vampire's Assistant", 52.5),
#  ('The Wolfman', 52.1),
#  ('The Last House on the Left', 52.1),
#  ('The Lovely Bones', 51.9),
#  ('High Tension (Switchblade Romance)', 51.9),
#  ('The Statement', 51.1),
#  ('The Uninvited', 50.9),
#  ('The Mummy', 50.8),
#  ('House of Wax', 50.5),
#  ('The Predator', 50.4),
#  ('Dreamcatcher', 50.3),
#  ('Hollow Man', 50.2),
#  ('Stage Fright', 50.1),
#  ('Morgan', 50.0),
#  ('Survival of the Dead', 50.0),
#  ('The Strangers', 50.0),
#  ('Freddy vs. Jason', 49.8),
#  ('The Green Inferno', 49.8),
#  ('Dark Skies', 49.7),
#  ('Maniac', 49.6),
#  ('Final Destination 2', 49.5),
#  ('Repo! The Genetic Opera', 49.4),
#  ('The Scorpion King', 49.3),
#  ('The Strangers: Prey At Night', 49.3),
#  ('The Twilight Saga: New Moon', 49.3),
#  ('Insidious: Chapter 2', 49.2),
#  ('Abraham Lincoln: Vampire Hunter', 49.1),
#  ('Saw II', 49.1),
#  ('The Grudge', 49.0),
#  ('The Chronicles of Riddick', 48.9),
#  ('Scouts Guide to the Zombie Apocalypse', 48.9),
#  ('The Texas Chainsaw Massacre', 48.8),
#  ('Stigmata', 48.7),
#  ('Intruders', 48.6),
#  ('The Quiet Ones', 48.6),
#  ('Underworld', 48.6),
#  ('The Invasion', 48.2),
#  ('The Woman in Black 2 Angel of Death', 48.0),
#  ('Antebellum', 47.8),
#  ('Paranormal Activity: The Marked Ones', 47.8),
#  ('The Ring Two', 47.8),
#  ('Shutter', 47.5),
#  ('Deliver Us from Evil', 47.4),
#  ('Hostel Part II', 47.3),
#  ('A Nightmare on Elm Street', 47.2),
#  ('Seed of Chucky', 47.2),
#  ('Abandon', 47.0),
#  ('Silent Hill', 46.9),
#  ('The Curse of La Llorona', 46.9),
#  ('Friday the 13th', 46.8),
#  ('The Fog', 46.7),
#  ('The Relic', 46.6),
#  ('Annabelle', 46.5),
#  ('Resident Evil', 46.2),
#  ('Saw VI', 46.2),
#  ('The Haunting in Connecticut', 45.8),
#  ('Blade: Trinity', 45.4),
#  ('The Nun', 45.0),
#  ('Pandorum', 44.8),
#  ('Underworld: Awakening', 44.8),
#  ('Black Christmas', 44.7),
#  ('The Haunted Mansion', 44.6),
#  ('Resident Evil: The Final Chapter', 44.6),
#  ('Saw III', 44.6),
#  ('Wrong Turn', 44.5),
#  ('The Amityville Horror', 44.4),
#  ('The Final Destination', 44.4),
#  ('The Eye', 44.2),
#  ('Resident Evil: Extinction', 44.2),
#  ('Ghost Rider', 44.1),
#  ('Flatliners', 44.0),
#  ('Underworld: The Rise of the Lycans', 44.0),
#  ('End of Days', 43.9),
#  ('The Collector', 43.7),
#  ('Club Dread', 43.6),
#  ('Anacondas: The Hunt for the Blood Orchid', 43.5),
#  ('Gothika', 43.5),
#  ('Paranormal Activity 4', 43.4),
#  ('AVP - Alien Vs. Predator', 43.3),
#  ('Sorority Row', 43.3),
#  ('Untraceable', 43.0),
#  ('Hannibal Rising', 43.0),
#  ('Turistas (Paradise Lost)', 42.7),
#  ('Jeepers Creepers 2', 42.3),
#  ('Resident Evil: Afterlife', 42.0),
#  ('Sinister 2', 42.0),
#  ('The Dark Tower', 42.0),
#  ('Van Helsing', 41.8),
#  ('Queen of the Damned', 41.7),
#  ('Chernobyl Diaries', 41.6),
#  ('Spawn', 41.6),
#  ('The Forest', 41.6),
#  ('Underworld: Evolution', 41.6),
#  ('Mirrors', 41.2),
#  ('Doom', 41.1),
#  ('The Lazarus Effect', 41.0),
#  ('Case 39', 40.9),
#  ('Swimfan', 40.9),
#  ('Pulse', 40.8),
#  ('Ghost Ship', 40.7),
#  ('Resident Evil: Apocalypse', 40.2),
#  ('Underworld: Blood Wars', 40.0),
#  ('Priest', 39.8),
#  ('The Hitcher', 39.7),
#  ('Wish Upon', 39.4),
#  ('Legion', 38.9),
#  ('Red Riding Hood', 38.6),
#  ('Saw IV', 38.5),
#  ('Cursed', 37.9),
#  ('When a Stranger Calls', 37.8),
#  ('House of 1000 Corpses', 37.7),
#  ('The Reaping', 37.7),
#  ("Blumhouse's Truth or Dare", 37.4),
#  ('Exorcist: The Beginning', 37.4),
#  ('The Cave', 37.3),
#  ('The Last Exorcism Part II', 36.7),
#  ('Jonah Hex', 36.6),
#  ('Blood and Chocolate', 36.5),
#  ('The Rage: Carrie 2', 36.0),
#  ('The Texas Chainsaw Massacre: The Beginning', 36.0),
#  ('Jason X', 35.9),
#  ('Godsend', 35.8),
#  ('The Grudge 2', 35.8),
#  ('The Bye Bye Man', 35.8),
#  ('White Noise', 35.8),
#  ('Primeval', 35.6),
#  ('The Skulls', 34.9),
#  ('Shark Night 3D', 34.5),
#  ('Slender Man', 34.5),
#  ("John Carpenter's Ghosts of Mars", 34.1),
#  ('Texas Chainsaw', 34.0),
#  ('Ouija', 33.9),
#  ('Darkness Falls', 33.8),
#  ('The Gallows', 33.8),
#  ('Venom', 33.7),
#  ('I, Frankenstein', 33.7),
#  ('One Missed Call', 33.4),
#  ('The Unborn', 33.0),
#  ('Rings', 33.0),
#  ('Saw V', 33.0),
#  ('Boogeyman', 32.3),
#  ('Saw 3D', 32.3),
#  ('Postal', 31.9),
#  ('Aliens vs. Predator: Requiem (AVP 2)', 31.7),
#  ('Silent Hill: Revelation', 31.2),
#  ('A Sound of Thunder', 30.8),
#  ('The Covenant', 30.3),
#  ('Prom Night', 28.7),
#  ('Feardotcom', 28.6),
#  ('Soul Survivors', 28.4),
#  ('The Devil Inside', 28.3),
#  ('The Roommate', 28.2),
#  ('Captivity', 27.1),
#  ('Ultraviolet', 27.0),
#  ('Battlefield Earth', 23.4),
#  ('Scary Movie 5', 20.8),
#  ('Alone in the Dark', 16.0)]

# %%
df = data
df=df.loc[:, ('Horror', 'runtime_interval', 'review_score_interval', 'tomatometer_rating_interval', 'movie_title', 'release_decade_interval', 'production_company')]




clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.7, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'Horror', 'type': 'one', 'value': 'True'},
                        {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'release_decade_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':3, 'maxlen':4, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 3412, rules 29,control number:0, times: prep 26.0899760723114, processing 4.855337858200073
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 3412
# Number of rules : 29
# Total time needed : 00h 00m 30s
# Time of data preparation : 00h 00m 26s
# Time of rule mining : 00h 00m 04s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1   186 0.715 +0.956 Horror(True) & runtime_interval(1.5-1.75h) & production_company(Focus Features) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      2   104 0.703 +0.921 Horror(True) & runtime_interval(1.75-2h) & production_company(Overture Films) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      3    75 0.701 +0.917 Horror(True) & runtime_interval(1.75-2h) & production_company(Picturehouse) => review_score_interval(70-90) | ---
#      4    75 0.701 +0.917 Horror(True) & runtime_interval(1.75-2h) & production_company(Picturehouse) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      5    54 0.711 +6.521 Horror(True) & runtime_interval(1.75-2h) & production_company(Royal Films International) => review_score_interval(>90) | ---
#      6    54 0.711 +6.521 Horror(True) & runtime_interval(1.75-2h) & production_company(Royal Films International) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#      7    54 0.711 +6.521 Horror(True) & production_company(Royal Films International) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#      8   128 0.707 +0.934 runtime_interval(1.5-1.75h) & production_company(Bad Robot Productions) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      9    51 0.773 +1.113 runtime_interval(1.5-1.75h) & production_company(Independent Films) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     10    97 0.770 +7.149 runtime_interval(1.5-1.75h) & production_company(Janus Films) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     11    62 0.705 +0.926 runtime_interval(1.5-1.75h) & production_company(Motto Pictures) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     12    64 0.753 +6.970 runtime_interval(1.5-1.75h) & production_company(Warner Bros. Pictures) & release_decade_interval(1930's) => review_score_interval(>90) | ---
#     13    83 0.716 +0.956 runtime_interval(1.5-1.75h) & production_company(s) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     14    64 0.762 +1.083 runtime_interval(1.75-2h) & production_company(Big World Pictures) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     15    54 0.711 +6.521 runtime_interval(1.75-2h) & production_company(Royal Films International) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#     16    52 0.722 +0.975 runtime_interval(1.75-2h) & production_company(levelFILM) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     17    89 0.718 +6.598 runtime_interval(2-2.5) & production_company(20th Century Fox) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#     18    53 0.736 +1.013 runtime_interval(2-2.5) & production_company(Kino International) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     19    53 0.791 +7.374 runtime_interval(2-2.5) & production_company(Paramount Pictures) & release_decade_interval(1920's) => review_score_interval(>90) | ---
#     20   102 0.729 +0.992 runtime_interval(<1.5h) & production_company(Fireworks Pictures) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     21    73 0.730 +6.728 runtime_interval(<1.5h) & production_company(Janus Films) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     22    99 0.733 +1.005 runtime_interval(<1.5h) & production_company(Newmarket Films) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     23    83 0.722 +0.973 runtime_interval(<1.5h) & production_company(Paladin Pictures) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     24    61 0.726 +0.986 runtime_interval(<1.5h) & production_company(Race Point Films) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     25    86 0.717 +9.296 runtime_interval(<1.5h) & production_company(Sony) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#     26    50 0.704 +0.926 runtime_interval(<1.5h) & production_company(Think Film) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     27   112 0.842 +7.914 runtime_interval(>2.5h) & production_company(Columbia Pictures) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     28   130 0.802 +7.495 runtime_interval(>2.5h) & production_company(Paramount Pictures) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#     29    76 0.760 +7.045 runtime_interval(>2.5h) & production_company(Rialto Pictures) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#
#
#
# Rule id : 2
#
# Base :   104  Relative base : 0.000  CONF : 0.703  AAD : +0.921  BAD : -0.921
#
# Cedents:
#   antecedent : Horror(True) & runtime_interval(1.75-2h) & production_company(Overture Films) & release_decade_interval(2010's)
#   succcedent : review_score_interval(70-90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |  104|   44|
# ----|-----|-----|
# ¬A  |245080|425183|
# ----|-----|-----|

# %% [markdown]
# ## Bonus: Nicolas Cage

# %%
pd.set_option('display.max_columns', None)
data.head(1)
# Out:
#                                                             movie_title  \
# rotten_tomatoes_link
# m/0814255             Percy Jackson & the Olympians: The Lightning T...
#
#                      content_rating  \
# rotten_tomatoes_link
# m/0814255                        PG
#
#                                                                  genres  \
# rotten_tomatoes_link
# m/0814255             [Action & Adventure, Comedy, Drama, Science Fi...
#
#                            directors  \
# rotten_tomatoes_link
# m/0814255             Chris Columbus
#
#                                                          authors  \
# rotten_tomatoes_link
# m/0814255             Craig Titley, Chris Columbus, Rick Riordan
#
#                                                                  actors  \
# rotten_tomatoes_link
# m/0814255             [Logan Lerman, Brandon T. Jackson, Alexandra D...
#
#                      original_release_date streaming_release_date  runtime  \
# rotten_tomatoes_link
# m/0814255                       2010-02-12             2015-11-25    119.0
#
#                      production_company tomatometer_status  \
# rotten_tomatoes_link
# m/0814255              20th Century Fox             Rotten
#
#                       tomatometer_rating  tomatometer_count audience_status  \
# rotten_tomatoes_link
# m/0814255                           49.0              149.0         Spilled
#
#                       audience_rating  audience_count  \
# rotten_tomatoes_link
# m/0814255                        53.0        254421.0
#
#                       tomatometer_top_critics_count  \
# rotten_tomatoes_link
# m/0814255                                        43
#
#                       tomatometer_fresh_critics_count  \
# rotten_tomatoes_link
# m/0814255                                          73
#
#                       tomatometer_rotten_critics_count   critic_name  \
# rotten_tomatoes_link
# m/0814255                                           76  Ben McEachen
#
#                       top_critic           publisher_name review_type  \
# rotten_tomatoes_link
# m/0814255                  False  Sunday Mail (Australia)       Fresh
#
#                       review_score review_date review_score_interval  \
# rotten_tomatoes_link
# m/0814255                     70.0  2010-02-09                 70-90
#
#                      audience_rating_interval tomatometer_rating_interval  \
# rotten_tomatoes_link
# m/0814255                               50-70                       30-50
#
#                      runtime_interval release_decade_interval  Horror
# rotten_tomatoes_link
# m/0814255                     1.75-2h                  2010's   False

# %%
def is_nicolas(row):
    if 'Nicolas Cage' in row['actors']:
        return True
    else: return False
data["nicolas cage"] = data.apply(is_nicolas, axis=1)

# %%
#JSOU FILMY S NICOLASEM CAGEM DOBRÉ?
df = data
df=df.loc[:, ('nicolas cage', 'runtime_interval', 'review_score_interval', 'release_decade_interval', 'production_company', 'content_rating')]




clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.4, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'nicolas cage', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':3, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 5145, rules 1546,control number:0, times: prep 4.47517991065979, processing 4.737284898757935
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 5145
# Number of rules : 1546
# Total time needed : 00h 00m 09s
# Time of data preparation : 00h 00m 04s
# Time of rule mining : 00h 00m 04s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1    55 0.500 +0.367 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(20th Century Fox Film Corporat) => review_score_interval(70-90) | ---
#      2   847 0.565 +0.546 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(A24) => review_score_interval(70-90) | ---
#      3   489 0.473 +0.294 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(A24 Films) => review_score_interval(70-90) | ---
#      4   302 0.411 +0.123 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(A24 and DIRECTV) => review_score_interval(70-90) | ---
#      5    53 0.510 +0.561 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(ATO Pictures) => review_score_interval(50-70) | ---
#      6   176 0.418 +0.143 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Amazon Studios) => review_score_interval(70-90) | ---
#      7    53 0.510 +0.393 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Amplify) => review_score_interval(70-90) | ---
#      8    90 0.439 +0.200 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Annapurna Pictures) => review_score_interval(70-90) | ---
#      9    56 0.609 +0.664 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Anonymous Content) => review_score_interval(70-90) | ---
#     10    51 0.411 +1.862 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Arc Entertainment) => review_score_interval(30-50) | ---
#     11    55 0.663 +0.812 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Arthouse Films) => review_score_interval(70-90) | ---
#     12    56 0.514 +0.574 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(BH Tilt) => review_score_interval(50-70) | ---
#     13   128 0.707 +0.934 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Bad Robot Productions) => review_score_interval(70-90) | ---
#     14    70 0.556 +0.519 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Blackbird Films) => review_score_interval(70-90) | ---
#     15   156 0.479 +0.308 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Bleecker Street) => review_score_interval(70-90) | ---
#     16   114 0.613 +0.676 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Blumhouse Productions) => review_score_interval(70-90) | ---
#     17    50 0.595 +0.628 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Bright Moving Pictures Sweden) => review_score_interval(70-90) | ---
#     18    99 0.508 +0.555 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Broad Green Pictures) => review_score_interval(50-70) | ---
#     19    62 0.477 +0.461 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Broken Road Productions) => review_score_interval(50-70) | ---
#     20   618 0.403 +0.233 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Buena Vista) => review_score_interval(50-70) | ---
#     21    55 0.529 +0.446 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Buena Vista Internationa) => review_score_interval(70-90) | ---
#     22    54 0.675 +0.846 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(CG Cinéma) => review_score_interval(70-90) | ---
#     23    74 0.627 +0.715 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Castle Rock Entertainment) => review_score_interval(70-90) | ---
#     24   208 0.474 +0.296 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Cinedigm) => review_score_interval(70-90) | ---
#     25    80 0.571 +0.562 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Cinema Guild) => review_score_interval(70-90) | ---
#     26    77 0.438 +0.340 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Clarius Entertainment) => review_score_interval(50-70) | ---
#     27   290 0.450 +0.229 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Cohen Media Group) => review_score_interval(70-90) | ---
#     28    51 0.472 +0.446 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Crescendo Productions) => review_score_interval(50-70) | ---
#     29   293 0.484 +0.324 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Criterion Collection) => review_score_interval(70-90) | ---
#     30    50 0.435 +0.332 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Dada Films) => review_score_interval(50-70) | ---
#     31    68 0.417 +0.141 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Dark Sky Films) => review_score_interval(70-90) | ---
#     32   131 0.450 +0.379 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Disney) => review_score_interval(50-70) | ---
#     33   461 0.507 +0.387 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Disney/Pixar) => review_score_interval(70-90) | ---
#     34   369 0.562 +0.536 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Drafthouse Films) => review_score_interval(70-90) | ---
#     35   298 0.522 +0.598 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(DreamWorks Animation) => review_score_interval(50-70) | ---
#     36   329 0.416 +0.274 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(DreamWorks SKG) => review_score_interval(50-70) | ---
#     37    76 0.628 +0.717 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(DreamWorks/Paramount Distribution) => review_score_interval(70-90) | ---
#     38    81 0.544 +0.665 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Dreamworks Pictures) => review_score_interval(50-70) | ---
#     39    58 0.580 +0.586 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(El Deseo) => review_score_interval(70-90) | ---
#     40   109 0.476 +0.458 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Entertainment One) => review_score_interval(50-70) | ---
#     41   101 0.479 +0.309 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Eone Films) => review_score_interval(70-90) | ---
#     42    60 0.526 +0.439 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Exhibition On Screen) => review_score_interval(70-90) | ---
#     43   105 0.625 +0.709 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Film 44) => review_score_interval(70-90) | ---
#     44    80 0.412 +1.870 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Film District) => review_score_interval(30-50) | ---
#     45   220 0.455 +0.243 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Film Movement) => review_score_interval(70-90) | ---
#     46    59 0.480 +0.469 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(FilmNation Entertainment) => review_score_interval(50-70) | ---
#     47    50 0.407 +0.112 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(FilmNation Entertainment) => review_score_interval(70-90) | ---
#     48   114 0.570 +0.559 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(FilmRise) => review_score_interval(70-90) | ---
#     49   174 0.415 +0.135 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Fine Line Features) => review_score_interval(70-90) | ---
#     50    73 0.553 +0.512 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Fingerprint Releasing and Bleecker Street) => review_score_interval(70-90) | ---
#     51   191 0.537 +0.467 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(First Look Pictures) => review_score_interval(70-90) | ---
#     52   267 0.520 +0.423 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(First Run Features) => review_score_interval(70-90) | ---
#     53  2372 0.424 +0.159 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Focus Features) => review_score_interval(70-90) | ---
#     54   126 0.458 +0.403 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Fox Atomic) => review_score_interval(50-70) | ---
#     55  1348 0.443 +0.210 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Fox Searchlight) => review_score_interval(70-90) | ---
#     56  1377 0.456 +0.248 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Fox Searchlight Pictures) => review_score_interval(70-90) | ---
#     57    75 0.475 +0.454 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Fox Walden) => review_score_interval(50-70) | ---
#     58   238 0.571 +0.561 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(GKIDS) => review_score_interval(70-90) | ---
#     59    92 0.554 +0.515 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Good Deed Entertainment) => review_score_interval(70-90) | ---
#     60    84 0.641 +0.753 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Greenwich Entertainment) => review_score_interval(70-90) | ---
#     61    98 0.636 +0.740 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Gunpowder & Sky) => review_score_interval(70-90) | ---
#     62    87 0.592 +0.618 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(HBO Films) => review_score_interval(70-90) | ---
#     63    55 0.519 +0.589 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(IDP) => review_score_interval(50-70) | ---
#     64    72 0.453 +0.238 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(IDP Films) => review_score_interval(70-90) | ---
#     65   119 0.416 +0.274 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(IDP/Samuel goldwyn Films) => review_score_interval(50-70) | ---
#     66   137 0.455 +0.245 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(IFC) => review_score_interval(70-90) | ---
#     67  3135 0.457 +0.250 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(IFC Films) => review_score_interval(70-90) | ---
#     68   142 0.415 +0.135 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(IFC First Take) => review_score_interval(70-90) | ---
#     69   196 0.471 +0.288 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(IFC Midnight) => review_score_interval(70-90) | ---
#     70    80 0.510 +0.393 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Ideaman Studios) => review_score_interval(70-90) | ---
#     71   125 0.403 +0.235 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Image Entertainment) => review_score_interval(50-70) | ---
#     72    51 0.773 +1.113 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Independent Films) => review_score_interval(70-90) | ---
#     73   269 0.469 +0.281 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Independent Pictures) => review_score_interval(70-90) | ---
#     74    83 0.638 +0.746 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(International Film Circuit) => review_score_interval(70-90) | ---
#     75   114 0.525 +4.561 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Janus Films) => review_score_interval(>90) | ---
#     76    64 0.640 +0.960 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Keep Your Head) => review_score_interval(50-70) | ---
#     77   107 0.491 +0.342 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Kino International) => review_score_interval(70-90) | ---
#     78   201 0.588 +0.607 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Kino Lorber) => review_score_interval(70-90) | ---
#     79    98 0.490 +0.340 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Kino Lorber Films) => review_score_interval(70-90) | ---
#     80    63 0.477 +0.305 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(LD Entertainment/Lionsgate/Roadside Attractions) => review_score_interval(70-90) | ---
#     81    56 0.403 +0.234 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Lions Gate) => review_score_interval(50-70) | ---
#     82   138 0.690 +0.887 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Lions Gate Films Inc.) => review_score_interval(70-90) | ---
#     83   191 0.468 +0.280 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Lions Gate Releasing) => review_score_interval(70-90) | ---
#     84    61 0.535 +0.639 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Lionsgate Pictures) => review_score_interval(50-70) | ---
#     85   172 0.400 +0.225 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Lionsgate Premiere) => review_score_interval(50-70) | ---
#     86    55 0.509 +0.392 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(MCA/Universal Pictures) => review_score_interval(70-90) | ---
#     87    62 0.544 +0.487 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(MGM/Dimension) => review_score_interval(70-90) | ---
#     88   102 0.630 +8.046 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(MGM/UA Distribution Company) => review_score_interval(<30) | ---
#     89   163 0.424 +0.300 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Magnet Releasing) => review_score_interval(50-70) | ---
#     90    72 0.533 +0.458 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Magnolia) => review_score_interval(70-90) | ---
#     91  1945 0.432 +0.182 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Magnolia Pictures) => review_score_interval(70-90) | ---
#     92   183 0.415 +0.135 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Millenium Entertainment) => review_score_interval(70-90) | ---
#     93  1597 0.426 +0.166 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Miramax Films) => review_score_interval(70-90) | ---
#     94    58 0.492 +0.505 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Mirimax Films) => review_score_interval(50-70) | ---
#     95   112 0.432 +0.324 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Momentum Pictures) => review_score_interval(50-70) | ---
#     96    62 0.705 +0.926 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Motto Pictures) => review_score_interval(70-90) | ---
#     97   681 0.551 +0.507 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Music Box Films) => review_score_interval(70-90) | ---
#     98   288 0.549 +0.500 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(NEON) => review_score_interval(70-90) | ---
#     99   123 0.612 +0.673 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(National Geographic) => review_score_interval(70-90) | ---
#    100    63 0.401 +0.097 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(NeoClassics Films) => review_score_interval(70-90) | ---
#    101   322 0.405 +0.106 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Netflix) => review_score_interval(70-90) | ---
#    102    74 0.622 +0.700 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(New Video) => review_score_interval(70-90) | ---
#    103    76 0.420 +0.286 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Orion Home Video) => review_score_interval(50-70) | ---
#    104    77 0.464 +0.268 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Oscilloscope Laboratories) => review_score_interval(70-90) | ---
#    105   223 0.521 +0.425 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Oscilloscope Pictures) => review_score_interval(70-90) | ---
#    106   262 0.556 +0.521 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Palm Pictures) => review_score_interval(70-90) | ---
#    107   288 0.478 +0.463 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount) => review_score_interval(50-70) | ---
#    108   407 0.428 +0.169 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount Classics) => review_score_interval(70-90) | ---
#    109   164 0.448 +0.225 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount Studios) => review_score_interval(70-90) | ---
#    110    58 0.457 +0.399 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount Studios/DWA) => review_score_interval(50-70) | ---
#    111    61 0.480 +0.313 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount Studios/DWA) => review_score_interval(70-90) | ---
#    112    66 0.516 +0.410 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount Studios/Dreamworks) => review_score_interval(70-90) | ---
#    113   348 0.462 +0.262 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount Vantage) => review_score_interval(70-90) | ---
#    114    93 0.660 +0.803 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount/DWA) => review_score_interval(70-90) | ---
#    115    67 0.632 +0.728 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount/Dreamworks) => review_score_interval(70-90) | ---
#    116    62 0.416 +0.274 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount/Dreamworks Animation) => review_score_interval(50-70) | ---
#    117    69 0.463 +0.266 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Paramount/Dreamworks Animation) => review_score_interval(70-90) | ---
#    118    68 0.496 +0.520 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Perdido Productions) => review_score_interval(50-70) | ---
#    119   120 0.632 +0.727 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Petit Film) => review_score_interval(70-90) | ---
#    120   353 0.473 +0.292 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Picturehouse) => review_score_interval(70-90) | ---
#    121    66 0.532 +0.455 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Picturehouse Films) => review_score_interval(70-90) | ---
#    122    70 0.603 +0.650 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Piki Films) => review_score_interval(70-90) | ---
#    123    63 0.573 +0.566 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Rachael Horovitz Productions) => review_score_interval(70-90) | ---
#    124    54 0.432 +0.181 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Radius) => review_score_interval(70-90) | ---
#    125   496 0.451 +0.234 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Radius-TWC) => review_score_interval(70-90) | ---
#    126   135 0.515 +4.454 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Rialto Pictures) => review_score_interval(>90) | ---
#    127  1289 0.502 +0.371 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Roadside Attractions) => review_score_interval(70-90) | ---
#    128    59 0.694 +0.898 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Rogue Pictures) => review_score_interval(70-90) | ---
#    129    54 0.458 +2.185 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Rogue Pictures/Universal Studios) => review_score_interval(30-50) | ---
#    130    52 0.627 +0.713 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(SHOUT! STUDIOS) => review_score_interval(70-90) | ---
#    131   653 0.415 +0.136 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Samuel Goldwyn Films) => review_score_interval(70-90) | ---
#    132   122 0.601 +0.643 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Scott Rudin Productions) => review_score_interval(70-90) | ---
#    133   224 0.405 +0.241 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Screen Media Films) => review_score_interval(50-70) | ---
#    134    82 0.522 +0.600 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Skydance Films) => review_score_interval(50-70) | ---
#    135    78 0.473 +0.448 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Smokehouse Pictures) => review_score_interval(50-70) | ---
#    136   124 0.582 +0.592 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Sony Classic Pictures) => review_score_interval(70-90) | ---
#    137   114 0.585 +0.599 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Sony Classics) => review_score_interval(70-90) | ---
#    138    51 0.543 +0.662 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Sony Films) => review_score_interval(50-70) | ---
#    139    60 0.588 +0.608 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Sony Picture Classics) => review_score_interval(70-90) | ---
#    140  3795 0.498 +0.363 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Sony Pictures Classics) => review_score_interval(70-90) | ---
#    141    70 0.464 +0.268 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Starburns Industries) => review_score_interval(70-90) | ---
#    142   455 0.421 +0.151 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Strand Releasing) => review_score_interval(70-90) | ---
#    143   439 0.403 +0.234 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Summit Entertainment) => review_score_interval(50-70) | ---
#    144   264 0.526 +0.438 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Sundance Selects) => review_score_interval(70-90) | ---
#    145    89 0.454 +0.391 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(The Film Arcade) => review_score_interval(50-70) | ---
#    146   239 0.498 +0.361 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(The Orchard) => review_score_interval(70-90) | ---
#    147   318 0.426 +0.166 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(The Weinstein Co.) => review_score_interval(70-90) | ---
#    148  1119 0.428 +0.171 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(The Weinstein Company) => review_score_interval(70-90) | ---
#    149   313 0.448 +0.224 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(ThinkFilm) => review_score_interval(70-90) | ---
#    150    92 0.413 +0.264 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Tribeca Film) => review_score_interval(50-70) | ---
#    151   186 0.491 +0.342 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Tribeca Films) => review_score_interval(70-90) | ---
#    152    50 0.427 +0.169 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Turner Home Entertainment) => review_score_interval(70-90) | ---
#    153   222 0.453 +0.239 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(USA Films) => review_score_interval(70-90) | ---
#    154    87 0.613 +0.675 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(United Artists Pictures) => review_score_interval(70-90) | ---
#    155    86 0.404 +1.810 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Universal) => review_score_interval(30-50) | ---
#    156    51 0.405 +0.107 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Variance Films) => review_score_interval(70-90) | ---
#    157    77 0.475 +0.456 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Vestron Video) => review_score_interval(50-70) | ---
#    158    51 0.432 +0.324 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Vivendi Entertainment) => review_score_interval(50-70) | ---
#    159  1629 0.402 +0.100 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Walt Disney Pictures) => review_score_interval(70-90) | ---
#    160   137 0.688 +0.882 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Walt Disney Pictures/PIXAR) => review_score_interval(70-90) | ---
#    161    70 0.493 +0.510 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Walt Disney Studios) => review_score_interval(50-70) | ---
#    162   104 0.528 +0.617 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Warner Bros. Pictures/Village Roadshow) => review_score_interval(50-70) | ---
#    163   142 0.504 +0.542 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Warner Independent) => review_score_interval(50-70) | ---
#    164   244 0.425 +0.162 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Warner Independent Pictures) => review_score_interval(70-90) | ---
#    165    60 0.545 +0.671 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Warners Bros. Pictures) => review_score_interval(50-70) | ---
#    166   241 0.433 +0.183 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Weinstein Company) => review_score_interval(70-90) | ---
#    167    83 0.466 +0.428 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Well Go USA) => review_score_interval(50-70) | ---
#    168    53 0.546 +0.494 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Wolfe Releasing) => review_score_interval(70-90) | ---
#    169    56 0.438 +0.340 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Yari Film Group) => review_score_interval(50-70) | ---
#    170   237 0.535 +0.463 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(Zeitgeist Films) => review_score_interval(70-90) | ---
#    171    85 0.720 +0.970 nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(s) => review_score_interval(70-90) | ---
#    172    66 0.508 +0.388 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(20th Century Fox Film Corporation) => review_score_interval(70-90) | ---
#    173   102 0.537 +0.644 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(20th Century Fox/Regency Films) => review_score_interval(50-70) | ---
#    174   107 0.448 +0.224 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(21 Laps Entertainment) => review_score_interval(70-90) | ---
#    175   109 0.456 +3.828 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(21 Laps Entertainment) => review_score_interval(>90) | ---
#    176   447 0.494 +0.352 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(A24) => review_score_interval(70-90) | ---
#    177   365 0.502 +0.373 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(A24 Films) => review_score_interval(70-90) | ---
#    178   135 0.413 +0.264 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(A24 and DIRECTV) => review_score_interval(50-70) | ---
#    179    56 0.500 +0.531 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Alchemy) => review_score_interval(50-70) | ---
#    180    90 0.405 +0.242 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Amazon Studios) => review_score_interval(50-70) | ---
#    181    94 0.423 +0.158 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Amazon Studios) => review_score_interval(70-90) | ---
#    182   280 0.543 +0.484 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Annapurna Pictures) => review_score_interval(70-90) | ---
#    183    81 0.405 +0.240 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Apparition) => review_score_interval(50-70) | ---
#    184    86 0.430 +0.176 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Apparition) => review_score_interval(70-90) | ---
#    185    62 0.579 +0.584 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Apparition Films) => review_score_interval(70-90) | ---
#    186   229 0.513 +0.404 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Artisan Entertainment) => review_score_interval(70-90) | ---
#    187    50 0.633 +0.731 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Artisan Pictures) => review_score_interval(70-90) | ---
#    188    87 0.617 +0.687 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(BBC Films) => review_score_interval(70-90) | ---
#    189    71 0.747 +1.044 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Big World Pictures) => review_score_interval(70-90) | ---
#    190   323 0.493 +0.348 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Bleecker Street) => review_score_interval(70-90) | ---
#    191    50 0.442 +0.355 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Bleecker Street / Participant Media.) => review_score_interval(50-70) | ---
#    192    51 0.451 +0.234 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Bleecker Street / Participant Media.) => review_score_interval(70-90) | ---
#    193    87 0.458 +0.252 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Broad Green Pictures) => review_score_interval(70-90) | ---
#    194   131 0.575 +0.571 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Buena Vista Internationa) => review_score_interval(70-90) | ---
#    195   460 0.452 +0.236 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(CBS Films) => review_score_interval(70-90) | ---
#    196   109 0.418 +0.279 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(CBS Films and Lionsgate) => review_score_interval(50-70) | ---
#    197   124 0.475 +0.299 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(CBS Films and Lionsgate) => review_score_interval(70-90) | ---
#    198   140 0.651 +0.780 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Cinema Guild) => review_score_interval(70-90) | ---
#    199   222 0.407 +0.248 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Cohen Media Group) => review_score_interval(50-70) | ---
#    200   123 0.486 +0.329 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Criterion Collection) => review_score_interval(70-90) | ---
#    201    98 0.478 +0.464 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Dimension Films) => review_score_interval(50-70) | ---
#    202    55 0.430 +0.316 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Disney) => review_score_interval(50-70) | ---
#    203   116 0.571 +0.562 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Disney/Marvel) => review_score_interval(70-90) | ---
#    204   409 0.550 +0.503 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Disney/Pixar) => review_score_interval(70-90) | ---
#    205    60 0.513 +0.402 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Dog Eat Dog Films) => review_score_interval(70-90) | ---
#    206    66 0.482 +0.317 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Drafthouse Films) => review_score_interval(70-90) | ---
#    207    56 0.467 +0.276 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Drafthouse Recommends) => review_score_interval(70-90) | ---
#    208    55 0.458 +3.852 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Drafthouse Recommends) => review_score_interval(>90) | ---
#    209    56 0.475 +0.453 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(DreamWorks Studios) => review_score_interval(50-70) | ---
#    210   170 0.572 +0.565 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(DreamWorks/Paramount Studios) => review_score_interval(70-90) | ---
#    211    88 0.456 +0.396 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Dreamworks) => review_score_interval(50-70) | ---
#    212    80 0.415 +0.133 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Dreamworks) => review_score_interval(70-90) | ---
#    213   144 0.465 +0.423 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Dreamworks Distribution LLC) => review_score_interval(50-70) | ---
#    214   204 0.408 +0.250 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Dreamworks/Paramount) => review_score_interval(50-70) | ---
#    215   214 0.428 +0.170 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Dreamworks/Paramount) => review_score_interval(70-90) | ---
#    216    74 0.548 +0.499 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Electric City Entertainment) => review_score_interval(70-90) | ---
#    217   192 0.519 +0.419 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Element Pictures) => review_score_interval(70-90) | ---
#    218    84 0.418 +0.280 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Embargo Films) => review_score_interval(50-70) | ---
#    219   228 0.549 +0.502 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Film Movement) => review_score_interval(70-90) | ---
#    220    58 0.586 +0.602 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Film Science) => review_score_interval(70-90) | ---
#    221    57 0.648 +0.984 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Film4) => review_score_interval(50-70) | ---
#    222   117 0.401 +0.227 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(FilmDistrict) => review_score_interval(50-70) | ---
#    223   139 0.509 +0.392 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Fine Line Features) => review_score_interval(70-90) | ---
#    224   115 0.697 +0.906 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Fingerprint Releasing / Bleecker Street) => review_score_interval(70-90) | ---
#    225  1924 0.435 +0.190 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Focus Features) => review_score_interval(70-90) | ---
#    226   806 0.456 +0.246 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Fox Searchlight) => review_score_interval(70-90) | ---
#    227  1756 0.471 +0.289 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Fox Searchlight Pictures) => review_score_interval(70-90) | ---
#    228   100 0.592 +0.618 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(GKIDS) => review_score_interval(70-90) | ---
#    229   140 0.524 +0.434 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Gramercy Pictures) => review_score_interval(70-90) | ---
#    230    92 0.554 +0.515 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Hollywood/Buena Vista) => review_score_interval(70-90) | ---
#    231   154 0.556 +0.520 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(IFC) => review_score_interval(70-90) | ---
#    232  1474 0.446 +0.218 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(IFC Films) => review_score_interval(70-90) | ---
#    233   131 0.530 +0.450 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(IFC First Take) => review_score_interval(70-90) | ---
#    234   131 0.567 +0.551 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(IFC Midnight) => review_score_interval(70-90) | ---
#    235   100 0.407 +0.112 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Illumination Entertainment) => review_score_interval(70-90) | ---
#    236    59 0.418 +0.144 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Independent Pictures) => review_score_interval(70-90) | ---
#    237   102 0.596 +5.314 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(June Pictures) => review_score_interval(>90) | ---
#    238    73 0.521 +0.426 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(K5 International) => review_score_interval(70-90) | ---
#    239    56 0.400 +3.234 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(K5 International) => review_score_interval(>90) | ---
#    240    57 0.413 +0.265 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Kino Lorber) => review_score_interval(50-70) | ---
#    241    73 0.525 +0.436 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Kino Lorber Films) => review_score_interval(70-90) | ---
#    242   218 0.653 +0.785 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Likely Story) => review_score_interval(70-90) | ---
#    243   221 0.637 +0.741 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Lions Gate) => review_score_interval(70-90) | ---
#    244    70 0.432 +0.323 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Lionsgate Pictures) => review_score_interval(50-70) | ---
#    245    52 0.547 +0.497 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Lionsgate Releasing) => review_score_interval(70-90) | ---
#    246    50 0.431 +0.320 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Lionsgate and CBS Films) => review_score_interval(50-70) | ---
#    247   199 0.594 +0.624 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Lionsgate and Roadside Attractions) => review_score_interval(70-90) | ---
#    248    85 0.578 +0.581 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Lionsgate/Roadside Attractions) => review_score_interval(70-90) | ---
#    249   194 0.564 +0.727 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Lionsgate/Summit Entertainment) => review_score_interval(50-70) | ---
#    250   110 0.410 +0.122 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Live Home Video) => review_score_interval(70-90) | ---
#    251    52 0.500 +0.367 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(MGM Distribution) => review_score_interval(70-90) | ---
#    252    75 0.528 +0.618 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(MGM Distribution Company) => review_score_interval(50-70) | ---
#    253    58 0.667 +0.823 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(MGM/Sidney Kimmel Entertainment) => review_score_interval(70-90) | ---
#    254   259 0.443 +0.358 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(MGM/UA) => review_score_interval(50-70) | ---
#    255    74 0.679 +0.856 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(MTV Films) => review_score_interval(70-90) | ---
#    256    75 0.620 +0.695 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Magnet/Magnolia Pictures) => review_score_interval(70-90) | ---
#    257    77 0.562 +0.537 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Magnolia) => review_score_interval(70-90) | ---
#    258  1251 0.442 +0.207 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Magnolia Pictures) => review_score_interval(70-90) | ---
#    259    72 0.541 +0.480 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Manhattan Pictures Internation) => review_score_interval(70-90) | ---
#    260  1474 0.463 +0.265 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Miramax Films) => review_score_interval(70-90) | ---
#    261   458 0.586 +0.603 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Music Box Films) => review_score_interval(70-90) | ---
#    262    55 0.567 +0.550 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(NCM Fathom) => review_score_interval(70-90) | ---
#    263   529 0.537 +0.467 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(NEON) => review_score_interval(70-90) | ---
#    264   471 0.430 +0.175 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Netflix) => review_score_interval(70-90) | ---
#    265    55 0.491 +0.343 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(New Line) => review_score_interval(70-90) | ---
#    266  1195 0.405 +0.239 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(New Line Cinema) => review_score_interval(50-70) | ---
#    267    93 0.500 +0.367 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Newmarket Film Group) => review_score_interval(70-90) | ---
#    268    63 0.404 +0.104 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Newmarket Films) => review_score_interval(70-90) | ---
#    269    57 0.496 +0.355 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Orion Pictures) => review_score_interval(70-90) | ---
#    270   105 0.407 +0.113 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Orion Pictures Corporation) => review_score_interval(70-90) | ---
#    271   106 0.411 +3.349 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Orion Pictures Corporation) => review_score_interval(>90) | ---
#    272   164 0.571 +0.562 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Oscilloscope Laboratories) => review_score_interval(70-90) | ---
#    273   176 0.525 +0.437 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Oscilloscope Pictures) => review_score_interval(70-90) | ---
#    274   109 0.458 +0.252 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Palm Pictures) => review_score_interval(70-90) | ---
#    275   302 0.479 +0.309 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Paramount Classics) => review_score_interval(70-90) | ---
#    276   338 0.466 +0.428 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Paramount Studios) => review_score_interval(50-70) | ---
#    277   211 0.429 +0.173 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Paramount Vantage) => review_score_interval(70-90) | ---
#    278    56 0.415 +0.134 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Phase 4 Films) => review_score_interval(70-90) | ---
#    279   227 0.444 +0.215 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Picturehouse) => review_score_interval(70-90) | ---
#    280    61 0.427 +0.166 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Radius-TWC) => review_score_interval(70-90) | ---
#    281    78 0.417 +0.277 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Regent Releasing) => review_score_interval(50-70) | ---
#    282   610 0.412 +0.263 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Relativity Media) => review_score_interval(50-70) | ---
#    283    67 0.444 +3.697 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Rialto Pictures) => review_score_interval(>90) | ---
#    284   727 0.421 +0.152 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Roadside Attractions) => review_score_interval(70-90) | ---
#    285   105 0.565 +0.544 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Roadside Attractions/LD Entertainment) => review_score_interval(70-90) | ---
#    286    79 0.403 +0.234 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Rogue Pictures) => review_score_interval(50-70) | ---
#    287    54 0.711 +6.521 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Royal Films International) => review_score_interval(>90) | ---
#    288   240 0.423 +0.155 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(STX Entertainment) => review_score_interval(70-90) | ---
#    289   182 0.550 +0.503 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(STXfilms) => review_score_interval(70-90) | ---
#    290   134 0.411 +0.259 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Saban Films) => review_score_interval(50-70) | ---
#    291   144 0.447 +0.370 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Screen Gems) => review_score_interval(50-70) | ---
#    292    96 0.686 +0.875 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Shudder and NEON) => review_score_interval(70-90) | ---
#    293   142 0.594 +0.625 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sony Classics) => review_score_interval(70-90) | ---
#    294    80 0.630 +0.722 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sony Picture Classics) => review_score_interval(70-90) | ---
#    295  2481 0.487 +0.332 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sony Pictures Classics) => review_score_interval(70-90) | ---
#    296   214 0.459 +0.406 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sony Pictures Releasing) => review_score_interval(50-70) | ---
#    297   162 0.418 +0.142 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sony Pictures/Columbia) => review_score_interval(70-90) | ---
#    298   105 0.449 +0.374 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sony/Columbia) => review_score_interval(50-70) | ---
#    299    77 0.507 +0.552 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sony/Columbia Pictures) => review_score_interval(50-70) | ---
#    300   162 0.450 +0.378 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sony/MGM) => review_score_interval(50-70) | ---
#    301   156 0.433 +0.185 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sony/MGM) => review_score_interval(70-90) | ---
#    302   159 0.452 +0.235 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Strand Releasing) => review_score_interval(70-90) | ---
#    303    99 0.611 +0.671 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Sundance Selects) => review_score_interval(70-90) | ---
#    304    71 0.530 +0.449 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Tartan Films) => review_score_interval(70-90) | ---
#    305    62 0.585 +0.599 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(Tartan USA) => review_score_interval(70-90) | ---
#    306    60 0.556 +0.702 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(The Film District) => review_score_interval(50-70) | ---
#    307   164 0.571 +0.562 nicolas cage(False) & runtime_interval(1.75-2h) & production_company(The Orchard) => review_score_interval(70-90) | ---
# ...
#   1425    74 0.457 +0.249 runtime_interval(<1.5h) & production_company(Anchor Bay Films) => review_score_interval(70-90) | ---
#   1426   151 0.627 +0.713 runtime_interval(<1.5h) & production_company(Balcony Releasing) => review_score_interval(70-90) | ---
#   1427    59 0.546 +0.494 runtime_interval(<1.5h) & production_company(Buena Vista Distribution) => review_score_interval(70-90) | ---
#   1428   105 0.583 +0.595 runtime_interval(<1.5h) & production_company(Cinema Guild) => review_score_interval(70-90) | ---
#   1429    75 0.439 +0.343 runtime_interval(<1.5h) & production_company(Cinema Libre) => review_score_interval(50-70) | ---
#   1430    61 0.409 +0.119 runtime_interval(<1.5h) & production_company(Cohen Media Group) => review_score_interval(70-90) | ---
#   1431   157 0.412 +3.362 runtime_interval(<1.5h) & production_company(Criterion Collection) => review_score_interval(>90) | ---
#   1432    58 0.586 +0.794 runtime_interval(<1.5h) & production_company(DJ Films) => review_score_interval(50-70) | ---
#   1433    89 0.459 +0.254 runtime_interval(<1.5h) & production_company(Dark Sky Films) => review_score_interval(70-90) | ---
#   1434    57 0.491 +0.505 runtime_interval(<1.5h) & production_company(DreamWorks Animation) => review_score_interval(50-70) | ---
#   1435   216 0.484 +0.483 runtime_interval(<1.5h) & production_company(DreamWorks SKG) => review_score_interval(50-70) | ---
#   1436   425 0.537 +0.467 runtime_interval(<1.5h) & production_company(Dreamworks) => review_score_interval(70-90) | ---
#   1437    50 0.490 +0.340 runtime_interval(<1.5h) & production_company(Empire Pictures) => review_score_interval(70-90) | ---
#   1438    71 0.444 +0.359 runtime_interval(<1.5h) & production_company(Entertainment Studios Motion Pictures) => review_score_interval(50-70) | ---
#   1439   120 0.600 +0.641 runtime_interval(<1.5h) & production_company(Film District) => review_score_interval(70-90) | ---
#   1440   148 0.574 +0.569 runtime_interval(<1.5h) & production_company(Film Movement) => review_score_interval(70-90) | ---
#   1441   111 0.430 +0.176 runtime_interval(<1.5h) & production_company(Fine Line Features) => review_score_interval(70-90) | ---
#   1442   102 0.729 +0.992 runtime_interval(<1.5h) & production_company(Fireworks Pictures) => review_score_interval(70-90) | ---
#   1443    50 0.407 +0.112 runtime_interval(<1.5h) & production_company(First Look Pictures) => review_score_interval(70-90) | ---
#   1444   268 0.475 +0.299 runtime_interval(<1.5h) & production_company(First Run Features) => review_score_interval(70-90) | ---
#   1445   150 0.575 +0.571 runtime_interval(<1.5h) & production_company(GKIDS) => review_score_interval(70-90) | ---
#   1446    84 0.587 +0.606 runtime_interval(<1.5h) & production_company(Ghost House Pictures) => review_score_interval(70-90) | ---
#   1447    67 0.515 +0.409 runtime_interval(<1.5h) & production_company(Greenwich Entertainment) => review_score_interval(70-90) | ---
#   1448    60 0.414 +4.945 runtime_interval(<1.5h) & production_company(Hollywood Pictures) => review_score_interval(<30) | ---
#   1449    64 0.489 +0.496 runtime_interval(<1.5h) & production_company(IFC) => review_score_interval(50-70) | ---
#   1450  1405 0.472 +0.290 runtime_interval(<1.5h) & production_company(IFC Films) => review_score_interval(70-90) | ---
#   1451   105 0.430 +0.177 runtime_interval(<1.5h) & production_company(IFC First Take) => review_score_interval(70-90) | ---
#   1452   150 0.487 +0.332 runtime_interval(<1.5h) & production_company(Independent Pictures) => review_score_interval(70-90) | ---
#   1453    95 0.655 +5.935 runtime_interval(<1.5h) & production_company(Janus Films) => review_score_interval(>90) | ---
#   1454   102 0.531 +0.453 runtime_interval(<1.5h) & production_company(Kino International) => review_score_interval(70-90) | ---
#   1455   126 0.521 +0.424 runtime_interval(<1.5h) & production_company(Kino Lorber) => review_score_interval(70-90) | ---
#   1456    50 0.617 +0.688 runtime_interval(<1.5h) & production_company(Kissiki Film) => review_score_interval(70-90) | ---
#   1457   125 0.401 +0.095 runtime_interval(<1.5h) & production_company(Magnet Releasing) => review_score_interval(70-90) | ---
#   1458  1028 0.489 +0.337 runtime_interval(<1.5h) & production_company(Magnolia Pictures) => review_score_interval(70-90) | ---
#   1459    87 0.408 +0.117 runtime_interval(<1.5h) & production_company(Magnolia Releasing) => review_score_interval(70-90) | ---
#   1460   114 0.640 +0.751 runtime_interval(<1.5h) & production_company(Miramax and Roadside Attractions) => review_score_interval(70-90) | ---
#   1461   109 0.522 +0.426 runtime_interval(<1.5h) & production_company(Music Box Films) => review_score_interval(70-90) | ---
#   1462   135 0.553 +0.513 runtime_interval(<1.5h) & production_company(NEON) => review_score_interval(70-90) | ---
#   1463   257 0.580 +0.586 runtime_interval(<1.5h) & production_company(Netflix) => review_score_interval(70-90) | ---
#   1464    65 0.602 +0.646 runtime_interval(<1.5h) & production_company(New Yorker Films) => review_score_interval(70-90) | ---
#   1465    99 0.733 +1.005 runtime_interval(<1.5h) & production_company(Newmarket Films) => review_score_interval(70-90) | ---
#   1466    63 0.423 +0.295 runtime_interval(<1.5h) & production_company(Ombra Films) => review_score_interval(50-70) | ---
#   1467    68 0.456 +0.248 runtime_interval(<1.5h) & production_company(Ombra Films) => review_score_interval(70-90) | ---
#   1468   120 0.500 +0.367 runtime_interval(<1.5h) & production_company(Oscilloscope Laboratories) => review_score_interval(70-90) | ---
#   1469   282 0.495 +0.353 runtime_interval(<1.5h) & production_company(Oscilloscope Pictures) => review_score_interval(70-90) | ---
#   1470    83 0.722 +0.973 runtime_interval(<1.5h) & production_company(Paladin Pictures) => review_score_interval(70-90) | ---
#   1471    89 0.539 +0.475 runtime_interval(<1.5h) & production_company(Palm Pictures) => review_score_interval(70-90) | ---
#   1472   140 0.513 +0.402 runtime_interval(<1.5h) & production_company(Paramount) => review_score_interval(70-90) | ---
#   1473    84 0.402 +0.231 runtime_interval(<1.5h) & production_company(Paramount Studios) => review_score_interval(50-70) | ---
#   1474    51 0.537 +0.468 runtime_interval(<1.5h) & production_company(Paramount/Dreamworks) => review_score_interval(70-90) | ---
#   1475    74 0.468 +0.281 runtime_interval(<1.5h) & production_company(RLJE Films) => review_score_interval(70-90) | ---
#   1476    61 0.726 +0.986 runtime_interval(<1.5h) & production_company(Race Point Films) => review_score_interval(70-90) | ---
#   1477    79 0.427 +0.308 runtime_interval(<1.5h) & production_company(Radius-TWC) => review_score_interval(50-70) | ---
#   1478    77 0.416 +0.138 runtime_interval(<1.5h) & production_company(Radius-TWC) => review_score_interval(70-90) | ---
#   1479    52 0.426 +0.305 runtime_interval(<1.5h) & production_company(RatPac-Dune Entertainment) => review_score_interval(50-70) | ---
#   1480    52 0.426 +0.165 runtime_interval(<1.5h) & production_company(RatPac-Dune Entertainment) => review_score_interval(70-90) | ---
#   1481    76 0.415 +0.272 runtime_interval(<1.5h) & production_company(Regent Releasing) => review_score_interval(50-70) | ---
#   1482   225 0.446 +0.221 runtime_interval(<1.5h) & production_company(Roadside Attractions) => review_score_interval(70-90) | ---
#   1483   238 0.527 +0.440 runtime_interval(<1.5h) & production_company(Samuel Goldwyn Films) => review_score_interval(70-90) | ---
#   1484   148 0.567 +0.550 runtime_interval(<1.5h) & production_company(Shadow Distribution) => review_score_interval(70-90) | ---
#   1485    66 0.496 +0.520 runtime_interval(<1.5h) & production_company(Shout! Factory) => review_score_interval(50-70) | ---
#   1486    86 0.717 +9.296 runtime_interval(<1.5h) & production_company(Sony) => review_score_interval(<30) | ---
#   1487    56 0.415 +4.959 runtime_interval(<1.5h) & production_company(Sony Pictures Animation) => review_score_interval(<30) | ---
#   1488  1272 0.536 +0.464 runtime_interval(<1.5h) & production_company(Sony Pictures Classics) => review_score_interval(70-90) | ---
#   1489    60 0.488 +0.334 runtime_interval(<1.5h) & production_company(Sony Pictures/Screen Gems) => review_score_interval(70-90) | ---
#   1490    96 0.593 +0.620 runtime_interval(<1.5h) & production_company(Sony/Columbia Pictures) => review_score_interval(70-90) | ---
#   1491    60 0.619 +0.691 runtime_interval(<1.5h) & production_company(Studio Ghibli) => review_score_interval(70-90) | ---
#   1492   242 0.467 +0.277 runtime_interval(<1.5h) & production_company(Summit Entertainment) => review_score_interval(70-90) | ---
#   1493    54 0.568 +0.554 runtime_interval(<1.5h) & production_company(The Cinema Guild) => review_score_interval(70-90) | ---
#   1494   127 0.460 +0.258 runtime_interval(<1.5h) & production_company(The Film Arcade) => review_score_interval(70-90) | ---
#   1495    87 0.416 +0.275 runtime_interval(<1.5h) & production_company(The Orchard) => review_score_interval(50-70) | ---
#   1496    92 0.440 +0.204 runtime_interval(<1.5h) & production_company(The Orchard) => review_score_interval(70-90) | ---
#   1497    91 0.410 +0.255 runtime_interval(<1.5h) & production_company(The Weinstein Co.) => review_score_interval(50-70) | ---
#   1498    50 0.704 +0.926 runtime_interval(<1.5h) & production_company(Think Film) => review_score_interval(70-90) | ---
#   1499   216 0.461 +0.259 runtime_interval(<1.5h) & production_company(ThinkFilm) => review_score_interval(70-90) | ---
#   1500    57 0.792 +1.165 runtime_interval(<1.5h) & production_company(Tilapia Film) => review_score_interval(70-90) | ---
#   1501    80 0.462 +0.264 runtime_interval(<1.5h) & production_company(Tribeca Film) => review_score_interval(70-90) | ---
#   1502   267 0.412 +0.127 runtime_interval(<1.5h) & production_company(United Artists) => review_score_interval(70-90) | ---
#   1503    57 0.576 +0.763 runtime_interval(<1.5h) & production_company(United Artists Releasing) => review_score_interval(50-70) | ---
#   1504    58 0.563 +0.540 runtime_interval(<1.5h) & production_company(Universal Pictures/Rogue) => review_score_interval(70-90) | ---
#   1505    73 0.471 +0.288 runtime_interval(<1.5h) & production_company(Variance Films) => review_score_interval(70-90) | ---
#   1506    90 0.508 +0.390 runtime_interval(<1.5h) & production_company(Warner Bros Pictures) => review_score_interval(70-90) | ---
#   1507   105 0.420 +0.286 runtime_interval(<1.5h) & production_company(Warner Bros.) => review_score_interval(50-70) | ---
#   1508   191 0.503 +0.374 runtime_interval(<1.5h) & production_company(Warner Independent Pictures) => review_score_interval(70-90) | ---
#   1509    76 0.442 +0.353 runtime_interval(<1.5h) & production_company(Weinstein Co.) => review_score_interval(50-70) | ---
#   1510    68 0.405 +0.240 runtime_interval(<1.5h) & production_company(Weinstein Company) => review_score_interval(50-70) | ---
#   1511   239 0.586 +0.602 runtime_interval(<1.5h) & production_company(Zeitgeist Films) => review_score_interval(70-90) | ---
#   1512   157 0.449 +0.374 runtime_interval(>2.5h) & production_company(Buena Vista) => review_score_interval(50-70) | ---
#   1513    67 0.465 +0.272 runtime_interval(>2.5h) & production_company(Buena Vista Pictures) => review_score_interval(70-90) | ---
#   1514   405 0.436 +3.620 runtime_interval(>2.5h) & production_company(Columbia Pictures) => review_score_interval(>90) | ---
#   1515    61 0.530 +4.615 runtime_interval(>2.5h) & production_company(Criterion Collection) => review_score_interval(>90) | ---
#   1516    88 0.620 +5.560 runtime_interval(>2.5h) & production_company(Dreamworks Distribution) => review_score_interval(>90) | ---
#   1517    61 0.452 +0.236 runtime_interval(>2.5h) & production_company(Dreamworks Distribution LLC) => review_score_interval(70-90) | ---
#   1518   343 0.466 +0.274 runtime_interval(>2.5h) & production_company(IFC Films) => review_score_interval(70-90) | ---
#   1519    58 0.483 +0.322 runtime_interval(>2.5h) & production_company(MGM) => review_score_interval(70-90) | ---
#   1520    60 0.513 +0.571 runtime_interval(>2.5h) & production_company(MGM Home Entertainment) => review_score_interval(50-70) | ---
#   1521   149 0.490 +0.340 runtime_interval(>2.5h) & production_company(Marvel Studios) => review_score_interval(70-90) | ---
#   1522    76 0.531 +0.453 runtime_interval(>2.5h) & production_company(Miramax) => review_score_interval(70-90) | ---
#   1523   210 0.406 +0.111 runtime_interval(>2.5h) & production_company(Miramax Films) => review_score_interval(70-90) | ---
#   1524    85 0.563 +0.539 runtime_interval(>2.5h) & production_company(Music Box Films) => review_score_interval(70-90) | ---
#   1525   134 0.558 +4.910 runtime_interval(>2.5h) & production_company(Netflix) => review_score_interval(>90) | ---
#   1526    50 0.543 +0.486 runtime_interval(>2.5h) & production_company(Newmarket Films) => review_score_interval(70-90) | ---
#   1527   549 0.405 +0.108 runtime_interval(>2.5h) & production_company(Paramount Pictures) => review_score_interval(70-90) | ---
#   1528    83 0.568 +5.018 runtime_interval(>2.5h) & production_company(Paramount Vantage) => review_score_interval(>90) | ---
#   1529    53 0.434 +0.188 runtime_interval(>2.5h) & production_company(Parts and Labor) => review_score_interval(70-90) | ---
#   1530    76 0.760 +7.045 runtime_interval(>2.5h) & production_company(Rialto Pictures) => review_score_interval(>90) | ---
#   1531    99 0.627 +0.713 runtime_interval(>2.5h) & production_company(Sony Pictures) => review_score_interval(70-90) | ---
#   1532   256 0.479 +0.311 runtime_interval(>2.5h) & production_company(Sony Pictures Classics) => review_score_interval(70-90) | ---
#   1533    50 0.521 +0.424 runtime_interval(>2.5h) & production_company(Sony Pictures Home Entertainment) => review_score_interval(70-90) | ---
#   1534    66 0.405 +0.240 runtime_interval(>2.5h) & production_company(Sony Pictures/Columbia) => review_score_interval(50-70) | ---
#   1535    50 0.505 +0.381 runtime_interval(>2.5h) & production_company(Summit Entertainment) => review_score_interval(70-90) | ---
#   1536    95 0.528 +0.443 runtime_interval(>2.5h) & production_company(The Weinstein Co.) => review_score_interval(70-90) | ---
#   1537   179 0.455 +0.245 runtime_interval(>2.5h) & production_company(The Weinstein Company) => review_score_interval(70-90) | ---
#   1538    55 0.462 +0.416 runtime_interval(>2.5h) & production_company(Touchstone Pictures) => review_score_interval(50-70) | ---
#   1539    70 0.412 +0.126 runtime_interval(>2.5h) & production_company(Twentieth Century Fox Home Entertainment) => review_score_interval(70-90) | ---
#   1540   107 0.413 +3.373 runtime_interval(>2.5h) & production_company(United Artists) => review_score_interval(>90) | ---
#   1541   623 0.434 +0.185 runtime_interval(>2.5h) & production_company(Universal Pictures) => review_score_interval(70-90) | ---
#   1542   268 0.500 +0.367 runtime_interval(>2.5h) & production_company(Walt Disney Pictures) => review_score_interval(70-90) | ---
#   1543   407 0.475 +0.300 runtime_interval(>2.5h) & production_company(Warner Bros.) => review_score_interval(70-90) | ---
#   1544  1239 0.426 +0.165 runtime_interval(>2.5h) & production_company(Warner Bros. Pictures) => review_score_interval(70-90) | ---
#   1545   113 0.557 +4.893 runtime_interval(>2.5h) & production_company(Warner Bros. Pictures/Legendary) => review_score_interval(>90) | ---
#   1546    69 0.616 +0.685 runtime_interval(>2.5h) & production_company(Zeitgeist Films) => review_score_interval(70-90) | ---
#
#
#
# Rule id : 2
#
# Base :   847  Relative base : 0.001  CONF : 0.565  AAD : +0.546  BAD : -0.546
#
# Cedents:
#   antecedent : nicolas cage(False) & runtime_interval(1.5-1.75h) & production_company(A24)
#   succcedent : review_score_interval(70-90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |  847|  651|
# ----|-----|-----|
# ¬A  |244337|424576|
# ----|-----|-----|

# %% [markdown]
# ### SD4ftMiner

# %% [markdown]
# #### jestli maji Nicolase radsi top kritici, nebo ti ostatni

# %%
df = data
df=df.loc[:, ('nicolas cage', 'review_score', 'top_critic')]


clm = cleverminer(df=df,proc='SD4ftMiner',
               quantifiers= {'Base1':50, 'Base2':50, 'Ratioconf' : 2.0},
               ante ={
                    'attributes':[
                        {'name': 'nicolas cage', 'type': 'one', 'value': 'True'},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'},
               frst ={
                    'attributes':[
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'},
               scnd ={
                    'attributes':[
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(1)
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  SD4ftMiner
# Starting to mine rules.
# Done. Total verifications : 56, rules 2,control number:0, times: prep 0.9212470054626465, processing 0.2084050178527832
#
# CleverMiner task processing summary:
#
# Task type : SD4ftMiner
# Number of verifications : 56
# Number of rules : 2
# Total time needed : 00h 00m 01s
# Time of data preparation : 00h 00m 00s
# Time of rule mining : 00h 00m 00s
#
#
# List of rules:
# RULEID BASE1 BASE2 RatioConf DeltaConf Rule
#      1   562    62    2.295    +0.075  nicolas cage(True) => review_score(80.0) | --- : top_critic(False) x top_critic(True)
#      2    57    84    2.680    +0.033  nicolas cage(True) => review_score(25.0) | --- : top_critic(True) x top_critic(False)
#
#
#
# Rule id : 1
#
# Base1 :   562 Base2 :    62  Relative base 1 : 0.001 Relative base 2 : 0.000 CONF1 : 0.132  CONF2 : +0.058  Delta Conf : +0.075 Ratio Conf : +2.295
#
# Cedents:
#   antecedent : nicolas cage(True)
#   succcedent : review_score(80.0)
#   condition  : ---
#   first set  : top_critic(False)
#   second set : top_critic(True)
#
# Fourfold tables:
# FRST|  S  |  ¬S |  SCND|  S  |  ¬S |
# ----|-----|-----|  ----|-----|-----|
#  A  |  562| 3683|   A  |   62| 1013|
# ----|-----|-----|  ----|-----|-----|
# ¬A  |76966|436541|  ¬A  |13622|137962|
# ----|-----|-----|  ----|-----|-----|
#
#
#
# Rule id : 2
#
# Base1 :    57 Base2 :    84  Relative base 1 : 0.000 Relative base 2 : 0.000 CONF1 : 0.053  CONF2 : +0.020  Delta Conf : +0.033 Ratio Conf : +2.680
#
# Cedents:
#   antecedent : nicolas cage(True)
#   succcedent : review_score(25.0)
#   condition  : ---
#   first set  : top_critic(True)
#   second set : top_critic(False)
#
# Fourfold tables:
# FRST|  S  |  ¬S |  SCND|  S  |  ¬S |
# ----|-----|-----|  ----|-----|-----|
#  A  |   57| 1018|   A  |   84| 4161|
# ----|-----|-----|  ----|-----|-----|
# ¬A  | 5992|145592|  ¬A  | 8664|504843|
# ----|-----|-----|  ----|-----|-----|

# %% [markdown]
# #### Jak se obecně liší top kritici vs norm kritici na základě hodnocení filmu podle délky, produkční firmy nebo contnt ratingu

# %%
df = data
df=df.loc[:, ('runtime_interval', 'production_company', 'content_rating', 'genres', 'review_score', 'top_critic')]




clm = cleverminer(df=df,proc='SD4ftMiner',
               quantifiers= {'Base1':2000, 'Base2':2000, 'Ratioconf' : 2.0},
               ante ={
                    'attributes':[
                        {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'content_rating', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':3, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'},
               frst ={
                    'attributes':[
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'},
               scnd ={
                    'attributes':[
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(1)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  SD4ftMiner
# Starting to mine rules.
# Done. Total verifications : 444, rules 3,control number:0, times: prep 6.597846984863281, processing 39.004878997802734
#
# CleverMiner task processing summary:
#
# Task type : SD4ftMiner
# Number of verifications : 444
# Number of rules : 3
# Total time needed : 00h 00m 45s
# Time of data preparation : 00h 00m 06s
# Time of rule mining : 00h 00m 39s
#
#
# List of rules:
# RULEID BASE1 BASE2 RatioConf DeltaConf Rule
#      1  4231  6355    2.130    +0.092  runtime_interval(1.5-1.75h) & content_rating(R) => review_score(75.0) | --- : top_critic(True) x top_critic(False)
#      2  3740  6148    2.041    +0.094  runtime_interval(1.75-2h) & content_rating(R) => review_score(75.0) | --- : top_critic(True) x top_critic(False)
#      3  2309  4122    2.077    +0.093  runtime_interval(2-2.5) & content_rating(R) => review_score(75.0) | --- : top_critic(True) x top_critic(False)
#
#
#
# Rule id : 1
#
# Base1 :  4231 Base2 :  6355  Relative base 1 : 0.006 Relative base 2 : 0.009 CONF1 : 0.173  CONF2 : +0.081  Delta Conf : +0.092 Ratio Conf : +2.130
#
# Cedents:
#   antecedent : runtime_interval(1.5-1.75h) & content_rating(R)
#   succcedent : review_score(75.0)
#   condition  : ---
#   first set  : top_critic(True)
#   second set : top_critic(False)
#
# Fourfold tables:
# FRST|  S  |  ¬S |  SCND|  S  |  ¬S |
# ----|-----|-----|  ----|-----|-----|
#  A  | 4231|20207|   A  | 6355|71843|
# ----|-----|-----|  ----|-----|-----|
# ¬A  |22772|105449|  ¬A  |38919|400635|
# ----|-----|-----|  ----|-----|-----|
