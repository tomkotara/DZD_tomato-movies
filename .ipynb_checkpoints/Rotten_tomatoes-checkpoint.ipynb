# %% [markdown]
# ## Data import

# %%
import pandas as pd
from tqdm.notebook import tqdm_notebook, tqdm
import numpy as np
from cleverminer import cleverminer
# Out:
# Cleverminer version  1.0.2  educational version. For production use (bugfixes and keeping compatibility), ask for PRO version.

# %%
# movies
movies = pd.read_csv('./data/rotten_tomatoes_movies.csv', index_col = 'rotten_tomatoes_link')

# %%
# rotten_tomatoes_critic_reviews was too big it had to be split to be uploaded to GITHub
filenames = ['rotten_tomatoes_critic_reviews.csv', 'rotten_tomato_reviews_1.csv', 'rotten_tomato_reviews_2.csv', 'rotten_tomato_reviews_3.csv', 'rotten_tomato_reviews_4.csv', 'rotten_tomato_reviews_5.csv']
reviews_list = []

for filename in filenames:
    review = pd.read_csv(f'./data/{filename}', index_col='rotten_tomatoes_link')
    reviews_list.append(review)

# combining the critics review dataset back together
reviews = pd.concat(reviews_list)

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### movies

# %%
# deleting useless columna movies_info, critics_consensus containing long strings
movies.drop('movie_info', axis=1, inplace=True)
movies.drop('critics_consensus', axis=1, inplace=True)

# %% [markdown]
# ### reviews

# %%
# dropping rows with missing review_score values
reviews = reviews[reviews['review_score'].notna()]

# deleting useless column review_cotent containing long strings
reviews = reviews.drop('review_content', axis=1)

# %%
#unique values in review_score 
# unq = reviews['review_score'].unique()
# unq.sort()
# unq

#moje poznamky co napsat do zpravy
#FILTROVANI DAT NA ZAKLADE CRITICS_SCORE
# DLE RAUCHA JE TO OK..
# --- vime o tom a vysledek muze byt timto zpusobem zkreslen

# %%
# deleting reviews with non-numeric review scores (approx 80 000 values)
reviews = reviews[reviews['review_score'].str.contains('[A-Za-z]') == False]

# splitting review scores into columns
split = reviews['review_score'].str.split('/')

 #calculating percentage scores
scores =  pd.to_numeric(split.str.get(0)) / pd.to_numeric(split.str.get(1))
scores = scores*100

# assigning calculated values to the reviews scores column
reviews['review_score'] = scores

# %% [markdown]
# ## Final dataset

# %%
#Merging the two datasets - reviews and movies
data = pd.merge(movies, reviews, how='inner', on = 'rotten_tomatoes_link')

# %%
# data['actors'] = data['actors'].str.split(', ')

# remove rows with missing values
data = data[data['actors'].isnull() == False]
data = data[data['review_score'].isnull() == False]
data = data[np.isinf(data['review_score']) == False]
data = data[data['production_company'].isnull() == False]

# %%
## Rauch říkal, že by bylo moc práce to rozdělovat, pro naší SP stačí použít kategorie tak jak jsou...
## do zpravy je treba napsat, ze nam to takto rekl
## /--- se souhlasem cviciho
## muzeme pouzit kategorie tak jak jsou

#

# %%
data['genres'] = data['genres'].str.split(', ')
data = data[data['genres'].isnull() == False]

# %% [markdown]
# ### New columns

# %%
# new column with review score intervals
def review_score_interval(row):
    if row['review_score'] >= 90:
        return '>90'
    elif row['review_score'] >= 70:
        return '70-90'
    elif row['review_score'] >= 50:
        return '50-70'
    elif row['review_score'] >= 30:
        return '30-50'
    else:
        return '<30'

data["review_score_interval"] = data.apply(review_score_interval, axis=1)

# %%
# new column with review score intervals
def audience_rating_interval(row):
    if row['audience_rating'] >= 90:
        return '>90'
    elif row['audience_rating'] >= 70:
        return '70-90'
    elif row['audience_rating'] >= 50:
        return '50-70'
    elif row['audience_rating'] >= 30:
        return '30-50'
    else:
        return '<30'

data["audience_rating_interval"] = data.apply(audience_rating_interval, axis=1)

# %%
# new column with tomatometer rating interval
def tomatometer_rating_interval(row):
    if row['tomatometer_rating'] >= 90:
        return '>90'
    elif row['tomatometer_rating'] >= 70:
        return '70-90'
    elif row['tomatometer_rating'] >= 50:
        return '50-70'
    elif row['tomatometer_rating'] >= 30:
        return '30-50'
    else:
        return '<30'

data["tomatometer_rating_interval"] = data.apply(tomatometer_rating_interval, axis=1)

# %%
# new column with runtime intervals
def runtime_interval(row):
    if row['runtime'] >= 150:
        return '>2.5h'
    elif row['runtime'] >= 120:
        return '2-2.5'
    elif row['runtime'] >= 105:
        return '1.75-2h'
    elif row['runtime'] >= 90:
        return '1.5-1.75h'
    else:
        return '<1.5h'

data["runtime_interval"] = data.apply(runtime_interval, axis=1)

# %%
# new column with release interval
data = data[data['original_release_date'].notnull()]

def release_decade_interval(row):
    split = row["original_release_date"].split('-')
    year = split[0]
    interval =  str(pd.to_numeric(year)//10*10) + '\'s'
    return interval

data["release_decade_interval"] = data.apply(release_decade_interval, axis=1)

# %%
def is_horror(row):
    if 'Horror' in row['genres']:
        return True
    else: return False
data["Horror"] = data.apply(is_horror, axis=1)

# %% [markdown]
# ## top genres

# %%
genres_scores = dict()
for row in tqdm(range(data.shape[0])):
    value = data['review_score'][row]
    for genre in data['genres'][row]:
        if genre not in genres_scores.keys():
            genres_scores[genre] = [value]
        else:
            genres_scores[genre].append(value)
# Out:
#   0%|          | 0/687637 [00:00<?, ?it/s]

# %%
# calculating average scores for each actor
final_genres_scores = {}
for key in tqdm(genres_scores.keys()):
    # add only actors with 3000+ reviews 
    if len(genres_scores[key]) > 100:
        mean = np.mean(genres_scores[key])
        final_genres_scores[key] = round(mean, 1)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
final_genres_scores
genres_rating = sorted(final_genres_scores.items(), key=lambda x: x[1], reverse=True)
genres_rating
# Out:
# [('Classics', 75.6),
#  ('Documentary', 71.5),
#  ('Special Interest', 70.4),
#  ('Anime & Manga', 69.9),
#  ('Art House & International', 69.3),
#  ('Sports & Fitness', 67.3),
#  ('Animation', 66.7),
#  ('Television', 66.6),
#  ('Musical & Performing Arts', 66.4),
#  ('Western', 66.2),
#  ('Drama', 65.6),
#  ('Cult Movies', 64.7),
#  ('Gay & Lesbian', 63.6),
#  ('Science Fiction & Fantasy', 62.5),
#  ('Romance', 62.5),
#  ('Kids & Family', 62.0),
#  ('Faith & Spirituality', 61.8),
#  ('Mystery & Suspense', 61.4),
#  ('Action & Adventure', 60.6),
#  ('Comedy', 60.2),
#  ('Horror', 57.3)]

# %% [markdown]
# ## TOP10 actors

# %%
# creating dict with following annotation actor: [scores]
actor_scores = dict()
for row in tqdm(range(data.shape[0])):
    value = data['review_score'][row]
    for actor in data['actors'][row]:
        if actor not in actor_scores.keys():
            actor_scores[actor] = [value]
        else:
            actor_scores[actor].append(value)
# Out:
#   0%|          | 0/687637 [00:00<?, ?it/s]

# %%
# calculating average scores for each actor
final_scores = {}
for key in tqdm(actor_scores.keys()):
    
    # add only actors with 3000+ reviews 
    if len(actor_scores[key]) > 3000:
        mean = np.mean(actor_scores[key])
        final_scores[key] = round(mean, 1)
# Out:
#   0%|          | 0/203738 [00:00<?, ?it/s]

# %%
top10 = sorted(final_scores.items(), key=lambda x: x[1], reverse=True)
top10[0:10]
# Out:
# [('John Ratzenberger', 78.6),
#  ('Michael Stuhlbarg', 75.2),
#  ('Andy Serkis', 75.0),
#  ('Adam Driver', 74.6),
#  ('Leonardo DiCaprio', 73.3),
#  ('Anthony Daniels', 73.1),
#  ('Domhnall Gleeson', 72.5),
#  ('Warwick Davis', 72.4),
#  ('Tom Holland (II)', 72.3),
#  ('Tilda Swinton', 72.0)]

# %%
pd.set_option('display.max_columns', None)
data.head(1)
# Out:
#                                                             movie_title  \
# rotten_tomatoes_link
# m/0814255             Percy Jackson & the Olympians: The Lightning T...
#
#                      content_rating  \
# rotten_tomatoes_link
# m/0814255                        PG
#
#                                                                  genres  \
# rotten_tomatoes_link
# m/0814255             Action & Adventure, Comedy, Drama, Science Fic...
#
#                            directors  \
# rotten_tomatoes_link
# m/0814255             Chris Columbus
#
#                                                          authors  \
# rotten_tomatoes_link
# m/0814255             Craig Titley, Chris Columbus, Rick Riordan
#
#                                                                  actors  \
# rotten_tomatoes_link
# m/0814255             Logan Lerman, Brandon T. Jackson, Alexandra Da...
#
#                      original_release_date streaming_release_date  runtime  \
# rotten_tomatoes_link
# m/0814255                       2010-02-12             2015-11-25    119.0
#
#                      production_company tomatometer_status  \
# rotten_tomatoes_link
# m/0814255              20th Century Fox             Rotten
#
#                       tomatometer_rating  tomatometer_count audience_status  \
# rotten_tomatoes_link
# m/0814255                           49.0              149.0         Spilled
#
#                       audience_rating  audience_count  \
# rotten_tomatoes_link
# m/0814255                        53.0        254421.0
#
#                       tomatometer_top_critics_count  \
# rotten_tomatoes_link
# m/0814255                                        43
#
#                       tomatometer_fresh_critics_count  \
# rotten_tomatoes_link
# m/0814255                                          73
#
#                       tomatometer_rotten_critics_count   critic_name  \
# rotten_tomatoes_link
# m/0814255                                           76  Ben McEachen
#
#                       top_critic           publisher_name review_type  \
# rotten_tomatoes_link
# m/0814255                  False  Sunday Mail (Australia)       Fresh
#
#                       review_score review_date review_score_interval  \
# rotten_tomatoes_link
# m/0814255                     70.0  2010-02-09                 70-90
#
#                      audience_rating_interval tomatometer_rating_interval  \
# rotten_tomatoes_link
# m/0814255                               50-70                       30-50
#
#                      runtime_interval release_decade_interval
# rotten_tomatoes_link
# m/0814255                     1.75-2h                  2010's

# %% [markdown]
# ### histogram pro hodnocení filmů dle režiséra a production company, release decade a content rating

# %%
df = data
df = df.loc[:, ('directors', 'release_decade_interval', 'review_score_interval', 'production_company', 'tomatometer_status', 'tomatometer_top_critics_count', 'content_rating')]



clm = cleverminer(df=df,target='review_score_interval',proc='CFMiner',
               quantifiers= {'S_Up':2, 'Base':750},
                cond={
                    'attributes':[
                        {'name': 'directors', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'release_decade_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'content_rating', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':3, 'maxlen':4, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Warning: Python 3.10+ NOT detected. You should upgrade to Python 3.10 or greater to get better performance
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  CFMiner
# Starting to mine rules.
# Done. Total verifications : 218, rules 137,control number:0, times: prep 46.65488624572754, processing 45.2452187538147
#
# CleverMiner task processing summary:
#
# Task type : CFMiner
# Number of verifications : 218
# Number of rules : 137
# Total time needed : 00h 01m 31s
# Time of data preparation : 00h 00m 46s
# Time of rule mining : 00h 00m 45s
#
#
# List of rules:
# RULEID BASE  S_UP  S_DOWN Condition
#      1   814     2     1 directors(Anthony Russo) & release_decade_interval(2010's) & content_rating(PG-13)
#      2   866     2     1 directors(Bryan Singer) & production_company(20th Century Fox) & content_rating(PG-13)
#      3   893     2     1 directors(Christopher Nolan) & production_company(Warner Bros. Pictures) & content_rating(PG-13)
#      4   932     2     1 directors(Christopher Nolan) & release_decade_interval(2010's) & content_rating(PG-13)
#      5   758     2     1 directors(Clint Eastwood) & release_decade_interval(2000's) & content_rating(R)
#      6   757     2     1 directors(Clint Eastwood) & release_decade_interval(2010's) & content_rating(R)
#      7   797     2     1 directors(Danny Boyle) & production_company(Fox Searchlight Pictures) & release_decade_interval(2000's)
#      8   762     2     1 directors(Danny Boyle) & release_decade_interval(2000's) & content_rating(R)
#      9   790     2     1 directors(Danny Boyle) & release_decade_interval(2010's) & content_rating(R)
#     10   987     2     2 directors(David Gordon Green) & release_decade_interval(2010's) & content_rating(R)
#     11   808     2     1 directors(David Yates (II)) & production_company(Warner Bros. Pictures) & release_decade_interval(2010's)
#     12   808     2     1 directors(David Yates (II)) & production_company(Warner Bros. Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#     13   968     2     1 directors(David Yates (II)) & production_company(Warner Bros. Pictures) & content_rating(PG-13)
#     14   970     2     1 directors(David Yates (II)) & release_decade_interval(2010's) & content_rating(PG-13)
#     15  1037     2     1 directors(Denis Villeneuve) & release_decade_interval(2010's) & content_rating(R)
#     16  1096     2     1 directors(J.J. Abrams) & production_company(Walt Disney Pictures) & release_decade_interval(2010's)
#     17  1096     2     1 directors(J.J. Abrams) & production_company(Walt Disney Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#     18  1096     2     1 directors(J.J. Abrams) & production_company(Walt Disney Pictures) & content_rating(PG-13)
#     19  1856     2     1 directors(J.J. Abrams) & release_decade_interval(2010's) & content_rating(PG-13)
#     20   994     2     1 directors(Jon Watts) & production_company(Sony Pictures) & release_decade_interval(2010's)
#     21   994     2     1 directors(Jon Watts) & production_company(Sony Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#     22   994     2     1 directors(Jon Watts) & production_company(Sony Pictures) & content_rating(PG-13)
#     23   994     2     1 directors(Jon Watts) & release_decade_interval(2010's) & content_rating(PG-13)
#     24   897     2     1 directors(Martin Scorsese) & release_decade_interval(2010's) & content_rating(R)
#     25   775     2     1 directors(Paul Feig) & release_decade_interval(2010's) & content_rating(R)
#     26   795     2     1 directors(Rian Johnson) & release_decade_interval(2010's) & content_rating(PG-13)
#     27  1084     2     1 directors(Ridley Scott) & production_company(20th Century Fox) & release_decade_interval(2010's)
#     28   756     2     1 directors(Ridley Scott) & production_company(20th Century Fox) & release_decade_interval(2010's) & content_rating(R)
#     29   950     2     1 directors(Ridley Scott) & production_company(20th Century Fox) & content_rating(R)
#     30   900     2     1 directors(Ridley Scott) & release_decade_interval(2010's) & content_rating(R)
#     31   785     2     1 directors(Sam Mendes) & release_decade_interval(2000's) & content_rating(R)
#     32   864     2     1 directors(Sam Mendes) & release_decade_interval(2010's) & content_rating(PG-13)
#     33  1117     2     1 directors(Sam Raimi) & release_decade_interval(2000's) & content_rating(PG-13)
#     34   813     2     1 directors(Steven Spielberg) & release_decade_interval(2000's) & content_rating(PG-13)
#     35  1250     2     1 directors(Steven Spielberg) & release_decade_interval(2010's) & content_rating(PG-13)
#     36  1240     2     2 directors(nan) & release_decade_interval(2000's) & content_rating(PG-13)
#     37  1072     2     2 directors(nan) & release_decade_interval(2000's) & content_rating(R)
#     38   814     2     1 directors(nan) & release_decade_interval(2010's) & content_rating(NR)
#     39  1399     2     1 directors(nan) & release_decade_interval(2010's) & content_rating(R)
#     40   927     2     1 production_company(20th Century Fox) & release_decade_interval(1990's) & content_rating(R)
#     41  6193     2     2 production_company(20th Century Fox) & release_decade_interval(2010's) & content_rating(R)
#     42  3507     2     1 production_company(A24) & release_decade_interval(2010's) & content_rating(R)
#     43  2194     2     1 production_company(A24 Films) & release_decade_interval(2010's) & content_rating(R)
#     44  1057     2     2 production_company(A24 and DIRECTV) & release_decade_interval(2010's) & content_rating(R)
#     45   985     2     1 production_company(Amazon Studios) & release_decade_interval(2010's) & content_rating(R)
#     46  1236     2     1 production_company(Annapurna Pictures) & release_decade_interval(2010's) & content_rating(R)
#     47   952     2     2 production_company(Artisan Entertainment) & release_decade_interval(2000's) & content_rating(R)
#     48  1118     2     1 production_company(Buena Vista Pictures) & release_decade_interval(2000's) & content_rating(PG)
#     49  1126     2     1 production_company(CBS Films) & release_decade_interval(2010's) & content_rating(R)
#     50  1050     2     1 production_company(Columbia Pictures) & release_decade_interval(1990's) & content_rating(R)
#     51  1717     2     2 production_company(Columbia Pictures) & release_decade_interval(2000's) & content_rating(R)
#     52   774     2     1 production_company(Disney/Pixar) & release_decade_interval(2010's) & content_rating(PG)
#     53   839     2     1 production_company(Drafthouse Films) & release_decade_interval(2010's) & content_rating(NR)
#     54   806     2     1 production_company(DreamWorks SKG) & release_decade_interval(2000's) & content_rating(R)
#     55  1162     2     1 production_company(Dreamworks) & release_decade_interval(2000's) & content_rating(PG)
#     56  1099     2     1 production_company(Dreamworks) & release_decade_interval(2000's) & content_rating(PG-13)
#     57  3810     2     1 production_company(Focus Features) & release_decade_interval(2000's) & content_rating(R)
#     58   789     2     1 production_company(Focus Features) & release_decade_interval(2010's) & content_rating(PG)
#     59  2976     2     1 production_company(Focus Features) & release_decade_interval(2010's) & content_rating(PG-13)
#     60  5539     2     1 production_company(Focus Features) & release_decade_interval(2010's) & content_rating(R)
#     61  1272     2     1 production_company(Fox Searchlight) & release_decade_interval(2000's) & content_rating(R)
#     62   950     2     1 production_company(Fox Searchlight) & release_decade_interval(2010's) & content_rating(PG-13)
#     63  2342     2     1 production_company(Fox Searchlight) & release_decade_interval(2010's) & content_rating(R)
#     64  1633     2     1 production_company(Fox Searchlight Pictures) & release_decade_interval(2000's) & content_rating(PG-13)
#     65  3255     2     1 production_company(Fox Searchlight Pictures) & release_decade_interval(2000's) & content_rating(R)
#     66  1036     2     1 production_company(Fox Searchlight Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#     67  2296     2     1 production_company(Fox Searchlight Pictures) & release_decade_interval(2010's) & content_rating(R)
#     68  1023     2     1 production_company(IFC Films) & release_decade_interval(2000's) & content_rating(NR)
#     69  2352     2     1 production_company(IFC Films) & release_decade_interval(2000's) & content_rating(R)
#     70  4329     2     1 production_company(IFC Films) & release_decade_interval(2010's) & content_rating(NR)
#     71  1305     2     1 production_company(IFC Films) & release_decade_interval(2010's) & content_rating(PG-13)
#     72   792     2     1 production_company(Kino Lorber) & release_decade_interval(2010's) & content_rating(NR)
#     73  2593     2     2 production_company(Lions Gate Films) & release_decade_interval(2000's) & content_rating(R)
#     74  2831     2     2 production_company(Lionsgate) & release_decade_interval(2010's) & content_rating(R)
#     75  1470     2     2 production_company(Lionsgate Films) & release_decade_interval(2000's) & content_rating(R)
#     76   965     2     1 production_company(MGM) & release_decade_interval(2010's) & content_rating(PG-13)
#     77  2775     2     1 production_company(Magnolia Pictures) & release_decade_interval(2000's) & content_rating(R)
#     78  5765     2     1 production_company(Magnolia Pictures) & release_decade_interval(2010's) & content_rating(R)
#     79   888     2     1 production_company(Marvel Studios) & release_decade_interval(2010's) & content_rating(PG-13)
#     80  1544     2     1 production_company(Miramax) & release_decade_interval(1990's) & content_rating(R)
#     81   771     2     1 production_company(Miramax) & release_decade_interval(2000's) & content_rating(PG-13)
#     82  1515     2     2 production_company(Miramax) & release_decade_interval(2000's) & content_rating(R)
#     83  1328     2     1 production_company(Miramax Films) & release_decade_interval(1990's) & content_rating(R)
#     84   765     2     1 production_company(Miramax Films) & release_decade_interval(2000's) & content_rating(PG)
#     85  3066     2     1 production_company(Miramax Films) & release_decade_interval(2000's) & content_rating(PG-13)
#     86  4340     2     1 production_company(Miramax Films) & release_decade_interval(2000's) & content_rating(R)
#     87  1223     2     1 production_company(Music Box Films) & release_decade_interval(2010's) & content_rating(NR)
#     88  1019     2     1 production_company(Music Box Films) & release_decade_interval(2010's) & content_rating(R)
#     89  1685     2     1 production_company(NEON) & release_decade_interval(2010's) & content_rating(R)
#     90  1857     2     1 production_company(Netflix) & release_decade_interval(2010's) & content_rating(NR)
#     91  2090     2     1 production_company(Netflix) & release_decade_interval(2010's) & content_rating(R)
#     92  1276     2     2 production_company(New Line Cinema) & release_decade_interval(2010's) & content_rating(PG-13)
#     93  3186     2     1 production_company(Open Road Films) & release_decade_interval(2010's) & content_rating(R)
#     94  1371     2     1 production_company(Paramount Classics) & release_decade_interval(2000's) & content_rating(R)
#     95   769     2     1 production_company(Paramount Pictures) & release_decade_interval(1980's) & content_rating(PG)
#     96   828     2     1 production_company(Paramount Pictures) & release_decade_interval(1990's) & content_rating(PG-13)
#     97  1293     2     1 production_company(Paramount Pictures) & release_decade_interval(1990's) & content_rating(R)
#     98  3411     2     1 production_company(Paramount Pictures) & release_decade_interval(2000's) & content_rating(R)
#     99   909     2     2 production_company(Paramount Pictures) & release_decade_interval(2010's) & content_rating(PG)
#    100  6234     2     1 production_company(Paramount Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#    101  4762     2     1 production_company(Paramount Pictures) & release_decade_interval(2010's) & content_rating(R)
#    102  1130     2     1 production_company(Paramount Vantage) & release_decade_interval(2000's) & content_rating(R)
#    103   874     2     1 production_company(Picturehouse) & release_decade_interval(2000's) & content_rating(R)
#    104  1510     2     1 production_company(Radius-TWC) & release_decade_interval(2010's) & content_rating(R)
#    105   753     2     1 production_company(Roadside Attractions) & release_decade_interval(2000's) & content_rating(R)
#    106  1264     2     1 production_company(Roadside Attractions) & release_decade_interval(2010's) & content_rating(PG-13)
#    107  2461     2     1 production_company(Roadside Attractions) & release_decade_interval(2010's) & content_rating(R)
#    108   784     2     2 production_company(STXfilms) & release_decade_interval(2010's) & content_rating(R)
#    109  1107     2     2 production_company(Samuel Goldwyn Films) & release_decade_interval(2000's) & content_rating(R)
#    110  3893     2     1 production_company(Sony Pictures) & release_decade_interval(2010's) & content_rating(R)
#    111  2708     2     1 production_company(Sony Pictures Classics) & release_decade_interval(2000's) & content_rating(PG-13)
#    112  5645     2     1 production_company(Sony Pictures Classics) & release_decade_interval(2000's) & content_rating(R)
#    113  2840     2     1 production_company(Sony Pictures Classics) & release_decade_interval(2010's) & content_rating(PG-13)
#    114  6476     2     1 production_company(Sony Pictures Classics) & release_decade_interval(2010's) & content_rating(R)
#    115   766     2     1 production_company(Sony Pictures Home Entertainment) & release_decade_interval(1990's) & content_rating(PG)
#    116  1030     2     1 production_company(Strand Releasing) & release_decade_interval(2010's) & content_rating(NR)
#    117  1516     2     2 production_company(Summit Entertainment) & release_decade_interval(2010's) & content_rating(R)
#    118  1382     2     1 production_company(The Weinstein Company) & release_decade_interval(2000's) & content_rating(R)
#    119  2159     2     1 production_company(The Weinstein Company) & release_decade_interval(2010's) & content_rating(PG-13)
#    120  3535     2     1 production_company(The Weinstein Company) & release_decade_interval(2010's) & content_rating(R)
#    121  1245     2     1 production_company(ThinkFilm) & release_decade_interval(2000's) & content_rating(R)
#    122  1260     2     1 production_company(Universal Pictures) & release_decade_interval(1990's) & content_rating(R)
#    123  5455     2     1 production_company(Universal Pictures) & release_decade_interval(2000's) & content_rating(R)
#    124   784     2     1 production_company(Universal Pictures) & release_decade_interval(2020's) & content_rating(R)
#    125  1089     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2000's) & content_rating(G)
#    126  1742     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2000's) & content_rating(PG)
#    127   792     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2010's) & content_rating(G)
#    128  6007     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2010's) & content_rating(PG)
#    129  7533     2     1 production_company(Walt Disney Pictures) & release_decade_interval(2010's) & content_rating(PG-13)
#    130  1178     2     1 production_company(Warner Bros.) & release_decade_interval(2010's) & content_rating(R)
#    131   773     2     1 production_company(Warner Bros. Pictures) & release_decade_interval(1980's) & content_rating(R)
#    132   969     2     1 production_company(Warner Bros. Pictures) & release_decade_interval(1990's) & content_rating(R)
#    133  2029     2     1 production_company(Warner Bros. Pictures) & release_decade_interval(2010's) & content_rating(PG)
#    134   812     2     1 production_company(Warner Home Video) & release_decade_interval(1980's) & content_rating(R)
#    135   815     2     1 production_company(Warner Independent Pictures) & release_decade_interval(2000's) & content_rating(R)
#    136  1845     2     1 production_company(nan) & release_decade_interval(2010's) & content_rating(NR)
#    137  1475     2     1 production_company(nan) & release_decade_interval(2010's) & content_rating(R)
#
#
#
# Rule id : 2
#
# Base :   866  Relative base : 0.001  Steps UP (consecutive) :     2  Steps DOWN (consecutive) :     1  Steps UP (any) :     3  Steps DOWN (any) :     1  Histogram maximum :   388  Histogram minimum :    20  Histogram relative maximum : 0.448 Histogram relative minimum : 0.023
#
# Condition  : directors(Bryan Singer) & production_company(20th Century Fox) & content_rating(PG-13)
#
# Histogram [85, 294, 388, 20, 79]

# %% [markdown]
# ### histogram pro hodnocení filmů dle kritika a publishera, typu review a je-li kritik top-kritik

# %%
df = data
df = df.loc[:, ('critic_name', 'release_decade_interval', 'review_score_interval', 'publisher_name', 'review_type', 'top_critic')]



clm = cleverminer(df=df,target='review_score_interval',proc='CFMiner',
               quantifiers= {'S_Up':2, 'Base':500},
                cond={
                    'attributes':[
                        {'name': 'critic_name', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'publisher_name', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'review_type', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':3, 'maxlen':4, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Warning: Python 3.10+ NOT detected. You should upgrade to Python 3.10 or greater to get better performance
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  CFMiner
# Starting to mine rules.
# Done. Total verifications : 1537, rules 846,control number:0, times: prep 33.7854950428009, processing 71.67726612091064
#
# CleverMiner task processing summary:
#
# Task type : CFMiner
# Number of verifications : 1537
# Number of rules : 846
# Total time needed : 00h 01m 45s
# Time of data preparation : 00h 00m 33s
# Time of rule mining : 00h 01m 11s
#
#
# List of rules:
# RULEID BASE  S_UP  S_DOWN Condition
#      1   882     2     1 critic_name(A.O. Scott) & publisher_name(New York Times) & review_type(Fresh)
#      2   882     2     1 critic_name(A.O. Scott) & publisher_name(New York Times) & review_type(Fresh) & top_critic(True)
#      3  1402     2     1 critic_name(A.O. Scott) & publisher_name(New York Times) & top_critic(True)
#      4   882     2     1 critic_name(A.O. Scott) & review_type(Fresh) & top_critic(True)
#      5   822     2     1 critic_name(Alistair Harkness) & publisher_name(Scotsman) & review_type(Fresh)
#      6   822     2     1 critic_name(Alistair Harkness) & publisher_name(Scotsman) & review_type(Fresh) & top_critic(False)
#      7   822     2     1 critic_name(Alistair Harkness) & review_type(Fresh) & top_critic(False)
#      8  1100     2     1 critic_name(Allan Hunter) & review_type(Fresh) & top_critic(False)
#      9   617     2     1 critic_name(Amber Wilkinson) & publisher_name(Eye for Film) & review_type(Fresh)
#     10   617     2     1 critic_name(Amber Wilkinson) & publisher_name(Eye for Film) & review_type(Fresh) & top_critic(False)
#     11   758     2     1 critic_name(Amber Wilkinson) & publisher_name(Eye for Film) & top_critic(False)
#     12   622     2     1 critic_name(Amber Wilkinson) & review_type(Fresh) & top_critic(False)
#     13   617     2     1 critic_name(Amy Biancolli) & publisher_name(Houston Chronicle) & top_critic(True)
#     14  1093     2     1 critic_name(Andrea Chase) & publisher_name(Killer Movie Reviews) & review_type(Fresh)
#     15  1093     2     1 critic_name(Andrea Chase) & publisher_name(Killer Movie Reviews) & review_type(Fresh) & top_critic(False)
#     16  1093     2     1 critic_name(Andrea Chase) & review_type(Fresh) & top_critic(False)
#     17   683     2     1 critic_name(Ann Hornaday) & publisher_name(Washington Post) & review_type(Fresh)
#     18   683     2     1 critic_name(Ann Hornaday) & publisher_name(Washington Post) & review_type(Fresh) & top_critic(True)
#     19   971     2     1 critic_name(Ann Hornaday) & publisher_name(Washington Post) & top_critic(True)
#     20   683     2     1 critic_name(Ann Hornaday) & review_type(Fresh) & top_critic(True)
#     21   841     2     1 critic_name(Avi Offer) & publisher_name(NYC Movie Guru) & review_type(Fresh)
#     22   841     2     1 critic_name(Avi Offer) & publisher_name(NYC Movie Guru) & review_type(Fresh) & top_critic(False)
#     23  1323     2     1 critic_name(Avi Offer) & publisher_name(NYC Movie Guru) & top_critic(False)
#     24   841     2     1 critic_name(Avi Offer) & review_type(Fresh) & top_critic(False)
#     25   527     2     2 critic_name(Betsy Sharkey) & publisher_name(Los Angeles Times) & top_critic(True)
#     26   518     2     1 critic_name(Bill Gibron) & publisher_name(PopMatters) & review_type(Fresh)
#     27   518     2     1 critic_name(Bill Gibron) & publisher_name(PopMatters) & review_type(Fresh) & top_critic(False)
#     28   727     2     1 critic_name(Bill Gibron) & publisher_name(PopMatters) & top_critic(False)
#     29   910     2     1 critic_name(Bill Gibron) & review_type(Fresh) & top_critic(False)
#     30  1450     2     1 critic_name(Bill Goodykoontz) & publisher_name(Arizona Republic) & review_type(Fresh)
#     31  1450     2     1 critic_name(Bill Goodykoontz) & publisher_name(Arizona Republic) & review_type(Fresh) & top_critic(True)
#     32  1945     2     1 critic_name(Bill Goodykoontz) & publisher_name(Arizona Republic) & top_critic(True)
#     33  1450     2     1 critic_name(Bill Goodykoontz) & review_type(Fresh) & top_critic(True)
#     34   681     2     1 critic_name(Bill Muller) & publisher_name(Arizona Republic) & top_critic(True)
#     35   513     2     1 critic_name(Blake Howard) & review_type(Fresh) & top_critic(False)
#     36  1066     2     1 critic_name(Bob Bloom) & publisher_name(Journal and Courier (Lafayette, IN)) & review_type(Fresh)
#     37  1066     2     1 critic_name(Bob Bloom) & publisher_name(Journal and Courier (Lafayette, IN)) & review_type(Fresh) & top_critic(False)
#     38  1526     2     2 critic_name(Bob Bloom) & publisher_name(Journal and Courier (Lafayette, IN)) & top_critic(False)
#     39  1189     2     1 critic_name(Bob Bloom) & review_type(Fresh) & top_critic(False)
#     40   611     2     1 critic_name(Brian Mckay) & publisher_name(eFilmCritic.com) & top_critic(False)
#     41   857     2     1 critic_name(Brian Webster) & publisher_name(Apollo Guide) & review_type(Fresh)
#     42   857     2     1 critic_name(Brian Webster) & publisher_name(Apollo Guide) & review_type(Fresh) & top_critic(False)
#     43  1440     2     1 critic_name(Brian Webster) & publisher_name(Apollo Guide) & top_critic(False)
#     44   857     2     1 critic_name(Brian Webster) & review_type(Fresh) & top_critic(False)
#     45   657     2     1 critic_name(Bruce Kirkland) & publisher_name(Jam! Movies) & top_critic(False)
#     46   580     2     1 critic_name(CJ Johnson) & publisher_name(Film Mafia) & top_critic(False)
#     47   544     2     1 critic_name(Carla Meyer) & publisher_name(Sacramento Bee) & top_critic(False)
#     48  1737     2     1 critic_name(Carol Cling) & publisher_name(Las Vegas Review-Journal) & review_type(Fresh)
#     49  1737     2     1 critic_name(Carol Cling) & publisher_name(Las Vegas Review-Journal) & review_type(Fresh) & top_critic(False)
#     50  2002     2     1 critic_name(Carol Cling) & publisher_name(Las Vegas Review-Journal) & top_critic(False)
#     51  1737     2     1 critic_name(Carol Cling) & review_type(Fresh) & top_critic(False)
#     52   792     2     1 critic_name(Carrie Rickey) & publisher_name(Philadelphia Inquirer) & review_type(Fresh)
#     53   792     2     1 critic_name(Carrie Rickey) & publisher_name(Philadelphia Inquirer) & review_type(Fresh) & top_critic(True)
#     54  1210     2     1 critic_name(Carrie Rickey) & publisher_name(Philadelphia Inquirer) & top_critic(True)
#     55   792     2     1 critic_name(Carrie Rickey) & review_type(Fresh) & top_critic(True)
#     56   698     2     1 critic_name(Charles Koplinski) & publisher_name(Illinois Times) & top_critic(False)
#     57   544     2     1 critic_name(Charlotte O'Sullivan) & publisher_name(London Evening Standard) & review_type(Fresh)
#     58   544     2     1 critic_name(Charlotte O'Sullivan) & publisher_name(London Evening Standard) & review_type(Fresh) & top_critic(True)
#     59   544     2     1 critic_name(Charlotte O'Sullivan) & review_type(Fresh) & top_critic(True)
#     60  1459     2     1 critic_name(Cherryl Dawson and Leigh Ann Palone) & publisher_name(TheMovieChicks.com) & top_critic(False)
#     61   542     2     1 critic_name(Chris Barsanti) & review_type(Fresh) & top_critic(False)
#     62   919     2     1 critic_name(Chris Bumbray) & publisher_name(JoBlo's Movie Network) & review_type(Fresh)
#     63   919     2     1 critic_name(Chris Bumbray) & publisher_name(JoBlo's Movie Network) & review_type(Fresh) & top_critic(False)
#     64  1250     2     1 critic_name(Chris Bumbray) & publisher_name(JoBlo's Movie Network) & top_critic(False)
#     65   927     2     1 critic_name(Chris Bumbray) & review_type(Fresh) & top_critic(False)
#     66   571     2     1 critic_name(Chris Cabin) & publisher_name(Filmcritic.com) & top_critic(False)
#     67  2204     2     1 critic_name(Chris Hewitt) & publisher_name(St. Paul Pioneer Press) & review_type(Fresh)
#     68  2204     2     1 critic_name(Chris Hewitt) & publisher_name(St. Paul Pioneer Press) & review_type(Fresh) & top_critic(False)
#     69  3455     2     2 critic_name(Chris Hewitt) & publisher_name(St. Paul Pioneer Press) & top_critic(False)
#     70  2205     2     1 critic_name(Chris Hewitt) & review_type(Fresh) & top_critic(False)
#     71   865     2     1 critic_name(Chris Knight) & publisher_name(National Post) & review_type(Fresh)
#     72   865     2     1 critic_name(Chris Knight) & publisher_name(National Post) & review_type(Fresh) & top_critic(False)
#     73  1201     2     1 critic_name(Chris Knight) & publisher_name(National Post) & top_critic(False)
#     74   865     2     1 critic_name(Chris Knight) & review_type(Fresh) & top_critic(False)
#     75   527     2     2 critic_name(Christian Toto) & publisher_name(HollywoodInToto.com) & top_critic(False)
#     76   801     2     1 critic_name(Christian Toto) & review_type(Fresh) & top_critic(False)
#     77  1547     2     1 critic_name(Christopher Null) & publisher_name(Filmcritic.com) & review_type(Fresh)
#     78  1547     2     1 critic_name(Christopher Null) & publisher_name(Filmcritic.com) & review_type(Fresh) & top_critic(False)
#     79  2752     2     1 critic_name(Christopher Null) & publisher_name(Filmcritic.com) & top_critic(False)
#     80  1570     2     1 critic_name(Christopher Null) & review_type(Fresh) & top_critic(False)
#     81  1099     2     1 critic_name(Claudia Puig) & publisher_name(USA Today) & review_type(Fresh)
#     82  1099     2     1 critic_name(Claudia Puig) & publisher_name(USA Today) & review_type(Fresh) & top_critic(True)
#     83  1114     2     1 critic_name(Claudia Puig) & review_type(Fresh) & top_critic(True)
#     84  1062     2     1 critic_name(Cole Smithey) & publisher_name(ColeSmithey.com) & review_type(Fresh)
#     85  1062     2     1 critic_name(Cole Smithey) & publisher_name(ColeSmithey.com) & review_type(Fresh) & top_critic(False)
#     86  1177     2     1 critic_name(Cole Smithey) & publisher_name(ColeSmithey.com) & top_critic(False)
#     87  1062     2     1 critic_name(Cole Smithey) & review_type(Fresh) & top_critic(False)
#     88   562     2     1 critic_name(Dan Jardine) & publisher_name(Apollo Guide) & top_critic(False)
#     89   644     2     1 critic_name(Dan Jardine) & review_type(Fresh) & top_critic(False)
#     90   729     2     1 critic_name(Dan Lybarger) & review_type(Fresh) & top_critic(False)
#     91   617     2     1 critic_name(Daniel M. Kimmel) & publisher_name(North Shore Movies) & review_type(Fresh)
#     92   617     2     1 critic_name(Daniel M. Kimmel) & publisher_name(North Shore Movies) & review_type(Fresh) & top_critic(False)
#     93  1156     2     1 critic_name(Daniel M. Kimmel) & publisher_name(Worcester Telegram & Gazette) & review_type(Fresh)
#     94  1156     2     1 critic_name(Daniel M. Kimmel) & publisher_name(Worcester Telegram & Gazette) & review_type(Fresh) & top_critic(False)
#     95  1842     2     1 critic_name(Daniel M. Kimmel) & review_type(Fresh) & top_critic(False)
#     96   503     2     1 critic_name(Dave Calhoun) & publisher_name(Time Out) & top_critic(True)
#     97   582     2     1 critic_name(Dave White) & publisher_name(Movies.com) & review_type(Fresh)
#     98   582     2     1 critic_name(Dave White) & publisher_name(Movies.com) & review_type(Fresh) & top_critic(False)
#     99   590     2     1 critic_name(Dave White) & review_type(Fresh) & top_critic(False)
#    100   550     2     1 critic_name(David Cornelius) & publisher_name(eFilmCritic.com) & top_critic(False)
#    101   613     2     1 critic_name(David Edwards) & publisher_name(Daily Mirror (UK)) & review_type(Fresh)
#    102   613     2     1 critic_name(David Edwards) & publisher_name(Daily Mirror (UK)) & review_type(Fresh) & top_critic(False)
#    103   641     2     1 critic_name(David Edwards) & review_type(Fresh) & top_critic(False)
#    104   609     2     1 critic_name(David Keyes) & publisher_name(Cinemaphile.org) & review_type(Fresh)
#    105   609     2     1 critic_name(David Keyes) & publisher_name(Cinemaphile.org) & review_type(Fresh) & top_critic(False)
#    106  1045     2     2 critic_name(David Keyes) & publisher_name(Cinemaphile.org) & top_critic(False)
#    107   614     2     1 critic_name(David Keyes) & review_type(Fresh) & top_critic(False)
#    108   531     2     1 critic_name(David N. Butterworth) & review_type(Fresh) & top_critic(False)
#    109  2697     2     1 critic_name(David Nusair) & publisher_name(Reel Film Reviews) & review_type(Fresh)
#    110  2697     2     1 critic_name(David Nusair) & publisher_name(Reel Film Reviews) & review_type(Fresh) & top_critic(False)
#    111  2710     2     1 critic_name(David Nusair) & review_type(Fresh) & top_critic(False)
#    112   726     2     1 critic_name(David Parkinson) & review_type(Fresh) & top_critic(False)
#    113   514     2     1 critic_name(David Sterritt) & publisher_name(Christian Science Monitor) & review_type(Fresh)
#    114   514     2     1 critic_name(David Sterritt) & publisher_name(Christian Science Monitor) & review_type(Fresh) & top_critic(False)
#    115   871     2     1 critic_name(David Sterritt) & publisher_name(Christian Science Monitor) & top_critic(False)
#    116   514     2     1 critic_name(David Sterritt) & review_type(Fresh) & top_critic(False)
#    117   504     2     1 critic_name(David Stratton) & publisher_name(The Australian) & top_critic(False)
#    118   780     2     1 critic_name(David Stratton) & review_type(Fresh) & top_critic(False)
#    119   516     2     1 critic_name(Diana Saenger) & publisher_name(ReviewExpress.com) & top_critic(False)
#    120   862     2     1 critic_name(Duane Dudek) & publisher_name(Milwaukee Journal Sentinel) & review_type(Fresh)
#    121   862     2     1 critic_name(Duane Dudek) & publisher_name(Milwaukee Journal Sentinel) & review_type(Fresh) & top_critic(False)
#    122  1247     2     1 critic_name(Duane Dudek) & publisher_name(Milwaukee Journal Sentinel) & top_critic(False)
#    123   862     2     1 critic_name(Duane Dudek) & review_type(Fresh) & top_critic(False)
#    124  1728     2     1 critic_name(Dustin Putman) & publisher_name(TheFilmFile.com) & review_type(Fresh)
#    125  1728     2     1 critic_name(Dustin Putman) & publisher_name(TheFilmFile.com) & review_type(Fresh) & top_critic(False)
#    126  1858     2     1 critic_name(Dustin Putman) & review_type(Fresh) & top_critic(False)
#    127   635     2     1 critic_name(Ed Gonzalez) & publisher_name(Slant Magazine) & review_type(Fresh)
#    128   635     2     1 critic_name(Ed Gonzalez) & publisher_name(Slant Magazine) & review_type(Fresh) & top_critic(False)
#    129   655     2     1 critic_name(Ed Gonzalez) & review_type(Fresh) & top_critic(False)
#    130  1138     2     1 critic_name(Edward Douglas) & publisher_name(ComingSoon.net) & review_type(Fresh)
#    131  1138     2     1 critic_name(Edward Douglas) & publisher_name(ComingSoon.net) & review_type(Fresh) & top_critic(False)
#    132  1711     2     1 critic_name(Edward Douglas) & publisher_name(ComingSoon.net) & top_critic(False)
#    133  1339     2     1 critic_name(Edward Douglas) & review_type(Fresh) & top_critic(False)
#    134   505     2     1 critic_name(Edward Johnson-Ott) & publisher_name(NUVO Newsweekly) & top_critic(False)
#    135   506     2     1 critic_name(Emily Blunt) & publisher_name(Blunt Review) & top_critic(False)
#    136   594     2     1 critic_name(Eric Melin) & publisher_name(Scene-Stealers.com) & review_type(Fresh)
#    137   594     2     1 critic_name(Eric Melin) & publisher_name(Scene-Stealers.com) & review_type(Fresh) & top_critic(False)
#    138   859     2     2 critic_name(Eric Melin) & publisher_name(Scene-Stealers.com) & top_critic(False)
#    139   780     2     1 critic_name(Eric Melin) & review_type(Fresh) & top_critic(False)
#    140   621     2     1 critic_name(Erik Childress) & publisher_name(eFilmCritic.com) & review_type(Fresh)
#    141   621     2     1 critic_name(Erik Childress) & publisher_name(eFilmCritic.com) & review_type(Fresh) & top_critic(False)
#    142  1210     2     2 critic_name(Erik Childress) & publisher_name(eFilmCritic.com) & top_critic(False)
#    143   638     2     1 critic_name(Erik Childress) & review_type(Fresh) & top_critic(False)
#    144   594     2     1 critic_name(Frank Ochieng) & review_type(Fresh) & top_critic(False)
#    145  2593     2     1 critic_name(Frederic and Mary Ann Brussat) & publisher_name(Spirituality & Practice) & review_type(Fresh)
#    146  2593     2     1 critic_name(Frederic and Mary Ann Brussat) & publisher_name(Spirituality & Practice) & review_type(Fresh) & top_critic(False)
#    147  3192     2     1 critic_name(Frederic and Mary Ann Brussat) & publisher_name(Spirituality & Practice) & top_critic(False)
#    148  2593     2     1 critic_name(Frederic and Mary Ann Brussat) & review_type(Fresh) & top_critic(False)
#    149   608     2     1 critic_name(Gary Wolcott) & publisher_name(Tri-City Herald) & review_type(Fresh)
#    150   608     2     1 critic_name(Gary Wolcott) & publisher_name(Tri-City Herald) & review_type(Fresh) & top_critic(False)
#    151  1018     2     1 critic_name(Gary Wolcott) & publisher_name(Tri-City Herald) & top_critic(False)
#    152   672     2     1 critic_name(Gary Wolcott) & review_type(Fresh) & top_critic(False)
#    153   732     2     2 critic_name(Glenn Whipp) & publisher_name(Los Angeles Daily News) & top_critic(False)
#    154   626     2     1 critic_name(Graham Young) & review_type(Fresh) & top_critic(False)
#    155   671     2     2 critic_name(Greg Maki) & publisher_name(Star-Democrat (Easton, MD)) & top_critic(False)
#    156   721     2     1 critic_name(Harvey S. Karten) & publisher_name(Compuserve) & review_type(Fresh)
#    157   721     2     1 critic_name(Harvey S. Karten) & publisher_name(Compuserve) & review_type(Fresh) & top_critic(False)
#    158   940     2     1 critic_name(Harvey S. Karten) & publisher_name(Compuserve) & top_critic(False)
#    159   722     2     1 critic_name(Harvey S. Karten) & review_type(Fresh) & top_critic(False)
#    160   699     2     1 critic_name(Ian Mantgani) & publisher_name(UK Critic) & top_critic(False)
#    161   731     2     1 critic_name(J. Olson) & publisher_name(Cinemixtape) & top_critic(False)
#    162  1189     2     1 critic_name(Jack Garner) & publisher_name(Rochester Democrat and Chronicle) & review_type(Fresh)
#    163  1189     2     1 critic_name(Jack Garner) & publisher_name(Rochester Democrat and Chronicle) & review_type(Fresh) & top_critic(False)
#    164  1589     2     1 critic_name(Jack Garner) & publisher_name(Rochester Democrat and Chronicle) & top_critic(False)
#    165  1212     2     1 critic_name(Jack Garner) & review_type(Fresh) & top_critic(False)
#    166   720     2     1 critic_name(Jackie K. Cooper) & publisher_name(jackiekcooper.com) & review_type(Fresh)
#    167   720     2     1 critic_name(Jackie K. Cooper) & publisher_name(jackiekcooper.com) & review_type(Fresh) & top_critic(False)
#    168   781     2     1 critic_name(Jackie K. Cooper) & review_type(Fresh) & top_critic(False)
#    169  2702     2     1 critic_name(James Berardinelli) & publisher_name(ReelViews) & review_type(Fresh)
#    170  2702     2     1 critic_name(James Berardinelli) & publisher_name(ReelViews) & review_type(Fresh) & top_critic(True)
#    171  5199     2     2 critic_name(James Berardinelli) & publisher_name(ReelViews) & top_critic(True)
#    172  2702     2     1 critic_name(James Berardinelli) & review_type(Fresh) & top_critic(True)
#    173  1776     2     1 critic_name(James Kendrick) & publisher_name(Q Network Film Desk) & review_type(Fresh)
#    174  1776     2     1 critic_name(James Kendrick) & publisher_name(Q Network Film Desk) & review_type(Fresh) & top_critic(False)
#    175  2727     2     1 critic_name(James Kendrick) & publisher_name(Q Network Film Desk) & top_critic(False)
#    176  1776     2     1 critic_name(James Kendrick) & review_type(Fresh) & top_critic(False)
#    177   590     2     1 critic_name(James Mottram) & review_type(Fresh) & top_critic(False)
#    178   798     2     1 critic_name(James Rocchi) & publisher_name(Netflix) & review_type(Fresh)
#    179   798     2     1 critic_name(James Rocchi) & publisher_name(Netflix) & review_type(Fresh) & top_critic(False)
#    180  1003     2     1 critic_name(James Rocchi) & publisher_name(Netflix) & top_critic(False)
#    181  1017     2     1 critic_name(James Rocchi) & review_type(Fresh) & top_critic(False)
#    182   512     2     1 critic_name(James Sanford) & publisher_name(Kalamazoo Gazette) & review_type(Fresh)
#    183   512     2     1 critic_name(James Sanford) & publisher_name(Kalamazoo Gazette) & review_type(Fresh) & top_critic(False)
#    184   852     2     2 critic_name(James Sanford) & publisher_name(Kalamazoo Gazette) & top_critic(False)
#    185   524     2     1 critic_name(James Sanford) & review_type(Fresh) & top_critic(False)
#    186   531     2     1 critic_name(James Verniere) & publisher_name(Boston Herald) & top_critic(False)
#    187   587     2     1 critic_name(Janet Maslin) & publisher_name(New York Times) & top_critic(True)
#    188   583     2     2 critic_name(Jason Zingale) & publisher_name(Bullz-Eye.com) & top_critic(False)
#    189   806     2     1 critic_name(Jeanne Aufmuth) & publisher_name(Palo Alto Weekly) & review_type(Fresh)
#    190   806     2     1 critic_name(Jeanne Aufmuth) & publisher_name(Palo Alto Weekly) & review_type(Fresh) & top_critic(False)
#    191  1216     2     1 critic_name(Jeanne Aufmuth) & publisher_name(Palo Alto Weekly) & top_critic(False)
#    192   831     2     1 critic_name(Jeanne Aufmuth) & review_type(Fresh) & top_critic(False)
#    193   979     2     1 critic_name(Jeff Vice) & publisher_name(Deseret News (Salt Lake City)) & review_type(Fresh)
#    194   979     2     1 critic_name(Jeff Vice) & publisher_name(Deseret News (Salt Lake City)) & review_type(Fresh) & top_critic(False)
#    195   993     2     1 critic_name(Jeff Vice) & review_type(Fresh) & top_critic(False)
#    196   627     2     1 critic_name(Jeffrey Chen) & publisher_name(Window to the Movies) & review_type(Fresh)
#    197   627     2     1 critic_name(Jeffrey Chen) & publisher_name(Window to the Movies) & review_type(Fresh) & top_critic(False)
#    198   919     2     1 critic_name(Jeffrey Chen) & publisher_name(Window to the Movies) & top_critic(False)
#    199   809     2     1 critic_name(Jeffrey Chen) & review_type(Fresh) & top_critic(False)
#    200   520     2     1 critic_name(Jeffrey Lyles) & publisher_name(Lyles' Movie Files) & review_type(Fresh)
#    201   520     2     1 critic_name(Jeffrey Lyles) & publisher_name(Lyles' Movie Files) & review_type(Fresh) & top_critic(False)
#    202   742     2     1 critic_name(Jeffrey Lyles) & publisher_name(Lyles' Movie Files) & top_critic(False)
#    203   618     2     1 critic_name(Jeffrey Lyles) & review_type(Fresh) & top_critic(False)
#    204  2163     2     1 critic_name(Jeffrey M. Anderson) & publisher_name(Combustible Celluloid) & review_type(Fresh)
#    205  2163     2     1 critic_name(Jeffrey M. Anderson) & publisher_name(Combustible Celluloid) & review_type(Fresh) & top_critic(False)
#    206  3087     2     1 critic_name(Jeffrey M. Anderson) & publisher_name(Combustible Celluloid) & top_critic(False)
#    207   510     2     1 critic_name(Jeffrey M. Anderson) & publisher_name(San Francisco Examiner) & top_critic(False)
#    208  3162     2     1 critic_name(Jeffrey M. Anderson) & review_type(Fresh) & top_critic(False)
#    209  1600     2     1 critic_name(Jeffrey Westhoff) & publisher_name(Northwest Herald (Crystal Lake, IL)) & review_type(Fresh)
#    210  1600     2     1 critic_name(Jeffrey Westhoff) & publisher_name(Northwest Herald (Crystal Lake, IL)) & review_type(Fresh) & top_critic(False)
#    211  1600     2     1 critic_name(Jeffrey Westhoff) & review_type(Fresh) & top_critic(False)
#    212   839     2     1 critic_name(Jennie Kermode) & publisher_name(Eye for Film) & review_type(Fresh)
#    213   839     2     1 critic_name(Jennie Kermode) & publisher_name(Eye for Film) & review_type(Fresh) & top_critic(False)
#    214  1017     2     1 critic_name(Jennie Kermode) & publisher_name(Eye for Film) & top_critic(False)
#    215   843     2     1 critic_name(Jennie Kermode) & review_type(Fresh) & top_critic(False)
#    216   782     2     2 critic_name(Jim Slotek) & publisher_name(Jam! Movies) & top_critic(False)
#    217   968     2     1 critic_name(JoBlo) & publisher_name(JoBlo's Movie Network) & review_type(Fresh)
#    218   968     2     1 critic_name(JoBlo) & publisher_name(JoBlo's Movie Network) & review_type(Fresh) & top_critic(False)
#    219  1427     2     1 critic_name(JoBlo) & publisher_name(JoBlo's Movie Network) & top_critic(False)
#    220   968     2     1 critic_name(JoBlo) & review_type(Fresh) & top_critic(False)
#    221   592     2     1 critic_name(Joe Baltake) & publisher_name(Sacramento Bee) & top_critic(False)
#    222   523     2     1 critic_name(Joe Lozito) & publisher_name(Big Picture Big Sound) & review_type(Fresh)
#    223   523     2     1 critic_name(Joe Lozito) & publisher_name(Big Picture Big Sound) & review_type(Fresh) & top_critic(False)
#    224   959     2     2 critic_name(Joe Lozito) & publisher_name(Big Picture Big Sound) & top_critic(False)
#    225   523     2     1 critic_name(Joe Lozito) & review_type(Fresh) & top_critic(False)
#    226   558     2     1 critic_name(Joe Williams) & publisher_name(St. Louis Post-Dispatch) & review_type(Fresh)
#    227   558     2     1 critic_name(Joe Williams) & publisher_name(St. Louis Post-Dispatch) & review_type(Fresh) & top_critic(True)
#    228   917     2     1 critic_name(Joe Williams) & publisher_name(St. Louis Post-Dispatch) & top_critic(True)
#    229   558     2     1 critic_name(Joe Williams) & review_type(Fresh) & top_critic(True)
#    230   502     2     1 critic_name(John Anderson) & publisher_name(Newsday) & review_type(Fresh)
#    231   502     2     1 critic_name(John Anderson) & publisher_name(Newsday) & review_type(Fresh) & top_critic(True)
#    232   833     2     1 critic_name(John Anderson) & publisher_name(Newsday) & top_critic(True)
#    233   506     2     1 critic_name(John Anderson) & review_type(Fresh) & top_critic(True)
#    234  1597     2     1 critic_name(John Beifuss) & publisher_name(Commercial Appeal (Memphis, TN)) & review_type(Fresh)
#    235  1597     2     1 critic_name(John Beifuss) & publisher_name(Commercial Appeal (Memphis, TN)) & review_type(Fresh) & top_critic(False)
#    236  2628     2     1 critic_name(John Beifuss) & publisher_name(Commercial Appeal (Memphis, TN)) & top_critic(False)
#    237  1597     2     1 critic_name(John Beifuss) & review_type(Fresh) & top_critic(False)
#    238   632     2     1 critic_name(John Hartl) & publisher_name(Seattle Times) & top_critic(True)
#    239  1071     2     1 critic_name(John J. Puccio) & publisher_name(Movie Metropolis) & review_type(Fresh)
#    240  1071     2     1 critic_name(John J. Puccio) & publisher_name(Movie Metropolis) & review_type(Fresh) & top_critic(False)
#    241  1972     2     1 critic_name(John J. Puccio) & publisher_name(Movie Metropolis) & top_critic(False)
#    242  1071     2     1 critic_name(John J. Puccio) & review_type(Fresh) & top_critic(False)
#    243   558     2     1 critic_name(John Lui) & publisher_name(The Straits Times (Singapore)) & top_critic(False)
#    244   518     2     1 critic_name(John R. McEwen) & publisher_name(Film Quips Online) & review_type(Fresh)
#    245   518     2     1 critic_name(John R. McEwen) & publisher_name(Film Quips Online) & review_type(Fresh) & top_critic(False)
#    246   786     2     1 critic_name(John R. McEwen) & publisher_name(Film Quips Online) & top_critic(False)
#    247   518     2     1 critic_name(John R. McEwen) & review_type(Fresh) & top_critic(False)
#    248   526     2     1 critic_name(John Serba) & publisher_name(MLive.com) & top_critic(False)
#    249   626     2     1 critic_name(John Urbancich) & publisher_name(Your Movies (cleveland.com)) & top_critic(False)
#    250   736     2     1 critic_name(John Wirt) & publisher_name(Advocate (Baton Rouge, LA)) & top_critic(False)
#    251   515     2     1 critic_name(Jon Niccum) & publisher_name(Lawrence Journal-World) & review_type(Fresh)
#    252   515     2     1 critic_name(Jon Niccum) & publisher_name(Lawrence Journal-World) & review_type(Fresh) & top_critic(False)
#    253   739     2     1 critic_name(Jon Niccum) & review_type(Fresh) & top_critic(False)
#    254   759     2     1 critic_name(Jon Popick) & publisher_name(Planet S Magazine) & top_critic(False)
#    255   594     2     1 critic_name(Jonathan W. Hickman) & review_type(Fresh) & top_critic(False)
#    256   669     2     1 critic_name(Josh Bell) & publisher_name(Las Vegas Weekly) & review_type(Fresh)
#    257   669     2     1 critic_name(Josh Bell) & publisher_name(Las Vegas Weekly) & review_type(Fresh) & top_critic(False)
#    258   750     2     1 critic_name(Josh Bell) & review_type(Fresh) & top_critic(False)
#    259  1067     2     1 critic_name(Josh Larsen) & publisher_name(LarsenOnFilm) & review_type(Fresh)
#    260  1067     2     1 critic_name(Josh Larsen) & publisher_name(LarsenOnFilm) & review_type(Fresh) & top_critic(False)
#    261  1469     2     1 critic_name(Josh Larsen) & publisher_name(LarsenOnFilm) & top_critic(False)
#    262   999     2     2 critic_name(Josh Larsen) & publisher_name(Sun Publications (Chicago, IL)) & top_critic(False)
#    263  1574     2     1 critic_name(Josh Larsen) & review_type(Fresh) & top_critic(False)
#    264   550     2     1 critic_name(Josh Terry) & publisher_name(Deseret News (Salt Lake City)) & top_critic(False)
#    265   789     2     1 critic_name(Joshua Rothkopf) & publisher_name(Time Out) & review_type(Fresh)
#    266   789     2     1 critic_name(Joshua Rothkopf) & publisher_name(Time Out) & review_type(Fresh) & top_critic(True)
#    267   789     2     1 critic_name(Joshua Rothkopf) & review_type(Fresh) & top_critic(True)
#    268   815     2     1 critic_name(Joshua Tyler) & publisher_name(CinemaBlend) & top_critic(False)
#    269   515     2     1 critic_name(Joshua Tyler) & review_type(Fresh) & top_critic(False)
#    270  1266     2     1 critic_name(Jules Brenner) & publisher_name(Cinema Signals) & review_type(Fresh)
#    271  1266     2     1 critic_name(Jules Brenner) & publisher_name(Cinema Signals) & review_type(Fresh) & top_critic(False)
#    272  1782     2     1 critic_name(Jules Brenner) & publisher_name(Cinema Signals) & top_critic(False)
#    273  1310     2     1 critic_name(Jules Brenner) & review_type(Fresh) & top_critic(False)
#    274   550     2     1 critic_name(Julian Roman) & publisher_name(MovieWeb) & review_type(Fresh)
#    275   550     2     1 critic_name(Julian Roman) & publisher_name(MovieWeb) & review_type(Fresh) & top_critic(False)
#    276   552     2     1 critic_name(Julian Roman) & review_type(Fresh) & top_critic(False)
#    277   531     2     1 critic_name(Kam Williams) & publisher_name(Baret News) & top_critic(False)
#    278   556     2     1 critic_name(Kam Williams) & publisher_name(NewsBlaze) & top_critic(False)
#    279  1587     2     1 critic_name(Kam Williams) & review_type(Fresh) & top_critic(False)
#    280   766     2     1 critic_name(Karina Montgomery) & publisher_name(Cinerina) & review_type(Fresh)
#    281   766     2     1 critic_name(Karina Montgomery) & publisher_name(Cinerina) & review_type(Fresh) & top_critic(False)
#    282   999     2     1 critic_name(Karina Montgomery) & publisher_name(Cinerina) & top_critic(False)
#    283   792     2     1 critic_name(Karina Montgomery) & review_type(Fresh) & top_critic(False)
#    284   576     2     1 critic_name(Kate Muir) & publisher_name(Times (UK)) & top_critic(True)
#    285   723     2     1 critic_name(Ken Fox) & publisher_name(TV Guide) & review_type(Fresh)
#    286   723     2     1 critic_name(Ken Fox) & publisher_name(TV Guide) & review_type(Fresh) & top_critic(False)
#    287  1069     2     1 critic_name(Ken Fox) & publisher_name(TV Guide) & top_critic(False)
#    288   723     2     1 critic_name(Ken Fox) & review_type(Fresh) & top_critic(False)
#    289  2940     2     1 critic_name(Ken Hanke) & publisher_name(Mountain Xpress (Asheville, NC)) & review_type(Fresh)
#    290  2940     2     1 critic_name(Ken Hanke) & publisher_name(Mountain Xpress (Asheville, NC)) & review_type(Fresh) & top_critic(False)
#    291  4188     2     1 critic_name(Ken Hanke) & publisher_name(Mountain Xpress (Asheville, NC)) & top_critic(False)
#    292  2940     2     1 critic_name(Ken Hanke) & review_type(Fresh) & top_critic(False)
#    293   960     2     1 critic_name(Kenneth Turan) & publisher_name(Los Angeles Times) & review_type(Fresh)
#    294   960     2     1 critic_name(Kenneth Turan) & publisher_name(Los Angeles Times) & review_type(Fresh) & top_critic(True)
#    295  1364     2     1 critic_name(Kenneth Turan) & publisher_name(Los Angeles Times) & top_critic(True)
#    296   961     2     1 critic_name(Kenneth Turan) & review_type(Fresh) & top_critic(True)
#    297   716     2     1 critic_name(Kevin A. Ranson) & publisher_name(MovieCrypt.com) & review_type(Fresh)
#    298   716     2     1 critic_name(Kevin A. Ranson) & publisher_name(MovieCrypt.com) & review_type(Fresh) & top_critic(False)
#    299   980     2     1 critic_name(Kevin A. Ranson) & publisher_name(MovieCrypt.com) & top_critic(False)
#    300   716     2     1 critic_name(Kevin A. Ranson) & review_type(Fresh) & top_critic(False)
#    301   864     2     1 critic_name(Kevin Carr) & publisher_name(7M Pictures) & review_type(Fresh)
#    302   864     2     1 critic_name(Kevin Carr) & publisher_name(7M Pictures) & review_type(Fresh) & top_critic(False)
#    303   606     2     1 critic_name(Kevin Carr) & publisher_name(Fat Guys at the Movies) & top_critic(False)
#    304  1297     2     1 critic_name(Kevin Carr) & review_type(Fresh) & top_critic(False)
#    305   735     2     1 critic_name(Kevin N. Laforest) & publisher_name(Montreal Film Journal) & review_type(Fresh)
#    306   735     2     1 critic_name(Kevin N. Laforest) & publisher_name(Montreal Film Journal) & review_type(Fresh) & top_critic(False)
#    307   955     2     1 critic_name(Kevin N. Laforest) & publisher_name(Montreal Film Journal) & top_critic(False)
#    308   738     2     1 critic_name(Kevin N. Laforest) & review_type(Fresh) & top_critic(False)
#    309   641     2     1 critic_name(Kevin Thomas) & publisher_name(Los Angeles Times) & review_type(Fresh)
#    310   641     2     1 critic_name(Kevin Thomas) & publisher_name(Los Angeles Times) & review_type(Fresh) & top_critic(True)
#    311   857     2     1 critic_name(Kevin Thomas) & publisher_name(Los Angeles Times) & top_critic(True)
#    312   642     2     1 critic_name(Kevin Thomas) & review_type(Fresh) & top_critic(True)
#    313   504     2     1 critic_name(Kim Newman) & publisher_name(Empire Magazine) & review_type(Fresh)
#    314   504     2     1 critic_name(Kim Newman) & publisher_name(Empire Magazine) & review_type(Fresh) & top_critic(False)
#    315   639     2     1 critic_name(Kim Newman) & publisher_name(Empire Magazine) & top_critic(False)
#    316   509     2     1 critic_name(Kim Newman) & review_type(Fresh) & top_critic(False)
#    317   614     2     1 critic_name(Kyle Smith) & publisher_name(New York Post) & review_type(Fresh)
#    318   614     2     1 critic_name(Kyle Smith) & publisher_name(New York Post) & review_type(Fresh) & top_critic(True)
#    319   614     2     1 critic_name(Kyle Smith) & review_type(Fresh) & top_critic(True)
#    320   508     2     1 critic_name(Larry Ratliff) & publisher_name(San Antonio Express-News) & top_critic(False)
#    321   601     2     1 critic_name(Lawrence Toppman) & publisher_name(Charlotte Observer) & review_type(Fresh)
#    322   601     2     1 critic_name(Lawrence Toppman) & publisher_name(Charlotte Observer) & review_type(Fresh) & top_critic(False)
#    323  1047     2     1 critic_name(Lawrence Toppman) & publisher_name(Charlotte Observer) & top_critic(False)
#    324   601     2     1 critic_name(Lawrence Toppman) & review_type(Fresh) & top_critic(False)
#    325  1251     2     1 critic_name(Leigh Paatsch) & publisher_name(Herald Sun (Australia)) & review_type(Fresh)
#    326  1251     2     1 critic_name(Leigh Paatsch) & publisher_name(Herald Sun (Australia)) & review_type(Fresh) & top_critic(False)
#    327  1272     2     1 critic_name(Leigh Paatsch) & review_type(Fresh) & top_critic(False)
#    328   628     2     1 critic_name(Liam Lacey) & publisher_name(Globe and Mail) & review_type(Fresh)
#    329   628     2     1 critic_name(Liam Lacey) & publisher_name(Globe and Mail) & review_type(Fresh) & top_critic(True)
#    330   628     2     1 critic_name(Liam Lacey) & review_type(Fresh) & top_critic(True)
#    331  1689     2     1 critic_name(Linda Cook) & publisher_name(Quad City Times (Davenport, IA)) & review_type(Fresh)
#    332  1689     2     1 critic_name(Linda Cook) & publisher_name(Quad City Times (Davenport, IA)) & review_type(Fresh) & top_critic(False)
#    333  2472     2     1 critic_name(Linda Cook) & publisher_name(Quad City Times (Davenport, IA)) & top_critic(False)
#    334  1898     2     1 critic_name(Linda Cook) & review_type(Fresh) & top_critic(False)
#    335   874     2     1 critic_name(Lisa Kennedy) & publisher_name(Denver Post) & review_type(Fresh)
#    336   874     2     1 critic_name(Lisa Kennedy) & publisher_name(Denver Post) & review_type(Fresh) & top_critic(True)
#    337  1162     2     1 critic_name(Lisa Kennedy) & publisher_name(Denver Post) & top_critic(True)
#    338   874     2     1 critic_name(Lisa Kennedy) & review_type(Fresh) & top_critic(True)
#    339   809     2     1 critic_name(Liz Braun) & publisher_name(Jam! Movies) & review_type(Fresh)
#    340   809     2     1 critic_name(Liz Braun) & publisher_name(Jam! Movies) & review_type(Fresh) & top_critic(False)
#    341  1178     2     2 critic_name(Liz Braun) & publisher_name(Jam! Movies) & top_critic(False)
#    342   809     2     1 critic_name(Liz Braun) & review_type(Fresh) & top_critic(False)
#    343   787     2     1 critic_name(Lori Hoffman) & publisher_name(Atlantic City Weekly) & review_type(Fresh)
#    344   787     2     1 critic_name(Lori Hoffman) & publisher_name(Atlantic City Weekly) & review_type(Fresh) & top_critic(False)
#    345   787     2     1 critic_name(Lori Hoffman) & review_type(Fresh) & top_critic(False)
#    346  1058     2     1 critic_name(Lou Lumenick) & publisher_name(New York Post) & review_type(Fresh)
#    347  1058     2     1 critic_name(Lou Lumenick) & publisher_name(New York Post) & review_type(Fresh) & top_critic(True)
#    348  2164     2     2 critic_name(Lou Lumenick) & publisher_name(New York Post) & top_critic(True)
#    349  1058     2     1 critic_name(Lou Lumenick) & review_type(Fresh) & top_critic(True)
#    350   838     2     1 critic_name(Maitland McDonagh) & publisher_name(TV Guide) & review_type(Fresh)
#    351   838     2     1 critic_name(Maitland McDonagh) & publisher_name(TV Guide) & review_type(Fresh) & top_critic(False)
#    352   845     2     1 critic_name(Maitland McDonagh) & review_type(Fresh) & top_critic(False)
#    353   544     2     1 critic_name(Manohla Dargis) & publisher_name(New York Times) & review_type(Fresh)
#    354   544     2     1 critic_name(Manohla Dargis) & publisher_name(New York Times) & review_type(Fresh) & top_critic(True)
#    355   625     2     1 critic_name(Manohla Dargis) & review_type(Fresh) & top_critic(True)
#    356  1197     2     1 critic_name(Marc Savlov) & publisher_name(Austin Chronicle) & review_type(Fresh)
#    357  1197     2     1 critic_name(Marc Savlov) & publisher_name(Austin Chronicle) & review_type(Fresh) & top_critic(False)
#    358  1200     2     1 critic_name(Marc Savlov) & review_type(Fresh) & top_critic(False)
#    359   515     2     1 critic_name(Margaret A. McGurk) & publisher_name(Cincinnati Enquirer) & top_critic(False)
#    360   536     2     1 critic_name(Margaret Pomeranz) & publisher_name(At the Movies (Australia)) & top_critic(False)
#    361   569     2     1 critic_name(Mark Kermode) & publisher_name(Observer (UK)) & review_type(Fresh)
#    362   569     2     1 critic_name(Mark Kermode) & publisher_name(Observer (UK)) & review_type(Fresh) & top_critic(False)
#    363   569     2     1 critic_name(Mark Kermode) & review_type(Fresh) & top_critic(False)
#    364   576     2     1 critic_name(Mark R. Leeper) & publisher_name(rec.arts.movies.reviews) & review_type(Fresh)
#    365   576     2     1 critic_name(Mark R. Leeper) & publisher_name(rec.arts.movies.reviews) & review_type(Fresh) & top_critic(False)
#    366   730     2     1 critic_name(Mark R. Leeper) & publisher_name(rec.arts.movies.reviews) & top_critic(False)
#    367   892     2     1 critic_name(Mark R. Leeper) & review_type(Fresh) & top_critic(False)
#    368   826     2     1 critic_name(Marty Mapes) & publisher_name(Movie Habit) & review_type(Fresh)
#    369   826     2     1 critic_name(Marty Mapes) & publisher_name(Movie Habit) & review_type(Fresh) & top_critic(False)
#    370  1136     2     1 critic_name(Marty Mapes) & publisher_name(Movie Habit) & top_critic(False)
#    371   826     2     1 critic_name(Marty Mapes) & review_type(Fresh) & top_critic(False)
#    372   611     2     1 critic_name(MaryAnn Johanson) & publisher_name(Flick Filosopher) & review_type(Fresh)
#    373   611     2     1 critic_name(MaryAnn Johanson) & publisher_name(Flick Filosopher) & review_type(Fresh) & top_critic(False)
#    374   617     2     1 critic_name(MaryAnn Johanson) & review_type(Fresh) & top_critic(False)
#    375  1771     2     1 critic_name(Matt Brunson) & publisher_name(Creative Loafing) & review_type(Fresh)
#    376  1771     2     1 critic_name(Matt Brunson) & publisher_name(Creative Loafing) & review_type(Fresh) & top_critic(False)
#    377  2906     2     1 critic_name(Matt Brunson) & publisher_name(Creative Loafing) & top_critic(False)
#    378   846     2     1 critic_name(Matt Brunson) & publisher_name(Film Frenzy) & top_critic(False)
#    379  2270     2     1 critic_name(Matt Brunson) & review_type(Fresh) & top_critic(False)
#    380   529     2     1 critic_name(Matt Donato) & publisher_name(We Got This Covered) & review_type(Fresh)
#    381   529     2     1 critic_name(Matt Donato) & publisher_name(We Got This Covered) & review_type(Fresh) & top_critic(False)
#    382   633     2     1 critic_name(Matt Donato) & review_type(Fresh) & top_critic(False)
#    383   566     2     1 critic_name(Matt Pais) & publisher_name(RedEye) & review_type(Fresh)
#    384   566     2     1 critic_name(Matt Pais) & publisher_name(RedEye) & review_type(Fresh) & top_critic(False)
#    385  1034     2     1 critic_name(Matt Pais) & review_type(Fresh) & top_critic(False)
#    386   577     2     1 critic_name(Matthew Lucas) & publisher_name(From the Front Row) & review_type(Fresh)
#    387   577     2     1 critic_name(Matthew Lucas) & publisher_name(From the Front Row) & review_type(Fresh) & top_critic(False)
#    388   721     2     1 critic_name(Matthew Lucas) & publisher_name(From the Front Row) & top_critic(False)
#    389   508     2     1 critic_name(Matthew Lucas) & publisher_name(The Dispatch (Lexington, NC)) & review_type(Fresh)
#    390   508     2     1 critic_name(Matthew Lucas) & publisher_name(The Dispatch (Lexington, NC)) & review_type(Fresh) & top_critic(False)
#    391   700     2     1 critic_name(Matthew Lucas) & publisher_name(The Dispatch (Lexington, NC)) & top_critic(False)
#    392  1085     2     1 critic_name(Matthew Lucas) & review_type(Fresh) & top_critic(False)
#    393   783     2     1 critic_name(Matthew Pejkovic) & publisher_name(Matt's Movie Reviews) & review_type(Fresh)
#    394   783     2     1 critic_name(Matthew Pejkovic) & publisher_name(Matt's Movie Reviews) & review_type(Fresh) & top_critic(False)
#    395   991     2     1 critic_name(Matthew Pejkovic) & publisher_name(Matt's Movie Reviews) & top_critic(False)
#    396   783     2     1 critic_name(Matthew Pejkovic) & review_type(Fresh) & top_critic(False)
#    397  2434     2     1 critic_name(Matthew Turner) & publisher_name(ViewLondon) & review_type(Fresh)
#    398  2434     2     1 critic_name(Matthew Turner) & publisher_name(ViewLondon) & review_type(Fresh) & top_critic(False)
#    399  3225     2     1 critic_name(Matthew Turner) & publisher_name(ViewLondon) & top_critic(False)
#    400  2786     2     1 critic_name(Matthew Turner) & review_type(Fresh) & top_critic(False)
#    401   861     2     1 critic_name(Michael A. Smith) & review_type(Fresh) & top_critic(False)
#    402  1495     2     1 critic_name(Michael Dequina) & publisher_name(TheMovieReport.com) & review_type(Fresh)
#    403  1495     2     1 critic_name(Michael Dequina) & publisher_name(TheMovieReport.com) & review_type(Fresh) & top_critic(False)
#    404  2810     2     2 critic_name(Michael Dequina) & publisher_name(TheMovieReport.com) & top_critic(False)
#    405  1546     2     1 critic_name(Michael Dequina) & review_type(Fresh) & top_critic(False)
#    406   546     2     1 critic_name(Michael O'Sullivan) & publisher_name(Washington Post) & review_type(Fresh)
#    407   546     2     1 critic_name(Michael O'Sullivan) & publisher_name(Washington Post) & review_type(Fresh) & top_critic(True)
#    408   546     2     1 critic_name(Michael O'Sullivan) & review_type(Fresh) & top_critic(True)
#    409  1416     2     1 critic_name(Michael Phillips) & publisher_name(Chicago Tribune) & review_type(Fresh)
#    410  1416     2     1 critic_name(Michael Phillips) & publisher_name(Chicago Tribune) & review_type(Fresh) & top_critic(True)
#    411  2296     2     1 critic_name(Michael Phillips) & publisher_name(Chicago Tribune) & top_critic(True)
#    412  1416     2     1 critic_name(Michael Phillips) & review_type(Fresh) & top_critic(True)
#    413   573     2     1 critic_name(Michael Smith) & publisher_name(Tulsa World) & top_critic(False)
#    414   678     2     2 critic_name(Michael Szymanski) & publisher_name(Zap2it.com) & top_critic(False)
#    415   579     2     1 critic_name(Michael Szymanski) & review_type(Fresh) & top_critic(False)
#    416   644     2     1 critic_name(Michael W. Phillips, Jr.) & publisher_name(Goatdog's Movies) & review_type(Fresh)
#    417   644     2     1 critic_name(Michael W. Phillips, Jr.) & publisher_name(Goatdog's Movies) & review_type(Fresh) & top_critic(False)
#    418   893     2     1 critic_name(Michael W. Phillips, Jr.) & publisher_name(Goatdog's Movies) & top_critic(False)
#    419   647     2     1 critic_name(Michael W. Phillips, Jr.) & review_type(Fresh) & top_critic(False)
#    420   615     2     1 critic_name(Michael Wilmington) & publisher_name(Chicago Tribune) & review_type(Fresh)
#    421   615     2     1 critic_name(Michael Wilmington) & publisher_name(Chicago Tribune) & review_type(Fresh) & top_critic(True)
#    422   857     2     1 critic_name(Michael Wilmington) & publisher_name(Chicago Tribune) & top_critic(True)
#    423   619     2     1 critic_name(Michael Wilmington) & review_type(Fresh) & top_critic(True)
#    424  1672     2     1 critic_name(Mick LaSalle) & publisher_name(San Francisco Chronicle) & review_type(Fresh)
#    425  1672     2     1 critic_name(Mick LaSalle) & publisher_name(San Francisco Chronicle) & review_type(Fresh) & top_critic(True)
#    426  2902     2     2 critic_name(Mick LaSalle) & publisher_name(San Francisco Chronicle) & top_critic(True)
#    427  1681     2     1 critic_name(Mick LaSalle) & review_type(Fresh) & top_critic(True)
#    428   801     2     1 critic_name(Mike Massie) & publisher_name(Gone With The Twins) & review_type(Fresh)
#    429   801     2     1 critic_name(Mike Massie) & publisher_name(Gone With The Twins) & review_type(Fresh) & top_critic(False)
# ...
#    691  1597     2     1 publisher_name(Commercial Appeal (Memphis, TN)) & review_type(Fresh) & top_critic(False)
#    692   721     2     1 publisher_name(Compuserve) & review_type(Fresh) & top_critic(False)
#    693   923     2     1 publisher_name(Contactmusic.com) & review_type(Fresh) & top_critic(False)
#    694   560     2     1 publisher_name(CraveOnline) & review_type(Fresh) & top_critic(False)
#    695  1771     2     1 publisher_name(Creative Loafing) & review_type(Fresh) & top_critic(False)
#    696  1001     2     1 publisher_name(Daily Mirror (UK)) & review_type(Fresh) & top_critic(False)
#    697  1240     2     1 publisher_name(Denver Post) & review_type(Fresh) & top_critic(True)
#    698  1548     2     1 publisher_name(Deseret News (Salt Lake City)) & review_type(Fresh) & top_critic(False)
#    699   831     2     1 publisher_name(Detroit Free Press) & review_type(Fresh) & top_critic(True)
#    700   709     2     1 publisher_name(Detroit News) & review_type(Fresh) & top_critic(True)
#    701  1049     2     1 publisher_name(Digital Spy) & review_type(Fresh) & top_critic(False)
#    702   656     2     1 publisher_name(Entertainment Spectrum) & review_type(Fresh) & top_critic(False)
#    703   647     2     1 publisher_name(Examiner.com) & review_type(Fresh) & top_critic(False)
#    704  1572     2     1 publisher_name(Eye for Film) & review_type(Fresh) & top_critic(False)
#    705  1593     2     1 publisher_name(Film Freak Central) & review_type(Fresh) & top_critic(False)
#    706   518     2     1 publisher_name(Film Quips Online) & review_type(Fresh) & top_critic(False)
#    707  4266     2     1 publisher_name(Film Threat) & review_type(Fresh) & top_critic(False)
#    708   910     2     1 publisher_name(Film-Forward.com) & review_type(Fresh) & top_critic(False)
#    709  1117     2     1 publisher_name(Film4) & review_type(Fresh) & top_critic(False)
#    710  3764     2     1 publisher_name(Filmcritic.com) & review_type(Fresh) & top_critic(False)
#    711   611     2     1 publisher_name(Flick Filosopher) & review_type(Fresh) & top_critic(False)
#    712   898     2     1 publisher_name(Flickering Myth) & review_type(Fresh) & top_critic(False)
#    713   577     2     1 publisher_name(From the Front Row) & review_type(Fresh) & top_critic(False)
#    714   536     2     1 publisher_name(Future Movies UK) & review_type(Fresh) & top_critic(False)
#    715  2643     2     1 publisher_name(Globe and Mail) & review_type(Fresh) & top_critic(True)
#    716   644     2     1 publisher_name(Goatdog's Movies) & review_type(Fresh) & top_critic(False)
#    717   801     2     1 publisher_name(Gone With The Twins) & review_type(Fresh) & top_critic(False)
#    718  1475     2     1 publisher_name(Groucho Reviews) & review_type(Fresh) & top_critic(False)
#    719  1253     2     1 publisher_name(Herald Sun (Australia)) & review_type(Fresh) & top_critic(False)
#    720  1364     2     1 publisher_name(HeyUGuys) & review_type(Fresh) & top_critic(False)
#    721  1276     2     1 publisher_name(Hollywood.com) & review_type(Fresh) & top_critic(False)
#    722   702     2     1 publisher_name(Houston Chronicle) & review_type(Fresh) & top_critic(True)
#    723  1692     2     1 publisher_name(IGN Movies) & review_type(Fresh) & top_critic(False)
#    724   566     2     1 publisher_name(IONCINEMA.com) & review_type(Fresh) & top_critic(False)
#    725  1340     2     1 publisher_name(Internet Reviews) & review_type(Fresh) & top_critic(False)
#    726  2396     2     1 publisher_name(Jam! Movies) & review_type(Fresh) & top_critic(False)
#    727  2288     2     1 publisher_name(JoBlo's Movie Network) & review_type(Fresh) & top_critic(False)
#    728  1066     2     1 publisher_name(Journal and Courier (Lafayette, IN)) & review_type(Fresh) & top_critic(False)
#    729   512     2     1 publisher_name(Kalamazoo Gazette) & review_type(Fresh) & top_critic(False)
#    730  1253     2     1 publisher_name(Kansas City Star) & review_type(Fresh) & top_critic(False)
#    731  1093     2     1 publisher_name(Killer Movie Reviews) & review_type(Fresh) & top_critic(False)
#    732   997     2     1 publisher_name(Laramie Movie Scope) & review_type(Fresh) & top_critic(False)
#    733  1067     2     1 publisher_name(LarsenOnFilm) & review_type(Fresh) & top_critic(False)
#    734  1737     2     1 publisher_name(Las Vegas Review-Journal) & review_type(Fresh) & top_critic(False)
#    735   675     2     1 publisher_name(Las Vegas Weekly) & review_type(Fresh) & top_critic(False)
#    736   589     2     1 publisher_name(Lawrence Journal-World) & review_type(Fresh) & top_critic(False)
#    737   948     2     1 publisher_name(Los Angeles Daily News) & review_type(Fresh) & top_critic(False)
#    738  3158     2     1 publisher_name(Los Angeles Times) & review_type(Fresh) & top_critic(True)
#    739   520     2     1 publisher_name(Lyles' Movie Files) & review_type(Fresh) & top_critic(False)
#    740  1123     2     1 publisher_name(Matt's Movie Reviews) & review_type(Fresh) & top_critic(False)
#    741   857     2     1 publisher_name(Metromix.com) & review_type(Fresh) & top_critic(False)
#    742  1495     2     1 publisher_name(Miami Herald) & review_type(Fresh) & top_critic(True)
#    743  1585     2     1 publisher_name(Milwaukee Journal Sentinel) & review_type(Fresh) & top_critic(False)
#    744   560     2     1 publisher_name(Minneapolis Star Tribune) & review_type(Fresh) & top_critic(True)
#    745   535     2     1 publisher_name(Monsters and Critics) & review_type(Fresh) & top_critic(False)
#    746   735     2     1 publisher_name(Montreal Film Journal) & review_type(Fresh) & top_critic(False)
#    747  2978     2     1 publisher_name(Mountain Xpress (Asheville, NC)) & review_type(Fresh) & top_critic(False)
#    748   826     2     1 publisher_name(Movie Habit) & review_type(Fresh) & top_critic(False)
#    749  1596     2     1 publisher_name(Movie Metropolis) & review_type(Fresh) & top_critic(False)
#    750  1093     2     1 publisher_name(Movie Mom) & review_type(Fresh) & top_critic(False)
#    751   716     2     1 publisher_name(MovieCrypt.com) & review_type(Fresh) & top_critic(False)
#    752  1545     2     1 publisher_name(MovieFreak.com) & review_type(Fresh) & top_critic(False)
#    753   571     2     1 publisher_name(MovieWeb) & review_type(Fresh) & top_critic(False)
#    754   884     2     1 publisher_name(Movies.com) & review_type(Fresh) & top_critic(False)
#    755   841     2     1 publisher_name(NYC Movie Guru) & review_type(Fresh) & top_critic(False)
#    756  1287     2     1 publisher_name(National Post) & review_type(Fresh) & top_critic(False)
#    757   593     2     1 publisher_name(Needcoffee.com) & review_type(Fresh) & top_critic(False)
#    758   798     2     1 publisher_name(Netflix) & review_type(Fresh) & top_critic(False)
#    759  2683     2     1 publisher_name(New York Daily News) & review_type(Fresh) & top_critic(True)
#    760  3108     2     1 publisher_name(New York Post) & review_type(Fresh) & top_critic(True)
#    761  4409     2     1 publisher_name(New York Times) & review_type(Fresh) & top_critic(True)
#    762   704     2     1 publisher_name(New Zealand Herald) & review_type(Fresh) & top_critic(False)
#    763  1201     2     1 publisher_name(Newark Star-Ledger) & review_type(Fresh) & top_critic(True)
#    764  1943     2     1 publisher_name(Newsday) & review_type(Fresh) & top_critic(True)
#    765   617     2     1 publisher_name(North Shore Movies) & review_type(Fresh) & top_critic(False)
#    766  1600     2     1 publisher_name(Northwest Herald (Crystal Lake, IL)) & review_type(Fresh) & top_critic(False)
#    767   556     2     1 publisher_name(Observer) & review_type(Fresh) & top_critic(True)
#    768  1094     2     1 publisher_name(Observer (UK)) & review_type(Fresh) & top_critic(False)
#    769   946     2     1 publisher_name(One Room With A View) & review_type(Fresh) & top_critic(False)
#    770  1273     2     1 publisher_name(Orlando Sentinel) & review_type(Fresh) & top_critic(True)
#    771   849     2     1 publisher_name(Orlando Weekly) & review_type(Fresh) & top_critic(False)
#    772  1455     2     1 publisher_name(Palo Alto Weekly) & review_type(Fresh) & top_critic(False)
#    773  1310     2     1 publisher_name(Paste Magazine) & review_type(Fresh) & top_critic(False)
#    774  2647     2     1 publisher_name(Philadelphia Inquirer) & review_type(Fresh) & top_critic(True)
#    775  1370     2     1 publisher_name(PopMatters) & review_type(Fresh) & top_critic(False)
#    776   599     2     1 publisher_name(Punch Drunk Critics) & review_type(Fresh) & top_critic(False)
#    777  1776     2     1 publisher_name(Q Network Film Desk) & review_type(Fresh) & top_critic(False)
#    778  1689     2     1 publisher_name(Quad City Times (Davenport, IA)) & review_type(Fresh) & top_critic(False)
#    779   675     2     1 publisher_name(Quickflix) & review_type(Fresh) & top_critic(False)
#    780   722     2     1 publisher_name(RTÉ (Ireland)) & review_type(Fresh) & top_critic(False)
#    781   616     2     1 publisher_name(RedEye) & review_type(Fresh) & top_critic(False)
#    782  2697     2     1 publisher_name(Reel Film Reviews) & review_type(Fresh) & top_critic(False)
#    783  1548     2     1 publisher_name(Reel.com) & review_type(Fresh) & top_critic(False)
#    784  2702     2     1 publisher_name(ReelViews) & review_type(Fresh) & top_critic(True)
#    785  1191     2     1 publisher_name(Rochester Democrat and Chronicle) & review_type(Fresh) & top_critic(False)
#    786  1806     2     1 publisher_name(RogerEbert.com) & review_type(Fresh) & top_critic(True)
#    787  2173     2     1 publisher_name(Rolling Stone) & review_type(Fresh) & top_critic(True)
#    788  1144     2     1 publisher_name(SPLICEDWire) & review_type(Fresh) & top_critic(False)
#    789  1257     2     1 publisher_name(SSG Syndicate) & review_type(Fresh) & top_critic(False)
#    790   781     2     1 publisher_name(Sacramento Bee) & review_type(Fresh) & top_critic(False)
#    791  1410     2     1 publisher_name(Salt Lake Tribune) & review_type(Fresh) & top_critic(False)
#    792   929     2     1 publisher_name(San Diego Union-Tribune) & review_type(Fresh) & top_critic(False)
#    793  4011     2     1 publisher_name(San Francisco Chronicle) & review_type(Fresh) & top_critic(True)
#    794   918     2     1 publisher_name(San Francisco Examiner) & review_type(Fresh) & top_critic(False)
#    795   691     2     1 publisher_name(San Jose Mercury News) & review_type(Fresh) & top_critic(True)
#    796   594     2     1 publisher_name(Scene-Stealers.com) & review_type(Fresh) & top_critic(False)
#    797   614     2     1 publisher_name(Schmoes Know) & review_type(Fresh) & top_critic(False)
#    798  1085     2     1 publisher_name(Screen Rant) & review_type(Fresh) & top_critic(False)
#    799  3312     2     1 publisher_name(Seattle Times) & review_type(Fresh) & top_critic(True)
#    800  2892     2     1 publisher_name(Shadows on the Wall) & review_type(Fresh) & top_critic(False)
#    801  3255     2     1 publisher_name(Slant Magazine) & review_type(Fresh) & top_critic(False)
#    802   527     2     1 publisher_name(South China Morning Post) & review_type(Fresh) & top_critic(False)
#    803   547     2     1 publisher_name(South Florida Sun-Sentinel) & review_type(Fresh) & top_critic(False)
#    804  2593     2     1 publisher_name(Spirituality & Practice) & review_type(Fresh) & top_critic(False)
#    805  1096     2     1 publisher_name(St. Louis Post-Dispatch) & review_type(Fresh) & top_critic(True)
#    806  2258     2     1 publisher_name(St. Paul Pioneer Press) & review_type(Fresh) & top_critic(False)
#    807   790     2     1 publisher_name(Starburst) & review_type(Fresh) & top_critic(False)
#    808  1134     2     1 publisher_name(Sydney Morning Herald) & review_type(Fresh) & top_critic(True)
#    809  4036     2     1 publisher_name(TV Guide) & review_type(Fresh) & top_critic(False)
#    810   689     2     1 publisher_name(The Age (Australia)) & review_type(Fresh) & top_critic(True)
#    811   628     2     1 publisher_name(The Arts Desk) & review_type(Fresh) & top_critic(False)
#    812   761     2     1 publisher_name(The Australian) & review_type(Fresh) & top_critic(False)
#    813   508     2     1 publisher_name(The Dispatch (Lexington, NC)) & review_type(Fresh) & top_critic(False)
#    814   818     2     1 publisher_name(The Dissolve) & review_type(Fresh) & top_critic(False)
#    815   679     2     1 publisher_name(The Film Yap) & review_type(Fresh) & top_critic(False)
#    816  1824     2     1 publisher_name(The List) & review_type(Fresh) & top_critic(False)
#    817   540     2     1 publisher_name(The Mail on Sunday (UK)) & review_type(Fresh) & top_critic(False)
#    818   777     2     1 publisher_name(The Skinny) & review_type(Fresh) & top_critic(False)
#    819   566     2     1 publisher_name(The Times of India) & review_type(Fresh) & top_critic(False)
#    820   796     2     1 publisher_name(The Young Folks) & review_type(Fresh) & top_critic(False)
#    821  1728     2     1 publisher_name(TheFilmFile.com) & review_type(Fresh) & top_critic(False)
#    822  1463     2     1 publisher_name(TheIndependentCritic.com) & review_type(Fresh) & top_critic(False)
#    823  1495     2     1 publisher_name(TheMovieReport.com) & review_type(Fresh) & top_critic(False)
#    824   858     2     1 publisher_name(Three Movie Buffs) & review_type(Fresh) & top_critic(False)
#    825  1692     2     1 publisher_name(Times (UK)) & review_type(Fresh) & top_critic(True)
#    826   532     2     1 publisher_name(Tolucan Times) & review_type(Fresh) & top_critic(False)
#    827  2767     2     1 publisher_name(Toronto Star) & review_type(Fresh) & top_critic(True)
#    828  2846     2     1 publisher_name(Total Film) & review_type(Fresh) & top_critic(False)
#    829   608     2     1 publisher_name(Tri-City Herald) & review_type(Fresh) & top_critic(False)
#    830   823     2     1 publisher_name(Tribune News Service) & review_type(Fresh) & top_critic(False)
#    831   514     2     1 publisher_name(Tulsa World) & review_type(Fresh) & top_critic(False)
#    832  1989     2     1 publisher_name(USA Today) & review_type(Fresh) & top_critic(True)
#    833   509     2     1 publisher_name(Video-Reviewmaster.com) & review_type(Fresh) & top_critic(False)
#    834  2569     2     1 publisher_name(ViewLondon) & review_type(Fresh) & top_critic(False)
#    835   939     2     1 publisher_name(WaffleMovies.com) & review_type(Fresh) & top_critic(False)
#    836  2056     2     1 publisher_name(Washington Post) & review_type(Fresh) & top_critic(True)
#    837  1462     2     1 publisher_name(We Got This Covered) & review_type(Fresh) & top_critic(False)
#    838   504     2     1 publisher_name(What Culture) & review_type(Fresh) & top_critic(False)
#    839   627     2     1 publisher_name(Window to the Movies) & review_type(Fresh) & top_critic(False)
#    840  1156     2     1 publisher_name(Worcester Telegram & Gazette) & review_type(Fresh) & top_critic(False)
#    841   659     2     1 publisher_name(Your Movies (cleveland.com)) & review_type(Fresh) & top_critic(False)
#    842   580     2     1 publisher_name(Zap2it.com) & review_type(Fresh) & top_critic(False)
#    843  5591     2     1 publisher_name(eFilmCritic.com) & review_type(Fresh) & top_critic(False)
#    844   720     2     1 publisher_name(jackiekcooper.com) & review_type(Fresh) & top_critic(False)
#    845  2354     2     1 publisher_name(rec.arts.movies.reviews) & review_type(Fresh) & top_critic(False)
#    846   637     2     1 publisher_name(www.susangranger.com) & review_type(Fresh) & top_critic(False)
#
#
#
# Rule id : 2
#
# Base :   882  Relative base : 0.001  Steps UP (consecutive) :     2  Steps DOWN (consecutive) :     1  Steps UP (any) :     3  Steps DOWN (any) :     1  Histogram maximum :   511  Histogram minimum :     0  Histogram relative maximum : 0.579 Histogram relative minimum : 0.000
#
# Condition  : critic_name(A.O. Scott) & publisher_name(New York Times) & review_type(Fresh) & top_critic(True)
#
# Histogram [1, 240, 511, 0, 130]

# %% [markdown]
# ## Otazka 7 - neni nic moc :D

# %%
df = data
df=df.loc[:, ('critic_name','top_critic', 'review_score_interval')]



clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.7, 'Base': 100},
               ante ={
                    'attributes':[
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'critic_name', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':2, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Warning: Python 3.10+ NOT detected. You should upgrade to Python 3.10 or greater to get better performance
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 1561, rules 4,control number:0, times: prep 27.53919005393982, processing 53.20040535926819
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 1561
# Number of rules : 4
# Total time needed : 00h 01m 20s
# Time of data preparation : 00h 00m 27s
# Time of rule mining : 00h 00m 53s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1   150 0.754 +1.062 top_critic(False) & critic_name(Alan Ng) => review_score_interval(70-90) | ---
#      2   168 0.709 +0.939 top_critic(False) & critic_name(Anita Katz) => review_score_interval(70-90) | ---
#      3   100 0.775 +1.120 top_critic(False) & critic_name(Joe Bendel) => review_score_interval(70-90) | ---
#      4   157 0.809 +1.214 top_critic(False) & critic_name(Piers Marchant) => review_score_interval(70-90) | ---
#
#
#
# Rule id : 2
#
# Base :   168  Relative base : 0.000  CONF : 0.709  AAD : +0.939  BAD : -0.939
#
# Cedents:
#   antecedent : top_critic(False) & critic_name(Anita Katz)
#   succcedent : review_score_interval(70-90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |  168|   69|
# ----|-----|-----|
# ¬A  |251236|436164|
# ----|-----|-----|

# %% [markdown]
# ## Otazka 3

# %%
# bezi cca 2m 24s

df = data
df=df.loc[:, ('release_decade_interval', 'review_score_interval', 'genres', 'production_company')]



clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.6, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'genres', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'release_decade_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':3, 'maxlen':3, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Warning: Python 3.10+ NOT detected. You should upgrade to Python 3.10 or greater to get better performance
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 2984, rules 279,control number:0, times: prep 16.278171062469482, processing 128.39154815673828
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 2984
# Number of rules : 279
# Total time needed : 00h 02m 24s
# Time of data preparation : 00h 00m 16s
# Time of rule mining : 00h 02m 08s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1    78 0.634 +0.732 production_company(20th Century Fox) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      2    55 0.655 +0.788 production_company(20th Century Fox) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      3    83 0.659 +0.799 production_company(20th Century Fox) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      4    82 0.774 +7.201 production_company(20th Century Fox) & genres(['Action & Adventure', 'Drama', 'Science Fiction & Fantasy']) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#      5   176 0.642 +0.754 production_company(20th Century Fox) & genres(['Animation', 'Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      6    56 0.615 +0.681 production_company(20th Century Fox) & genres(['Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      7    90 0.652 +0.781 production_company(20th Century Fox) & genres(['Comedy', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      8   134 0.663 +0.812 production_company(20th Century Fox) & genres(['Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      9    67 0.670 +0.830 production_company(A24) & genres(['Comedy', 'Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     10    86 0.729 +0.991 production_company(A24) & genres(['Comedy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     11    92 0.605 +0.653 production_company(A24) & genres(['Drama', 'Horror']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     12    83 0.624 +0.704 production_company(A24 Films) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     13    61 0.642 +0.754 production_company(A24 Films) & genres(['Comedy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     14    83 0.610 +0.667 production_company(A24 Films) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     15   130 0.812 +1.219 production_company(A24 and DIRECTV) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     16    61 0.670 +0.831 production_company(Abramorama) & genres(['Documentary', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     17    52 0.612 +0.671 production_company(Adopt Films) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     18   108 0.639 +0.745 production_company(Amazon Studios) & genres(['Comedy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     19   104 0.623 +0.701 production_company(Annapurna Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     20    55 0.611 +0.669 production_company(Anonymous Content) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     21    61 0.616 +0.683 production_company(Artisan Entertainment) & genres(['Action & Adventure', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     22   134 0.632 +0.726 production_company(Artisan Entertainment) & genres(['Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     23    80 0.702 +0.917 production_company(Artisan Entertainment) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     24    64 0.711 +0.942 production_company(Artisan Entertainment) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     25    87 0.617 +0.685 production_company(BBC Films) & genres(['Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     26   128 0.707 +0.931 production_company(Bad Robot Productions) & genres(['Drama', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     27   108 0.688 +0.879 production_company(Big Beach Films) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     28    68 0.602 +0.644 production_company(Blumhouse Productions) & genres(['Action & Adventure', 'Horror', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     29    67 0.620 +0.900 production_company(Broad Green Pictures) & genres(['Action & Adventure', 'Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#     30    63 0.724 +0.978 production_company(Broad Green Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     31    61 0.635 +0.735 production_company(Buena Vista Pictures) & genres(['Action & Adventure', 'Comedy', 'Kids & Family', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     32    87 0.613 +0.673 production_company(Buena Vista Pictures) & genres(['Action & Adventure', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     33    57 0.640 +5.789 production_company(Buena Vista Pictures) & genres(['Animation', 'Comedy', 'Kids & Family']) & release_decade_interval(1990's) => review_score_interval(>90) | ---
#     34    54 0.675 +0.844 production_company(CG Cinéma) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     35    74 0.627 +0.713 production_company(Castle Rock Entertainment) & genres(['Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     36    67 0.615 +0.679 production_company(Cinema Guild) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     37    54 0.635 +0.945 production_company(Columbia Pictures) & genres(['Action & Adventure', 'Animation']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#     38    80 0.870 +8.218 production_company(Columbia Pictures) & genres(['Action & Adventure', 'Art House & International', 'Classics', 'Drama']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     39    79 0.669 +8.641 production_company(Columbia Pictures) & genres(['Action & Adventure', 'Comedy', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#     40    52 0.765 +10.012 production_company(Columbia Pictures) & genres(['Comedy', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#     41    50 0.633 +5.709 production_company(Columbia Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#     42   125 0.625 +0.707 production_company(Disney/Pixar) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#     43   145 0.636 +0.737 production_company(Disney/Pixar) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     44    66 0.629 +0.717 production_company(Disney/Pixar) & genres(['Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     45   108 0.643 +0.969 production_company(DreamWorks SKG) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Romance']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#     46    82 0.641 +0.750 production_company(DreamWorks SKG) & genres(['Action & Adventure', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     47    76 0.628 +0.715 production_company(DreamWorks/Paramount Distribution) & genres(['Comedy', 'Documentary', 'Science Fiction & Fantasy', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     48   100 0.629 +0.718 production_company(DreamWorks/Paramount Studios) & genres(['Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     49    73 0.619 +0.690 production_company(Dreamworks) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     50    88 0.620 +5.570 production_company(Dreamworks Distribution) & genres(['Action & Adventure', 'Drama']) & release_decade_interval(1990's) => review_score_interval(>90) | ---
#     51   113 0.604 +0.650 production_company(Dreamworks Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     52    90 0.608 +0.661 production_company(Dreamworks/Paramount) & genres(['Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     53    66 0.606 +0.654 production_company(EuropaCorp / STXfilms) & genres(['Comedy', 'Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     54   105 0.625 +0.707 production_company(Film 44) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     55   120 0.600 +0.639 production_company(Film District) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     56   188 0.635 +0.735 production_company(Film Movement) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     57    57 0.648 +0.983 production_company(Film4) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#     58   108 0.675 +0.844 production_company(FilmRise) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     59   115 0.697 +0.904 production_company(Fingerprint Releasing / Bleecker Street) & genres(['Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     60   102 0.729 +0.990 production_company(Fireworks Pictures) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     61    73 0.670 +0.829 production_company(Focus Features) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     62    70 0.625 +0.707 production_company(Focus Features) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     63   107 0.622 +0.699 production_company(Focus Features) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     64    81 0.604 +0.651 production_company(Focus Features) & genres(['Action & Adventure', 'Animation', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     65   186 0.715 +0.954 production_company(Focus Features) & genres(['Action & Adventure', 'Comedy', 'Horror', 'Science Fiction & Fantasy', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     66    66 0.667 +0.821 production_company(Focus Features) & genres(['Art House & International', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     67   114 0.659 +0.800 production_company(Focus Features) & genres(['Comedy', 'Drama', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     68    94 0.606 +0.656 production_company(Focus Features) & genres(['Drama', 'Gay & Lesbian']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     69    56 0.602 +0.645 production_company(Focus Features) & genres(['Drama', 'Musical & Performing Arts', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     70    58 0.604 +0.650 production_company(Focus Features) & genres(['Drama']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#     71    65 0.602 +0.644 production_company(Fox Searchlight) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     72    69 0.633 +0.729 production_company(Fox Searchlight) & genres(['Drama', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     73    77 0.636 +0.738 production_company(Fox Searchlight) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     74    96 0.662 +0.808 production_company(Fox Searchlight Pictures) & genres(['Drama', 'Musical & Performing Arts', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     75    68 0.607 +0.658 production_company(Fox Searchlight Pictures) & genres(['Drama', 'Mystery & Suspense', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     76   234 0.636 +0.737 production_company(Fox Searchlight Pictures) & genres(['Horror', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     77   107 0.748 +1.044 production_company(Fox Searchlight Pictures) & genres(['Horror', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     78    65 0.631 +0.724 production_company(Freestyle Releasing) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     79    72 0.655 +0.788 production_company(GKIDS) & genres(['Animation', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     80   130 0.610 +0.667 production_company(Greenwich Entertainment) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     81    61 0.678 +0.851 production_company(Gunpowder & Sky) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     82    72 0.632 +0.725 production_company(HBO Films) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     83    55 0.611 +0.669 production_company(Hurricane Films) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     84    79 0.669 +0.828 production_company(IFC) & genres(['Art House & International', 'Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     85    99 0.678 +0.852 production_company(IFC) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     86    82 0.745 +1.036 production_company(IFC Films) & genres(['Art House & International', 'Drama', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     87    84 0.667 +0.821 production_company(IFC Films) & genres(['Art House & International', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     88    75 0.620 +0.693 production_company(IFC Films) & genres(['Comedy']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#     89   108 0.730 +0.993 production_company(IFC Films) & genres(['Documentary', 'Horror', 'Television']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     90   113 0.720 +0.966 production_company(IFC Films) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     91    79 0.622 +0.699 production_company(IFC Films) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     92   331 0.604 +0.650 production_company(IFC Films) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     93   140 0.625 +0.707 production_company(IFC Films) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     94   120 0.659 +0.801 production_company(IFC Films) & genres(['Drama', 'Horror']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#     95    90 0.652 +0.781 production_company(IFC Midnight) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     96   296 0.655 +0.789 production_company(IMAX) & genres(['Action & Adventure', 'Drama', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     97   102 0.630 +0.720 production_company(Independent Pictures) & genres(['Documentary', 'Sports & Fitness']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     98    68 0.872 +8.242 production_company(Janus Films) & genres(['Action & Adventure', 'Art House & International', 'Classics', 'Drama', 'Science Fiction & Fantasy']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     99    60 0.769 +7.154 production_company(Janus Films) & genres(['Art House & International', 'Classics', 'Drama', 'Mystery & Suspense']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#    100    71 0.651 +0.779 production_company(Janus Films) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    101    64 0.640 +0.960 production_company(Keep Your Head) & genres(['Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    102    82 0.701 +0.914 production_company(Kino International) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    103    50 0.617 +0.686 production_company(Kissiki Film) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    104   174 0.696 +0.901 production_company(Likely Story) & genres(['Art House & International', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    105   128 0.640 +0.748 production_company(Lions Gate) & genres(['Art House & International', 'Comedy', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    106    82 0.683 +0.866 production_company(Lions Gate Films) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    107   138 0.690 +0.885 production_company(Lions Gate Films Inc.) & genres(['Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    108    54 0.643 +0.756 production_company(Lions Gate Releasing) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    109   125 0.665 +8.575 production_company(Lionsgate) & genres(['Action & Adventure', 'Horror']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#    110   158 0.775 +1.115 production_company(Lionsgate) & genres(['Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    111    51 0.911 +12.115 production_company(Lionsgate) & genres(['Comedy']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#    112   134 0.657 +0.794 production_company(Lionsgate) & genres(['Drama', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    113    94 0.676 +0.847 production_company(Lionsgate Films) & genres(['Action & Adventure', 'Drama', 'Western']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    114    53 0.602 +0.844 production_company(Lionsgate Films) & genres(['Drama', 'Horror', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    115   138 0.611 +0.668 production_company(Lionsgate and Roadside Attractions) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    116    85 0.739 +1.019 production_company(Lionsgate/Roadside Attractions) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    117    58 0.667 +0.821 production_company(MGM/Sidney Kimmel Entertainment) & genres(['Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    118   102 0.630 +8.067 production_company(MGM/UA Distribution Company) & genres(['Action & Adventure', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#    119    74 0.679 +0.854 production_company(MTV Films) & genres(['Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    120    75 0.620 +0.693 production_company(Magnet/Magnolia Pictures) & genres(['Art House & International', 'Drama', 'Horror']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    121    67 0.698 +0.906 production_company(Magnolia Pictures) & genres(['Action & Adventure', 'Art House & International', 'Comedy', 'Drama', 'Horror']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    122    79 0.658 +0.798 production_company(Magnolia Pictures) & genres(['Action & Adventure', 'Art House & International', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    123    57 0.770 +1.104 production_company(Magnolia Pictures) & genres(['Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    124    72 0.615 +0.681 production_company(Magnolia Pictures) & genres(['Documentary', 'Special Interest', 'Television']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    125   257 0.618 +0.687 production_company(Magnolia Pictures) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    126    53 0.609 +0.664 production_company(Magnolia Pictures) & genres(['Drama', 'Mystery & Suspense', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    127    58 0.617 +0.889 production_company(Miramax) & genres(['Action & Adventure', 'Animation', 'Musical & Performing Arts', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    128    69 0.600 +0.639 production_company(Miramax) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    129    60 0.612 +0.672 production_company(Miramax Films) & genres(['Action & Adventure', 'Animation', 'Drama', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(1990's) => review_score_interval(70-90) | ---
#    130   114 0.655 +5.945 production_company(Miramax Films) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(>90) | ---
#    131    65 0.747 +1.041 production_company(Miramax Films) & genres(['Art House & International', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    132    54 0.659 +0.799 production_company(Miramax Films) & genres(['Comedy', 'Romance']) & release_decade_interval(1990's) => review_score_interval(70-90) | ---
#    133   114 0.640 +0.749 production_company(Miramax and Roadside Attractions) & genres(['Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    134    68 0.694 +0.895 production_company(Motto Pictures) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    135   134 0.606 +0.656 production_company(Music Box Films) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    136    97 0.660 +0.802 production_company(Music Box Films) & genres(['Art House & International', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    137    56 0.602 +0.645 production_company(Music Box Films) & genres(['Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    138   170 0.780 +7.267 production_company(NEON) & genres(['Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(>90) | ---
#    139   105 0.705 +0.925 production_company(NEON) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    140   127 0.635 +0.734 production_company(National Geographic) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    141   187 0.649 +0.773 production_company(Netflix) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    142   107 0.641 +5.792 production_company(New Line Cinema) & genres(['Action & Adventure', 'Classics', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(>90) | ---
#    143   326 0.644 +0.760 production_company(New Line Cinema) & genres(['Action & Adventure', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    144    69 0.767 +1.094 production_company(New Line Cinema) & genres(['Art House & International', 'Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    145    82 0.603 +7.683 production_company(New Line Cinema) & genres(['Comedy', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#    146    68 0.694 +0.895 production_company(New Video) & genres(['Art House & International', 'Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    147    67 0.720 +0.968 production_company(Newmarket Films) & genres(['Drama']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    148    74 0.612 +5.483 production_company(Orion Pictures Corporation) & genres(['Horror', 'Mystery & Suspense']) & release_decade_interval(1990's) => review_score_interval(>90) | ---
#    149    71 0.657 +0.795 production_company(Oscilloscope Pictures) & genres(['Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    150   104 0.703 +0.919 production_company(Overture Films) & genres(['Drama', 'Horror', 'Science Fiction & Fantasy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    151    83 0.722 +0.971 production_company(Paladin Pictures) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    152    67 0.644 +0.759 production_company(Palm Pictures) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    153    77 0.688 +0.878 production_company(Palm Pictures) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    154    64 0.667 +0.821 production_company(Palm Pictures) & genres(['Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    155   166 0.610 +0.869 production_company(Paramount) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    156    98 0.645 +0.761 production_company(Paramount) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    157   256 0.667 +0.821 production_company(Paramount) & genres(['Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    158    55 0.764 +1.086 production_company(Paramount Classics) & genres(['Documentary', 'Kids & Family', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    159    61 0.616 +0.683 production_company(Paramount Classics) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    160   176 0.620 +0.693 production_company(Paramount Pictures) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    161    53 0.855 +8.062 production_company(Paramount Pictures) & genres(['Action & Adventure', 'Art House & International', 'Classics', 'Drama', 'Science Fiction & Fantasy']) & release_decade_interval(1920's) => review_score_interval(>90) | ---
#    162   103 0.602 +0.645 production_company(Paramount Pictures) & genres(['Action & Adventure', 'Drama', 'Western']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    163    83 0.790 +7.380 production_company(Paramount Pictures) & genres(['Classics', 'Drama']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#    164   154 0.720 +6.629 production_company(Paramount Pictures) & genres(['Classics', 'Horror', 'Mystery & Suspense']) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#    165    77 0.675 +6.160 production_company(Paramount Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#    166    77 0.606 +5.427 production_company(Paramount Pictures) & genres(['Drama']) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#    167    96 0.615 +0.681 production_company(Paramount Pictures) & genres(['Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    168   114 0.695 +0.898 production_company(Paramount Studios) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    169    75 0.664 +1.032 production_company(Paramount Studios) & genres(['Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    170    93 0.660 +0.801 production_company(Paramount/DWA) & genres(['Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    171    67 0.632 +0.726 production_company(Paramount/Dreamworks) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    172   120 0.632 +0.725 production_company(Petit Film) & genres(['Horror']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    173    75 0.701 +0.914 production_company(Picturehouse) & genres(['Drama', 'Horror', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    174    86 0.601 +5.375 production_company(Picturehouse) & genres(['Drama', 'Horror', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(>90) | ---
#    175    70 0.603 +0.648 production_company(Piki Films) & genres(['Action & Adventure', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    176    61 0.726 +0.983 production_company(Race Point Films) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    177    67 0.705 +0.926 production_company(Radius-TWC) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    178    94 0.644 +0.758 production_company(Radius-TWC) & genres(['Horror']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    179    75 0.615 +0.679 production_company(Radius-TWC) & genres(['Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    180   172 0.647 +0.766 production_company(Radius-TWC) & genres(['Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    181    76 0.760 +7.057 production_company(Rialto Pictures) & genres(['Action & Adventure', 'Art House & International', 'Classics', 'Drama']) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#    182   140 0.673 +0.838 production_company(Roadside Attractions) & genres(['Action & Adventure', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    183    56 0.609 +0.662 production_company(Roadside Attractions) & genres(['Art House & International', 'Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    184   121 0.647 +0.767 production_company(Roadside Attractions) & genres(['Art House & International', 'Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    185   127 0.641 +0.752 production_company(Roadside Attractions) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    186    81 0.628 +0.715 production_company(Roadside Attractions) & genres(['Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    187    59 0.694 +0.896 production_company(Rogue Pictures) & genres(['Comedy', 'Documentary', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    188    54 0.711 +6.532 production_company(Royal Films International) & genres(['Classics', 'Drama', 'Horror', 'Mystery & Suspense']) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#    189    93 0.762 +1.082 production_company(STX Entertainment) & genres(['Comedy', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    190    90 0.726 +0.982 production_company(STX Entertainment) & genres(['Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    191   122 0.601 +0.641 production_company(Scott Rudin Productions) & genres(['Action & Adventure', 'Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    192    53 0.616 +0.887 production_company(Screen Gems) & genres(['Comedy', 'Romance']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    193    50 0.602 +0.645 production_company(Shadow Distribution) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    194    96 0.686 +0.873 production_company(Shudder and NEON) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    195   109 0.690 +0.884 production_company(Sony) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    196    54 0.614 +0.676 production_company(Sony Classic Pictures) & genres(['Documentary', 'Drama', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    197    50 0.602 +0.645 production_company(Sony Classics) & genres(['Drama', 'Sports & Fitness']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    198    68 0.648 +0.769 production_company(Sony Pictures) & genres(['Action & Adventure', 'Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    199    68 0.613 +0.673 production_company(Sony Pictures) & genres(['Animation', 'Comedy', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    200   189 0.604 +0.649 production_company(Sony Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    201    74 0.638 +0.742 production_company(Sony Pictures Classics) & genres(['Action & Adventure', 'Art House & International', 'Comedy', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    202    72 0.632 +0.725 production_company(Sony Pictures Classics) & genres(['Action & Adventure', 'Art House & International', 'Drama', 'Mystery & Suspense']) & release_decade_interval(1990's) => review_score_interval(70-90) | ---
#    203    60 0.723 +6.663 production_company(Sony Pictures Classics) & genres(['Action & Adventure', 'Art House & International', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(>90) | ---
#    204   136 0.624 +0.704 production_company(Sony Pictures Classics) & genres(['Art House & International', 'Comedy', 'Drama', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    205    63 0.724 +0.978 production_company(Sony Pictures Classics) & genres(['Comedy', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    206    62 0.697 +0.903 production_company(Sony Pictures Classics) & genres(['Comedy', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    207   130 0.653 +0.784 production_company(Sony Pictures Classics) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    208    88 0.677 +0.849 production_company(Sony Pictures Classics) & genres(['Documentary', 'Special Interest', 'Sports & Fitness']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    209   199 0.630 +0.720 production_company(Sony Pictures Classics) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    210   158 0.615 +0.679 production_company(Sony Pictures Classics) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    211    72 0.632 +0.725 production_company(Sony Pictures Classics) & genres(['Documentary', 'Sports & Fitness']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    212   140 0.636 +0.738 production_company(Sony Pictures Classics) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    213    74 0.755 +1.062 production_company(Sony Pictures Classics) & genres(['Drama', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    214    59 0.656 +0.790 production_company(Sony Pictures Classics) & genres(['Drama', 'Sports & Fitness']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    215    84 0.651 +0.778 production_company(Sony Pictures Classics) & genres(['Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    216    76 0.608 +0.661 production_company(Sony Pictures/Screen Gems) & genres(['Comedy', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    217    76 0.650 +0.774 production_company(Strand Releasing) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    218    60 0.619 +0.689 production_company(Studio Ghibli) & genres(['Animation', 'Art House & International']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    219    69 0.645 +0.761 production_company(StudioCanal) & genres(['Art House & International', 'Drama', 'Mystery & Suspense', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    220   118 0.656 +0.790 production_company(Summit Entertainment) & genres(['Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    221    73 0.646 +0.764 production_company(Sundance Selects) & genres(['Documentary']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    222    54 0.761 +1.077 production_company(The Orchard) & genres(['Art House & International', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    223    50 0.617 +0.686 production_company(The Weinstein Co.) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    224    65 0.625 +0.707 production_company(The Weinstein Company) & genres(['Action & Adventure', 'Comedy', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    225    66 0.846 +11.185 production_company(The Weinstein Company) & genres(['Comedy', 'Horror', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(<30) | ---
#    226    79 0.806 +1.202 production_company(The Weinstein Company) & genres(['Comedy', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    227    50 0.704 +0.923 production_company(Think Film) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    228    53 0.646 +0.765 production_company(ThinkFilm) & genres(['Documentary', 'Musical & Performing Arts', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    229   104 0.608 +0.661 production_company(ThinkFilm) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    230   145 0.636 +0.737 production_company(ThinkFilm) & genres(['Documentary']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    231    53 0.602 +0.844 production_company(Touchstone Pictures) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Musical & Performing Arts', 'Romance']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    232    67 0.604 +0.848 production_company(Touchstone Pictures) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    233   136 0.642 +0.964 production_company(Touchstone Pictures) & genres(['Action & Adventure', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    234    87 0.604 +0.650 production_company(TriStar Pictures) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    235    57 0.663 +1.030 production_company(Twentieth Century Fox) & genres(['Action & Adventure', 'Animation', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    236    70 0.814 +7.629 production_company(United Artists) & genres(['Classics', 'Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#    237    72 0.706 +6.483 production_company(United Artists) & genres(['Drama']) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#    238    98 0.624 +0.705 production_company(Universal) & genres(['Comedy', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    239    50 0.667 +0.821 production_company(Universal) & genres(['Drama']) & release_decade_interval(1990's) => review_score_interval(70-90) | ---
#    240    67 0.620 +0.900 production_company(Universal Pictures) & genres(['Drama', 'Horror', 'Mystery & Suspense', 'Romance']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    241   190 0.629 +0.718 production_company(Universal Pictures) & genres(['Drama', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    242   158 0.678 +0.852 production_company(Universal Pictures) & genres(['Horror', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2020's) => review_score_interval(70-90) | ---
#    243    52 0.788 +7.352 production_company(Universal Pictures) & genres(['Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#    244   119 0.661 +0.806 production_company(Universal Studios) & genres(['Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    245    54 0.600 +0.639 production_company(Variance Films) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    246   112 0.640 +0.748 production_company(Walt Disney Animation Studios) & genres(['Action & Adventure', 'Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    247   246 0.719 +0.965 production_company(Walt Disney Animation Studios) & genres(['Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    248    70 0.614 +0.677 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Animation', 'Art House & International', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    249    83 0.654 +0.785 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Animation', 'Comedy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    250   131 0.630 +0.720 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    251    83 0.634 +0.940 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    252   137 0.688 +0.880 production_company(Walt Disney Pictures) & genres(['Action & Adventure', 'Kids & Family']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    253    69 0.734 +1.005 production_company(Walt Disney Pictures) & genres(['Animation', 'Art House & International', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    254    93 0.637 +0.740 production_company(Walt Disney Pictures) & genres(['Animation', 'Comedy', 'Horror', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    255    93 0.628 +0.716 production_company(Walt Disney Pictures) & genres(['Animation', 'Comedy', 'Kids & Family', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    256    83 0.654 +0.785 production_company(Walt Disney Pictures) & genres(['Comedy', 'Kids & Family', 'Romance']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    257    66 0.606 +0.854 production_company(Walt Disney Pictures) & genres(['Documentary', 'Drama']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    258   137 0.688 +0.880 production_company(Walt Disney Pictures/PIXAR) & genres(['Animation']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    259   146 0.619 +0.894 production_company(Walt Disney Studios) & genres(['Action & Adventure', 'Comedy', 'Drama', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(50-70) | ---
#    260    77 0.658 +0.797 production_company(Warner Bros. Pictures) & genres(['Action & Adventure', 'Animation', 'Comedy', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    261   249 0.616 +0.683 production_company(Warner Bros. Pictures) & genres(['Action & Adventure', 'Drama', 'Kids & Family', 'Mystery & Suspense', 'Science Fiction & Fantasy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    262   107 0.728 +0.988 production_company(Warner Bros. Pictures) & genres(['Action & Adventure', 'Drama', 'Mystery & Suspense', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    263   119 0.640 +0.747 production_company(Warner Bros. Pictures) & genres(['Animation', 'Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    264    58 0.879 +8.316 production_company(Warner Bros. Pictures) & genres(['Classics', 'Kids & Family', 'Musical & Performing Arts', 'Science Fiction & Fantasy']) & release_decade_interval(1930's) => review_score_interval(>90) | ---
#    265    88 0.647 +0.981 production_company(Warner Bros. Pictures) & genres(['Comedy', 'Drama', 'Kids & Family']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    266    70 0.614 +0.880 production_company(Warner Bros. Pictures) & genres(['Comedy', 'Drama', 'Musical & Performing Arts']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    267    66 0.600 +5.361 production_company(Warner Bros. Pictures) & genres(['Drama', 'Horror', 'Mystery & Suspense', 'Special Interest']) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#    268    59 0.615 +0.882 production_company(Warner Bros. Pictures/New Line Cinema) & genres(['Action & Adventure', 'Kids & Family', 'Science Fiction & Fantasy']) & release_decade_interval(2000's) => review_score_interval(50-70) | ---
#    269    69 0.616 +0.683 production_company(Warner Independent Pictures) & genres(['Documentary']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    270    51 0.689 +0.882 production_company(Weinstein Company) & genres(['Documentary', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    271    78 0.605 +0.651 production_company(Weinstein Company) & genres(['Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    272    84 0.706 +0.928 production_company(Well Go USA Entertainment) & genres(['Action & Adventure', 'Art House & International', 'Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    273    74 0.649 +0.773 production_company(Wellspring) & genres(['Drama', 'Mystery & Suspense']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    274    50 0.667 +0.821 production_company(Zeitgeist Films) & genres(['Documentary', 'Drama', 'Special Interest']) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#    275    51 0.680 +0.857 production_company(Zeitgeist Films) & genres(['Documentary', 'Musical & Performing Arts']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    276   161 0.674 +0.840 production_company(Zeitgeist Films) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    277    52 0.722 +0.973 production_company(levelFILM) & genres(['Drama']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    278    70 0.619 +0.692 production_company(nan) & genres(['Comedy']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#    279    83 0.716 +0.954 production_company(s) & genres(['Comedy', 'Drama', 'Romance']) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#
#
#
# Rule id : 2
#
# Base :    55  Relative base : 0.000  CONF : 0.655  AAD : +0.788  BAD : -0.788
#
# Cedents:
#   antecedent : production_company(20th Century Fox) & genres(['Action & Adventure', 'Animation', 'Kids & Family']) & release_decade_interval(2000's)
#   succcedent : review_score_interval(70-90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |   55|   29|
# ----|-----|-----|
# ¬A  |247286|428158|
# ----|-----|-----|

# %% [markdown]
# ## Otázka 4

# %% [markdown]
# ### 4ftMiner

# %%
df = data
df=df.loc[:, ('tomatometer_rating_interval', 'release_decade_interval', 'production_company')]



clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.8, 'Base': 100},
               ante ={
                    'attributes':[
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'release_decade_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':2, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'tomatometer_rating_interval', 'type': 'one', 'value': '>90'},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

# print(clm.result)
clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Warning: Python 3.10+ NOT detected. You should upgrade to Python 3.10 or greater to get better performance
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 249, rules 50,control number:0, times: prep 15.51873254776001, processing 10.54705810546875
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 249
# Number of rules : 50
# Total time needed : 00h 00m 26s
# Time of data preparation : 00h 00m 15s
# Time of rule mining : 00h 00m 10s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1   112 0.830 +3.447 production_company(20th Century Fox) & release_decade_interval(1940's) => tomatometer_rating_interval(>90) | ---
#      2   241 1.000 +4.361 production_company(21 Laps Entertainment) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#      3   181 1.000 +4.361 production_company(Bad Robot Productions) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#      4   126 0.813 +3.358 production_company(CJ Entertainment) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#      5   215 0.827 +3.433 production_company(Columbia Pictures) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#      6   104 1.000 +4.361 production_company(Criterion Collection) & release_decade_interval(1920's) => tomatometer_rating_interval(>90) | ---
#      7   107 0.915 +3.902 production_company(Criterion Collection) & release_decade_interval(1940's) => tomatometer_rating_interval(>90) | ---
#      8   199 0.816 +3.372 production_company(Criterion Collection) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#      9   449 0.849 +3.550 production_company(Criterion Collection) & release_decade_interval(1960's) => tomatometer_rating_interval(>90) | ---
#     10   424 1.000 +4.361 production_company(Disney/Pixar) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     11   904 0.871 +3.669 production_company(Disney/Pixar) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     12   122 1.000 +4.361 production_company(Drafthouse Recommends) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     13   372 0.925 +3.961 production_company(Element Pictures) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     14   168 1.000 +4.361 production_company(Film 44) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     15   166 1.000 +4.361 production_company(Fingerprint Releasing / Bleecker Street) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     16   225 1.000 +4.361 production_company(Fox Searchlight Pictures, Film4 and Waypoint) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     17   452 1.000 +4.361 production_company(IMAX) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     18   157 1.000 +4.361 production_company(Ideaman Studios) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     19   256 1.000 +4.361 production_company(Janus Films) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#     20   110 0.815 +3.368 production_company(Janus Films) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     21   171 1.000 +4.361 production_company(June Pictures) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     22   140 1.000 +4.361 production_company(K5 International) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     23   117 0.836 +3.480 production_company(Kino International) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     24   187 0.866 +3.641 production_company(MGM) & release_decade_interval(1930's) => tomatometer_rating_interval(>90) | ---
#     25   200 1.000 +4.361 production_company(National Geographic) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     26   119 0.844 +3.524 production_company(New Video) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     27   110 0.887 +3.755 production_company(New Yorker Films) & release_decade_interval(1970's) => tomatometer_rating_interval(>90) | ---
#     28   115 1.000 +4.361 production_company(Paladin Pictures) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     29   130 0.909 +3.873 production_company(Paramount Home Video) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#     30   143 0.831 +3.457 production_company(Paramount Pictures) & release_decade_interval(1940's) => tomatometer_rating_interval(>90) | ---
#     31   141 1.000 +4.361 production_company(Paramount/DWA) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     32   190 1.000 +4.361 production_company(Petit Film) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     33   116 1.000 +4.361 production_company(Piki Films) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     34   252 0.810 +3.344 production_company(Rialto Pictures) & release_decade_interval(1960's) => tomatometer_rating_interval(>90) | ---
#     35   100 1.000 +4.361 production_company(Rialto Pictures) & release_decade_interval(1980's) => tomatometer_rating_interval(>90) | ---
#     36   192 1.000 +4.361 production_company(Roadside Attractions ) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     37   137 1.000 +4.361 production_company(Rogue Pictures/Focus Features) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     38   126 1.000 +4.361 production_company(SBS Productions) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     39   204 1.000 +4.361 production_company(Scott Rudin Productions) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     40   142 1.000 +4.361 production_company(Shudder and NEON) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     41   152 1.000 +4.361 production_company(Starburns Industries) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     42   122 0.968 +4.190 production_company(The Cinema Guild) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     43   195 1.000 +4.361 production_company(United Artists) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#     44   112 0.911 +3.881 production_company(United Artists Films) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     45   191 0.834 +3.471 production_company(Universal Pictures) & release_decade_interval(1940's) => tomatometer_rating_interval(>90) | ---
#     46   102 0.850 +3.557 production_company(WARNER BROTHERS PICTURES) & release_decade_interval(1930's) => tomatometer_rating_interval(>90) | ---
#     47   100 0.909 +3.873 production_company(Warner Bros. Pictures) & release_decade_interval(1930's) => tomatometer_rating_interval(>90) | ---
#     48   307 0.819 +3.389 production_company(Warner Bros. Pictures) & release_decade_interval(1950's) => tomatometer_rating_interval(>90) | ---
#     49   203 1.000 +4.361 production_company(Warner Bros. Pictures/Legendary) & release_decade_interval(2000's) => tomatometer_rating_interval(>90) | ---
#     50   117 1.000 +4.361 production_company(s) & release_decade_interval(2010's) => tomatometer_rating_interval(>90) | ---
#
#
#
# Rule id : 2
#
# Base :   241  Relative base : 0.000  CONF : 1.000  AAD : +4.361  BAD : -4.361
#
# Cedents:
#   antecedent : production_company(21 Laps Entertainment) & release_decade_interval(2010's)
#   succcedent : tomatometer_rating_interval(>90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |  241|    0|
# ----|-----|-----|
# ¬A  |127035|555007|
# ----|-----|-----|

# %% [markdown]
# ## Question X: Hledání souvislosti mezi režiséry a review score

# %% [markdown]
# ### Jak se liší hodnocení filmů na základě režiséra, doby trvání a vhodnosti obsahu

# %%
# be patient, runs approx 50secs!
df = data
df=df.loc[:, ('directors', 'runtime_interval', 'content_rating', 'review_score_interval')]

clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.8, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'directors', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'content_rating', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':3, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 9780, rules 30,control number:0, times: prep 28.036372900009155, processing 16.148449897766113
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 9780
# Number of rules : 30
# Total time needed : 00h 00m 44s
# Time of data preparation : 00h 00m 28s
# Time of rule mining : 00h 00m 16s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1    80 0.870 +8.264 directors(Akira Kurosawa) & runtime_interval(>2.5h) & content_rating(G) => review_score_interval(>90) | ---
#      2    84 0.824 +7.773 directors(Akira Kurosawa) & content_rating(G) => review_score_interval(>90) | ---
#      3    53 0.828 +7.822 directors(Carol Reed) & runtime_interval(1.5-1.75h) => review_score_interval(>90) | ---
#      4    53 0.828 +7.822 directors(Carol Reed) & runtime_interval(1.5-1.75h) & content_rating(NR) => review_score_interval(>90) | ---
#      5    53 0.855 +8.107 directors(Fritz Lang) & runtime_interval(2-2.5) & content_rating(PG-13) => review_score_interval(>90) | ---
#      6    53 0.855 +8.107 directors(Fritz Lang) & content_rating(PG-13) => review_score_interval(>90) | ---
#      7    56 0.889 +8.470 directors(Jean Renoir) & runtime_interval(1.75-2h) => review_score_interval(>90) | ---
#      8    56 0.889 +8.470 directors(Jean Renoir) & runtime_interval(1.75-2h) & content_rating(NR) => review_score_interval(>90) | ---
#      9    70 0.814 +7.671 directors(John Huston, Billy Wilder) & runtime_interval(2-2.5) => review_score_interval(>90) | ---
#     10    70 0.814 +7.671 directors(John Huston, Billy Wilder) & runtime_interval(2-2.5) & content_rating(G) => review_score_interval(>90) | ---
#     11    70 0.814 +7.671 directors(John Huston, Billy Wilder) & content_rating(G) => review_score_interval(>90) | ---
#     12   130 0.812 +1.222 directors(John M. Maclean) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#     13   130 0.812 +1.222 directors(John M. Maclean) & runtime_interval(1.5-1.75h) & content_rating(R) => review_score_interval(70-90) | ---
#     14   130 0.812 +1.222 directors(John M. Maclean) & content_rating(R) => review_score_interval(70-90) | ---
#     15    58 0.879 +8.362 directors(King Vidor, Victor Fleming) & runtime_interval(1.5-1.75h) => review_score_interval(>90) | ---
#     16    58 0.879 +8.362 directors(King Vidor, Victor Fleming) & runtime_interval(1.5-1.75h) & content_rating(G) => review_score_interval(>90) | ---
#     17    58 0.879 +8.362 directors(King Vidor, Victor Fleming) & content_rating(G) => review_score_interval(>90) | ---
#     18    54 0.806 +1.204 directors(Lauren Greenfield) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#     19    54 0.806 +1.204 directors(Lauren Greenfield) & runtime_interval(1.5-1.75h) & content_rating(PG) => review_score_interval(70-90) | ---
#     20    54 0.806 +1.204 directors(Lauren Greenfield) & content_rating(PG) => review_score_interval(70-90) | ---
#     21    79 0.806 +1.205 directors(Paul King (VII), Marcos Da Silva) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#     22    79 0.806 +1.205 directors(Paul King (VII), Marcos Da Silva) & runtime_interval(1.5-1.75h) & content_rating(PG) => review_score_interval(70-90) | ---
#     23    79 0.806 +1.205 directors(Paul King (VII), Marcos Da Silva) & content_rating(PG) => review_score_interval(70-90) | ---
#     24    77 0.802 +7.545 directors(Stanley Donen, Gene Kelly) & runtime_interval(1.5-1.75h) => review_score_interval(>90) | ---
#     25    72 0.947 +9.093 directors(Stanley Donen, Gene Kelly) & runtime_interval(1.5-1.75h) & content_rating(G) => review_score_interval(>90) | ---
#     26    72 0.947 +9.093 directors(Stanley Donen, Gene Kelly) & content_rating(G) => review_score_interval(>90) | ---
#     27    53 0.803 +1.196 directors(Tobias Lindholm) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#     28    53 0.803 +1.196 directors(Tobias Lindholm) & runtime_interval(1.5-1.75h) & content_rating(R) => review_score_interval(70-90) | ---
#     29   131 0.819 +10.793 directors(Uwe Boll) & runtime_interval(1.5-1.75h) => review_score_interval(<30) | ---
#     30   131 0.819 +10.793 directors(Uwe Boll) & runtime_interval(1.5-1.75h) & content_rating(R) => review_score_interval(<30) | ---
#
#
#
# Rule id : 2
#
# Base :    84  Relative base : 0.000  CONF : 0.824  AAD : +7.773  BAD : -7.773
#
# Cedents:
#   antecedent : directors(Akira Kurosawa) & content_rating(G)
#   succcedent : review_score_interval(>90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |   84|   18|
# ----|-----|-----|
# ¬A  |64475|623189|
# ----|-----|-----|

# %% [markdown]
# ## Question Y: Hledání souvislosti mezi kritiky a review score

# %% [markdown]
# ### Jak se liší hodnocení filmů na základě kritika, zda je kritic top a  doby trvání

# %%
# be patient, runs approx 50secs!
df = data
df=df.loc[:, ('critic_name', 'runtime_interval', 'review_score', 'top_critic', 'review_score_interval')]

clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.8, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'critic_name', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'top_critic', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':3, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Warning: Python 3.10+ NOT detected. You should upgrade to Python 3.10 or greater to get better performance
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 8842, rules 9,control number:0, times: prep 26.825095891952515, processing 218.41206002235413
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 8842
# Number of rules : 9
# Total time needed : 00h 04m 05s
# Time of data preparation : 00h 00m 26s
# Time of rule mining : 00h 03m 38s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1    61 0.813 +1.221 critic_name(Anita Katz) & runtime_interval(1.5-1.75h) => review_score_interval(70-90) | ---
#      2    61 0.813 +1.221 critic_name(Anita Katz) & runtime_interval(1.5-1.75h) & top_critic(False) => review_score_interval(70-90) | ---
#      3    56 0.933 +1.549 critic_name(Piers Marchant) & runtime_interval(1.75-2h) => review_score_interval(70-90) | ---
#      4    56 0.933 +1.549 critic_name(Piers Marchant) & runtime_interval(1.75-2h) & top_critic(False) => review_score_interval(70-90) | ---
#      5    52 0.852 +1.328 critic_name(Piers Marchant) & runtime_interval(2-2.5) => review_score_interval(70-90) | ---
#      6    52 0.852 +1.328 critic_name(Piers Marchant) & runtime_interval(2-2.5) & top_critic(False) => review_score_interval(70-90) | ---
#      7   155 0.807 +1.205 critic_name(Piers Marchant) & top_critic(False) => review_score_interval(70-90) | ---
#      8    58 0.806 +1.200 critic_name(Reagan Gavin Rasquinha) & runtime_interval(2-2.5) => review_score_interval(70-90) | ---
#      9    58 0.806 +1.200 critic_name(Reagan Gavin Rasquinha) & runtime_interval(2-2.5) & top_critic(False) => review_score_interval(70-90) | ---
#
#
#
# Rule id : 2
#
# Base :    61  Relative base : 0.000  CONF : 0.813  AAD : +1.221  BAD : -1.221
#
# Cedents:
#   antecedent : critic_name(Anita Katz) & runtime_interval(1.5-1.75h) & top_critic(False)
#   succcedent : review_score_interval(70-90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |   61|   14|
# ----|-----|-----|
# ¬A  |247280|428173|
# ----|-----|-----|

# %% [markdown]
# ## bonus: horror movies

# %%
horror_scores = dict()
for row in tqdm(range(data.shape[0])):
    if 'Horror' in data['genres'][row]:
        value = data['review_score'][row]
        name = data['movie_title'][row]
        if name not in horror_scores.keys():
            horror_scores[name] = [value]
        else:
            horror_scores[name].append(value)
# Out:
#   0%|          | 0/675528 [00:00<?, ?it/s]

# %%
# calculating average scores for each actor
final_horror_scores = {}
for key in tqdm(horror_scores.keys()):
    # add only actors with 3000+ reviews 
    if len(horror_scores[key]) > 50:
        mean = np.mean(horror_scores[key])
        final_horror_scores[key] = round(mean, 1)
# Out:
#   0%|          | 0/1777 [00:00<?, ?it/s]

# %%
top_horrors = sorted(final_horror_scores.items(), key=lambda x: x[1], reverse=True)
top_horrors
# Out:
# [('Repulsion', 91.1),
#  ('Aliens', 90.8),
#  ("Rosemary's Baby", 90.6),
#  ('The Silence of the Lambs', 90.2),
#  ("Pan's Labyrinth", 89.2),
#  ('The Shining', 86.5),
#  ('Seconds', 85.5),
#  ('Let the Right One In', 85.3),
#  ('Psycho', 84.7),
#  ('Get Out', 83.6),
#  ('Hereditary', 82.3),
#  ('A Quiet Place', 81.9),
#  ('The Babadook', 81.7),
#  ('Night of the Living Dead', 81.4),
#  ('It Follows', 81.3),
#  ('Under The Shadow', 81.0),
#  ('The Lighthouse', 80.5),
#  ('The Fly', 80.2),
#  ('Re-Animator', 80.2),
#  ('A Girl Walks Home Alone at Night', 80.1),
#  ('Shaun of the Dead', 80.1),
#  ('The Blair Witch Project', 79.8),
#  ('The Cabin in the Woods', 79.8),
#  ('Us', 79.8),
#  ('Raw', 78.6),
#  ('The Witch', 77.9),
#  ('The Invisible Man', 77.8),
#  ('Freaks', 77.3),
#  ('The Love Witch', 76.9),
#  ('Drag Me to Hell', 76.6),
#  ('Green Room', 76.6),
#  ('The Host', 76.6),
#  ('The Little Stranger', 76.4),
#  ('Train to Busan (Busanhaeng)', 76.4),
#  ('Relic', 76.3),
#  ('28 Days Later', 76.1),
#  ('Midsommar', 76.1),
#  ('The Others', 76.0),
#  ('Santa Sangre', 75.7),
#  ('The Descent', 75.6),
#  ('Let Me In', 75.6),
#  ('The Endless', 75.6),
#  ('Room 237', 75.4),
#  ('The Orphanage', 75.4),
#  ('Possum', 75.3),
#  ('Frankenweenie', 75.1),
#  ('Goodnight Mommy (Ich seh, Ich seh)', 75.1),
#  ('In Fabric', 75.1),
#  ('Upgrade', 74.6),
#  ('Zombieland', 74.4),
#  ('Bone Tomahawk', 73.9),
#  ('It Comes At Night', 73.9),
#  ('Pulse (Kairo)', 73.8),
#  ('Shadow of the Vampire', 73.7),
#  ('Spring', 73.6),
#  ('It', 73.5),
#  ('The House of the Devil', 73.2),
#  ('Predator', 73.1),
#  ('Berberian Sound Studio', 73.0),
#  ("Don't Breathe", 73.0),
#  ('Cat People', 72.7),
#  ('Ready or Not', 72.7),
#  ('The Return of the Living Dead', 72.6),
#  ('The Conjuring', 72.3),
#  ('King Kong', 72.1),
#  ('The Autopsy of Jane Doe', 71.9),
#  ('Paranormal Activity', 71.6),
#  ('Paprika', 71.5),
#  ('This Is the End', 71.3),
#  ('Brick', 71.2),
#  ('Dracula', 70.9),
#  ('Bubba Ho-Tep', 70.9),
#  ('Stir of Echoes', 70.8),
#  ('Chronicle', 70.7),
#  ('Frailty', 70.6),
#  ('Tale of Tales (Il racconto dei racconti)', 70.3),
#  ('Starfish', 70.1),
#  ('American Psycho', 69.8),
#  ('Prometheus', 69.7),
#  ('Sputnik', 69.7),
#  ('Tucker and Dale vs. Evil', 69.7),
#  ('Little Monsters', 69.5),
#  ('Sleepy Hollow', 69.5),
#  ('Slither', 69.4),
#  ('Bakjwi (Thirst)', 69.3),
#  ('The Mist', 69.3),
#  ('Sea Fever', 69.2),
#  ('mother!', 69.1),
#  ('Land of the Dead', 69.0),
#  ('The Rocky Horror Picture Show', 69.0),
#  ('Anna and the Apocalypse', 68.9),
#  ('Hellboy', 68.9),
#  ('The Eyes of My Mother', 68.7),
#  ('Monsters', 68.6),
#  ('The Ring', 68.6),
#  ('Hard Candy', 68.5),
#  ('Session 9', 68.5),
#  ('Stoker', 68.1),
#  ('Dawn of the Dead', 68.0),
#  ('Scream 2', 68.0),
#  ('Suspiria', 68.0),
#  ('The Conjuring 2', 68.0),
#  ('Open Water', 67.9),
#  ('Satanic Panic', 67.9),
#  ('Color Out of Space', 67.8),
#  ('Red Dragon', 67.7),
#  ('Splice', 67.2),
#  ('1408', 67.0),
#  ('28 Weeks Later...', 66.9),
#  ('Overlord', 66.8),
#  ('Pacific Rim', 66.3),
#  ('Crimson Peak', 66.0),
#  ('Stake Land', 66.0),
#  ('The Innkeepers', 66.0),
#  ('Halloween', 65.7),
#  ('Split', 65.7),
#  ("You're Next", 65.5),
#  ('Fright Night', 65.4),
#  ('Byzantium', 65.3),
#  ('Scary Stories to Tell in the Dark', 65.3),
#  ('Crawl', 65.1),
#  ('The Limehouse Golem', 64.9),
#  ('Goosebumps', 64.8),
#  ('Oculus', 64.6),
#  ('[Rec] 2', 64.6),
#  ('Willard', 64.5),
#  ('The Rental', 64.4),
#  ("Jacob's Ladder", 64.3),
#  ('Lights Out', 64.1),
#  ('Severance', 64.0),
#  ('Diary of the Dead', 63.9),
#  ('Frozen', 63.8),
#  ('Sinister', 63.8),
#  ('Snakes on a Plane', 63.8),
#  ('Carrie', 63.6),
#  ('The Wretched', 63.6),
#  ('Ouija: Origin of Evil', 63.3),
#  ('Serial Mom', 63.3),
#  ('Black Sheep', 63.2),
#  ('The Last Exorcism', 62.9),
#  ('The Hole in the Ground', 62.8),
#  ('It Chapter Two', 62.7),
#  ('The Woman in Black', 62.7),
#  ('Daybreakers', 62.6),
#  ('Zombieland: Double Tap', 62.5),
#  ('Blade', 62.3),
#  ('Happy Death Day 2U', 62.3),
#  ('Blade II', 62.1),
#  ('Evil Dead', 62.0),
#  ('Annabelle: Creation', 61.9),
#  ('Happy Death Day', 61.8),
#  ('Rubber', 61.7),
#  ('Day Watch', 61.6),
#  ('Piranha 3-D', 61.6),
#  ('The Signal', 61.6),
#  ('World War Z', 61.6),
#  ('Rabid', 61.3),
#  ('Red State', 61.3),
#  ('The Crazies', 61.1),
#  ('Krampus', 61.1),
#  ('Paranormal Activity 2', 61.1),
#  ('Dark Water', 60.9),
#  ('Hostel', 60.6),
#  ('The Cell', 60.6),
#  ('The Neon Demon', 60.4),
#  ('Unfriended: Dark Web', 60.1),
#  ('Mama', 60.0),
#  ('Scream 4', 60.0),
#  ('Insidious', 59.9),
#  ("The Dead Don't Die", 59.9),
#  ("Child's Play", 59.8),
#  ('Predators', 59.7),
#  ('The Next Three Days', 59.7),
#  ('The House That Jack Built', 59.7),
#  ('The Hunt', 59.7),
#  ('Final Destination 5', 59.6),
#  ('Kaboom', 59.5),
#  ('Mom and Dad', 59.5),
#  ('From Hell', 59.3),
#  ('Spree', 59.3),
#  ('My Bloody Valentine 3-D', 59.2),
#  ('Paranormal Activity 3', 59.2),
#  ('V/H/S/2', 59.2),
#  ('Pitch Black', 59.0),
#  ('Ravenous', 59.0),
#  ('Night Watch', 58.9),
#  ('Saw', 58.9),
#  ('The Visit', 58.6),
#  ('Deep Blue Sea', 58.5),
#  ('Pet Sematary', 58.5),
#  ('30 Days of Night', 58.4),
#  ("Don't Be Afraid Of The Dark", 58.4),
#  ('The Jacket', 58.3),
#  ('Orphan', 58.1),
#  ('Antiviral', 58.1),
#  ('Vacancy', 58.1),
#  ('Wolf Creek', 58.1),
#  ('Poltergeist', 58.0),
#  ('The Thing', 57.9),
#  ('Annabelle Comes Home', 57.9),
#  ('Unknown', 57.9),
#  ('Maggie', 57.8),
#  ('Quarantine', 57.7),
#  ('John Carter', 57.6),
#  ('What Lies Beneath', 57.6),
#  ('Antichrist', 57.5),
#  ('V/H/S', 57.4),
#  ('Constantine', 57.2),
#  ('Cabin Fever', 57.0),
#  ('The Exorcism of Emily Rose', 56.8),
#  ('Insidious: Chapter 3', 56.8),
#  ('Jeepers Creepers', 56.6),
#  ('Eight Legged Freaks', 56.5),
#  ('Scream 3', 56.5),
#  ('Ma', 56.3),
#  ('The Hills Have Eyes', 56.1),
#  ('Brightburn', 56.1),
#  ('The Belko Experiment', 56.1),
#  ('Scary Movie', 56.0),
#  ('Twilight', 56.0),
#  ('The First Purge', 55.9),
#  ('Tusk', 55.9),
#  ('The Awakening', 55.5),
#  ('The Haunting', 55.5),
#  ('The Ruins', 55.5),
#  ('The Purge: Anarchy', 55.4),
#  ('The Purge: Election Year', 55.0),
#  ('Femme Fatale', 54.9),
#  ('Dark Shadows', 54.9),
#  ("Jennifer's Body", 54.9),
#  ('The Mummy Returns', 54.9),
#  ('Goosebumps 2: Haunted Halloween', 54.7),
#  ("The Devil's Rejects", 54.6),
#  ('The Wicker Man', 54.5),
#  ('The Skeleton Key', 54.3),
#  ('Final Destination', 54.2),
#  ('The Human Centipede (First Sequence)', 54.0),
#  ('Pride and Prejudice and Zombies', 53.9),
#  ('The Omen', 53.8),
#  ('The Possession', 53.7),
#  ('The Stepfather', 53.4),
#  ('The Phantom of the Opera', 53.3),
#  ('Doomsday', 53.3),
#  ('The Box', 53.1),
#  ('Insidious: The Last Key', 53.1),
#  ('Silent House', 53.1),
#  ('The Meg', 53.1),
#  ('Blair Witch', 53.0),
#  ('Devil', 53.0),
#  ('[REC] 3 Genesis', 52.8),
#  ('Final Destination 3', 52.7),
#  ('Psycho II', 52.5),
#  ("Cirque du Freak: The Vampire's Assistant", 52.5),
#  ('The Wolfman', 52.1),
#  ('The Last House on the Left', 52.1),
#  ('The Lovely Bones', 51.9),
#  ('High Tension (Switchblade Romance)', 51.9),
#  ('The Statement', 51.1),
#  ('The Uninvited', 50.9),
#  ('The Mummy', 50.8),
#  ('House of Wax', 50.5),
#  ('The Predator', 50.4),
#  ('Dreamcatcher', 50.3),
#  ('Hollow Man', 50.2),
#  ('Stage Fright', 50.1),
#  ('Morgan', 50.0),
#  ('Survival of the Dead', 50.0),
#  ('The Strangers', 50.0),
#  ('Freddy vs. Jason', 49.8),
#  ('The Green Inferno', 49.8),
#  ('Dark Skies', 49.7),
#  ('Maniac', 49.6),
#  ('Final Destination 2', 49.5),
#  ('Repo! The Genetic Opera', 49.4),
#  ('The Scorpion King', 49.3),
#  ('The Strangers: Prey At Night', 49.3),
#  ('The Twilight Saga: New Moon', 49.3),
#  ('Insidious: Chapter 2', 49.2),
#  ('Abraham Lincoln: Vampire Hunter', 49.1),
#  ('Saw II', 49.1),
#  ('The Grudge', 49.0),
#  ('The Chronicles of Riddick', 48.9),
#  ('Scouts Guide to the Zombie Apocalypse', 48.9),
#  ('The Texas Chainsaw Massacre', 48.8),
#  ('Stigmata', 48.7),
#  ('Intruders', 48.6),
#  ('The Quiet Ones', 48.6),
#  ('Underworld', 48.6),
#  ('The Invasion', 48.2),
#  ('The Woman in Black 2 Angel of Death', 48.0),
#  ('Antebellum', 47.8),
#  ('Paranormal Activity: The Marked Ones', 47.8),
#  ('The Ring Two', 47.8),
#  ('Shutter', 47.5),
#  ('Deliver Us from Evil', 47.4),
#  ('Hostel Part II', 47.3),
#  ('A Nightmare on Elm Street', 47.2),
#  ('Seed of Chucky', 47.2),
#  ('Abandon', 47.0),
#  ('Silent Hill', 46.9),
#  ('The Curse of La Llorona', 46.9),
#  ('Friday the 13th', 46.8),
#  ('The Fog', 46.7),
#  ('The Relic', 46.6),
#  ('Annabelle', 46.5),
#  ('Resident Evil', 46.2),
#  ('Saw VI', 46.2),
#  ('The Haunting in Connecticut', 45.8),
#  ('Blade: Trinity', 45.4),
#  ('The Nun', 45.0),
#  ('Pandorum', 44.8),
#  ('Underworld: Awakening', 44.8),
#  ('Black Christmas', 44.7),
#  ('The Haunted Mansion', 44.6),
#  ('Resident Evil: The Final Chapter', 44.6),
#  ('Saw III', 44.6),
#  ('Wrong Turn', 44.5),
#  ('The Amityville Horror', 44.4),
#  ('The Final Destination', 44.4),
#  ('The Eye', 44.2),
#  ('Resident Evil: Extinction', 44.2),
#  ('Ghost Rider', 44.1),
#  ('Flatliners', 44.0),
#  ('Underworld: The Rise of the Lycans', 44.0),
#  ('End of Days', 43.9),
#  ('The Collector', 43.7),
#  ('Club Dread', 43.6),
#  ('Anacondas: The Hunt for the Blood Orchid', 43.5),
#  ('Gothika', 43.5),
#  ('Paranormal Activity 4', 43.4),
#  ('AVP - Alien Vs. Predator', 43.3),
#  ('Sorority Row', 43.3),
#  ('Untraceable', 43.0),
#  ('Hannibal Rising', 43.0),
#  ('Turistas (Paradise Lost)', 42.7),
#  ('Jeepers Creepers 2', 42.3),
#  ('Resident Evil: Afterlife', 42.0),
#  ('Sinister 2', 42.0),
#  ('The Dark Tower', 42.0),
#  ('Van Helsing', 41.8),
#  ('Queen of the Damned', 41.7),
#  ('Chernobyl Diaries', 41.6),
#  ('Spawn', 41.6),
#  ('The Forest', 41.6),
#  ('Underworld: Evolution', 41.6),
#  ('Mirrors', 41.2),
#  ('Doom', 41.1),
#  ('The Lazarus Effect', 41.0),
#  ('Case 39', 40.9),
#  ('Swimfan', 40.9),
#  ('Pulse', 40.8),
#  ('Ghost Ship', 40.7),
#  ('Resident Evil: Apocalypse', 40.2),
#  ('Underworld: Blood Wars', 40.0),
#  ('Priest', 39.8),
#  ('The Hitcher', 39.7),
#  ('Wish Upon', 39.4),
#  ('Legion', 38.9),
#  ('Red Riding Hood', 38.6),
#  ('Saw IV', 38.5),
#  ('Cursed', 37.9),
#  ('When a Stranger Calls', 37.8),
#  ('House of 1000 Corpses', 37.7),
#  ('The Reaping', 37.7),
#  ("Blumhouse's Truth or Dare", 37.4),
#  ('Exorcist: The Beginning', 37.4),
#  ('The Cave', 37.3),
#  ('The Last Exorcism Part II', 36.7),
#  ('Jonah Hex', 36.6),
#  ('Blood and Chocolate', 36.5),
#  ('The Rage: Carrie 2', 36.0),
#  ('The Texas Chainsaw Massacre: The Beginning', 36.0),
#  ('Jason X', 35.9),
#  ('Godsend', 35.8),
#  ('The Grudge 2', 35.8),
#  ('The Bye Bye Man', 35.8),
#  ('White Noise', 35.8),
#  ('Primeval', 35.6),
#  ('The Skulls', 34.9),
#  ('Shark Night 3D', 34.5),
#  ('Slender Man', 34.5),
#  ("John Carpenter's Ghosts of Mars", 34.1),
#  ('Texas Chainsaw', 34.0),
#  ('Ouija', 33.9),
#  ('Darkness Falls', 33.8),
#  ('The Gallows', 33.8),
#  ('Venom', 33.7),
#  ('I, Frankenstein', 33.7),
#  ('One Missed Call', 33.4),
#  ('The Unborn', 33.0),
#  ('Rings', 33.0),
#  ('Saw V', 33.0),
#  ('Boogeyman', 32.3),
#  ('Saw 3D', 32.3),
#  ('Postal', 31.9),
#  ('Aliens vs. Predator: Requiem (AVP 2)', 31.7),
#  ('Silent Hill: Revelation', 31.2),
#  ('A Sound of Thunder', 30.8),
#  ('The Covenant', 30.3),
#  ('Prom Night', 28.7),
#  ('Feardotcom', 28.6),
#  ('Soul Survivors', 28.4),
#  ('The Devil Inside', 28.3),
#  ('The Roommate', 28.2),
#  ('Captivity', 27.1),
#  ('Ultraviolet', 27.0),
#  ('Battlefield Earth', 23.4),
#  ('Scary Movie 5', 20.8),
#  ('Alone in the Dark', 16.0)]

# %%
df = data
df=df.loc[:, ('Horror', 'runtime_interval', 'review_score_interval', 'tomatometer_rating_interval', 'movie_title', 'release_decade_interval', 'production_company')]




clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.7, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'Horror', 'type': 'one', 'value': 'True'},
                        {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'release_decade_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':3, 'maxlen':4, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Warning: Python 3.10+ NOT detected. You should upgrade to Python 3.10 or greater to get better performance
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# Done. Total verifications : 3446, rules 29,control number:0, times: prep 83.25991582870483, processing 87.14502096176147
#
# CleverMiner task processing summary:
#
# Task type : 4ftMiner
# Number of verifications : 3446
# Number of rules : 29
# Total time needed : 00h 02m 50s
# Time of data preparation : 00h 01m 23s
# Time of rule mining : 00h 01m 27s
#
#
# List of rules:
# RULEID BASE  CONF  AAD    Rule
#      1   186 0.715 +0.954 Horror(True) & runtime_interval(1.5-1.75h) & production_company(Focus Features) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      2   104 0.703 +0.919 Horror(True) & runtime_interval(1.75-2h) & production_company(Overture Films) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      3    75 0.701 +0.914 Horror(True) & runtime_interval(1.75-2h) & production_company(Picturehouse) => review_score_interval(70-90) | ---
#      4    75 0.701 +0.914 Horror(True) & runtime_interval(1.75-2h) & production_company(Picturehouse) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#      5    54 0.711 +6.532 Horror(True) & runtime_interval(1.75-2h) & production_company(Royal Films International) => review_score_interval(>90) | ---
#      6    54 0.711 +6.532 Horror(True) & runtime_interval(1.75-2h) & production_company(Royal Films International) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#      7    54 0.711 +6.532 Horror(True) & production_company(Royal Films International) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#      8   128 0.707 +0.931 runtime_interval(1.5-1.75h) & production_company(Bad Robot Productions) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#      9    51 0.773 +1.110 runtime_interval(1.5-1.75h) & production_company(Independent Films) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     10    97 0.770 +7.161 runtime_interval(1.5-1.75h) & production_company(Janus Films) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     11    62 0.705 +0.924 runtime_interval(1.5-1.75h) & production_company(Motto Pictures) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     12    64 0.753 +6.982 runtime_interval(1.5-1.75h) & production_company(Warner Bros. Pictures) & release_decade_interval(1930's) => review_score_interval(>90) | ---
#     13    83 0.716 +0.954 runtime_interval(1.5-1.75h) & production_company(s) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     14    64 0.762 +1.081 runtime_interval(1.75-2h) & production_company(Big World Pictures) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     15    54 0.711 +6.532 runtime_interval(1.75-2h) & production_company(Royal Films International) & release_decade_interval(1960's) => review_score_interval(>90) | ---
#     16    52 0.722 +0.973 runtime_interval(1.75-2h) & production_company(levelFILM) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     17    89 0.718 +6.609 runtime_interval(2-2.5) & production_company(20th Century Fox) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#     18    53 0.736 +1.010 runtime_interval(2-2.5) & production_company(Kino International) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     19    53 0.791 +7.386 runtime_interval(2-2.5) & production_company(Paramount Pictures) & release_decade_interval(1920's) => review_score_interval(>90) | ---
#     20   102 0.729 +0.990 runtime_interval(<1.5h) & production_company(Fireworks Pictures) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     21    73 0.730 +6.739 runtime_interval(<1.5h) & production_company(Janus Films) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     22    99 0.733 +1.003 runtime_interval(<1.5h) & production_company(Newmarket Films) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     23    83 0.722 +0.971 runtime_interval(<1.5h) & production_company(Paladin Pictures) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     24    61 0.726 +0.983 runtime_interval(<1.5h) & production_company(Race Point Films) & release_decade_interval(2010's) => review_score_interval(70-90) | ---
#     25    86 0.717 +9.320 runtime_interval(<1.5h) & production_company(Sony) & release_decade_interval(2000's) => review_score_interval(<30) | ---
#     26    50 0.704 +0.923 runtime_interval(<1.5h) & production_company(Think Film) & release_decade_interval(2000's) => review_score_interval(70-90) | ---
#     27   112 0.842 +7.927 runtime_interval(>2.5h) & production_company(Columbia Pictures) & release_decade_interval(1950's) => review_score_interval(>90) | ---
#     28   130 0.802 +7.507 runtime_interval(>2.5h) & production_company(Paramount Pictures) & release_decade_interval(1970's) => review_score_interval(>90) | ---
#     29    76 0.760 +7.057 runtime_interval(>2.5h) & production_company(Rialto Pictures) & release_decade_interval(1980's) => review_score_interval(>90) | ---
#
#
#
# Rule id : 2
#
# Base :   104  Relative base : 0.000  CONF : 0.703  AAD : +0.919  BAD : -0.919
#
# Cedents:
#   antecedent : Horror(True) & runtime_interval(1.75-2h) & production_company(Overture Films) & release_decade_interval(2010's)
#   succcedent : review_score_interval(70-90)
#   condition  : ---
#
# Fourfold table
#     |  S  |  ¬S |
# ----|-----|-----|
#  A  |  104|   44|
# ----|-----|-----|
# ¬A  |247237|428143|
# ----|-----|-----|

# %% [markdown]
# ## Bonus: Nicolas Cage

# %%
pd.set_option('display.max_columns', None)
data.head(1)
# Out:
#                                                             movie_title  \
# rotten_tomatoes_link
# m/0814255             Percy Jackson & the Olympians: The Lightning T...
#
#                      content_rating  \
# rotten_tomatoes_link
# m/0814255                        PG
#
#                                                                  genres  \
# rotten_tomatoes_link
# m/0814255             [Action & Adventure, Comedy, Drama, Science Fi...
#
#                            directors  \
# rotten_tomatoes_link
# m/0814255             Chris Columbus
#
#                                                          authors  \
# rotten_tomatoes_link
# m/0814255             Craig Titley, Chris Columbus, Rick Riordan
#
#                                                                  actors  \
# rotten_tomatoes_link
# m/0814255             [Logan Lerman, Brandon T. Jackson, Alexandra D...
#
#                      original_release_date streaming_release_date  runtime  \
# rotten_tomatoes_link
# m/0814255                       2010-02-12             2015-11-25    119.0
#
#                      production_company tomatometer_status  \
# rotten_tomatoes_link
# m/0814255              20th Century Fox             Rotten
#
#                       tomatometer_rating  tomatometer_count audience_status  \
# rotten_tomatoes_link
# m/0814255                           49.0              149.0         Spilled
#
#                       audience_rating  audience_count  \
# rotten_tomatoes_link
# m/0814255                        53.0        254421.0
#
#                       tomatometer_top_critics_count  \
# rotten_tomatoes_link
# m/0814255                                        43
#
#                       tomatometer_fresh_critics_count  \
# rotten_tomatoes_link
# m/0814255                                          73
#
#                       tomatometer_rotten_critics_count   critic_name  \
# rotten_tomatoes_link
# m/0814255                                           76  Ben McEachen
#
#                       top_critic           publisher_name review_type  \
# rotten_tomatoes_link
# m/0814255                  False  Sunday Mail (Australia)       Fresh
#
#                       review_score review_date review_score_interval  \
# rotten_tomatoes_link
# m/0814255                     70.0  2010-02-09                 70-90
#
#                      tomatometer_rating_interval runtime_interval  Horror  \
# rotten_tomatoes_link
# m/0814255                                  30-50          1.75-2h   False
#
#                      release_decade_interval
# rotten_tomatoes_link
# m/0814255                             2010's

# %%
def is_nicolas(row):
    if 'Nicolas Cage' in row['actors']:
        return True
    else: return False
data["nicolas cage"] = data.apply(is_nicolas, axis=1)

# %%
#JSOU FILMY S NICOLASEM CAGEM DOBRÉ?
df = data
df=df.loc[:, ('nicolas cage', 'runtime_interval', 'review_score_interval', 'release_decade_interval', 'production_company', 'content_rating')]




clm = cleverminer(df=df,proc='4ftMiner',
               quantifiers= {'conf':0.4, 'Base': 50},
               ante ={
                    'attributes':[
                        {'name': 'nicolas cage', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                        {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
                    ], 'minlen':2, 'maxlen':3, 'type':'con'},
               succ ={
                    'attributes':[
                        {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
                    ], 'minlen':1, 'maxlen':1, 'type':'con'}
               )

clm.print_summary()
clm.print_rulelist()
clm.print_rule(2)
# Out:
# Cleverminer version 1.0.2. Note: This version is for personal and educational use only. If you need PRO version (support, fixing structures for compactibility in future versions for production deployment, additional development, licensing of commercial use of subroutines used), feel free to ask authors. Most of these functionalities are maintained in best-effort, as soon as this project is at given conditions for free use and rapid development is needed, they cannot be guaranteed.
# Warning: Python 3.10+ NOT detected. You should upgrade to Python 3.10 or greater to get better performance
# Starting data preparation ...
# Encoding columns into bit-form...
# Encoding columns into bit-form...done
# Data preparation finished.
# Will go for  4ftMiner
# Starting to mine rules.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [29], in <cell line: 8>()
#       2 df = data
#       3 df=df.loc[:, ('nicolas cage', 'runtime_interval', 'review_score_interval', 'release_decade_interval', 'production_company', 'content_rating')]
# ----> 8 clm = cleverminer(df=df,proc='4ftMiner',
#       9                quantifiers= {'conf':0.4, 'Base': 50},
#      10                ante ={
#      11                     'attributes':[
#      12                         {'name': 'nicolas cage', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
#      13                         {'name': 'runtime_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
#      14                         {'name': 'production_company', 'type': 'subset', 'minlen': 1, 'maxlen': 1},
#      15                     ], 'minlen':2, 'maxlen':3, 'type':'con'},
#      16                succ ={
#      17                     'attributes':[
#      18                         {'name': 'review_score_interval', 'type': 'subset', 'minlen': 1, 'maxlen': 1}
#      19                     ], 'minlen':1, 'maxlen':1, 'type':'con'}
#      20                )
#      22 clm.print_summary()
#      23 clm.print_rulelist()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:61, in cleverminer.__init__(O0OO0OOO0OO0O0O0O, **O000OOOOO00O000O0)
#      59 OO00OOO000O0O00O0 =O000OOOOO00O000O0 .get ("proc",None )#line:92
#      60 if not (OO00OOO000O0O00O0 ==None ):#line:93
# ---> 61     O0OO0OOO0OO0O0O0O ._calculate (**O000OOOOO00O000O0 )#line:94
#      62 else :#line:96
#      63     if O0OO0OOO0OO0O0O0O .verbosity ['debug']:#line:97
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:1044, in cleverminer._calculate(OO0OOOOOO00O00000, **OOO00O0O0OOO0OO0O)
#    1042 OO0OOOOOO00O00000 .task_actinfo ['optim']=OOO00O0OO00O000OO #line:1325
#    1043 print ("Starting to mine rules.")#line:1333
# -> 1044 OO0OOOOOO00O00000 ._start_cedent (OO0OOOOOO00O00000 .task_actinfo )#line:1334
#    1045 OO0OOOOOO00O00000 .stats ['end_proc_time']=time .time ()#line:1336
#    1046 print ("Done. Total verifications : "+str (OO0OOOOOO00O00000 .stats ['total_cnt'])+", rules "+str (OO0OOOOOO00O00000 .stats ['total_valid'])+",control number:"+str (OO0OOOOOO00O00000 .stats ['control_number'])+", times: prep "+str (OO0OOOOOO00O00000 .stats ['end_prep_time']-OO0OOOOOO00O00000 .stats ['start_prep_time'])+", processing "+str (OO0OOOOOO00O00000 .stats ['end_proc_time']-OO0OOOOOO00O00000 .stats ['start_proc_time']))#line:1339
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:850, in cleverminer._start_cedent(O00O0O0OO0O0OO0OO, OOO00OOO0OO0O00OO)
#     848 if (OOOO0O00OOO00OO00 ['defi'].get ('type')=='con'):#line:1103
#     849     _OOO0OOOOOO00OOOO0 =(1 <<O00O0O0OO0O0OO0OO .data ["rows_count"])-1 #line:1104
# --> 850 O00O0O0OO0O0OO0OO ._genvar (OOO00OOO0OO0O00OO ,OOOO0O00OOO00OO00 ,_OO000OOOOO0O0O000 ,_OOOO00OOO0O0O0O0O ,_OOO0OOOOOO00OOOO0 ,OOOO0O00OOO00OO00 ['defi'].get ('minlen'),OOOO0O00OOO00OO00 ['defi'].get ('maxlen'))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:711, in cleverminer._genvar(OOO00OOO0OOOOOO00, O00O0OO00O00OOOO0, O0O00OOOO000OO000, _OO000O00O0O0O00OO, _OOOO000O00OO0OO0O, _OOOOOOOOO00O0OO0O, _OOOOOOO00OO0OOO00, _O0O0O00OO0OOOO0O0)
#     709 _OOOO000O00OO0OO0O .append (_O0000O00O0OOO0O00 )#line:931
#     710 _OO0OO0OOO0O00OO00 =int (0 )#line:932
# --> 711 OOO00OOO0OOOOOO00 ._gencomb (O00O0OO00O00OOOO0 ,O0O00OOOO000OO000 ,_OO000O00O0O0O00OO ,_OOOO000O00OO0OO0O ,_O0000O00O0OOO0O00 ,_OOOOOOOOO00O0OO0O ,_OO0OO0OOO0O00OO00 ,OOOOO0O0O0000OOO0 ,_OO0000O0OO000OO0O ,_OOOOOOO00OO0OOO00 ,_O0O0O00OO0OOOO0O0 ,_O0O0O0OO00O00000O ,_OO0O0O0OOO00OO0OO )#line:933
#     712 _OOOO000O00OO0OO0O .pop ()#line:934
#     713 _OO000O00O0O0O00OO .pop ()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:828, in cleverminer._gencomb(O0O0OO0000O000OO0, OO0O0O0O0OO00OO0O, OOO0OOOOO00OO0OO0, _OOO000O00O000OOOO, _OOOO00000O0OOOOOO, _OOOOOOOOO00OOO00O, _OO00O0O0O00OO0O0O, _O00OOOO000OOO00OO, O000O00OOO0OO0OOO, _O0OOO0O0OOO00O0O0, _OO00O000O0OOO000O, _OOOOOOO0O00OOOOO0, _OO0OO00O0O0O0OOO0, _OO0O0000OOO000O0O)
#     826     OO0O0O0O0OO00OO0O ['cedents'].pop ()#line:1075
#     827     if (len (_OOO000O00O000OOOO )<_OOOOOOO0O00OOOOO0 ):#line:1076
# --> 828         O0O0OO0000O000OO0 ._genvar (OO0O0O0O0OO00OO0O ,OOO0OOOOO00OO0OO0 ,_OOO000O00O000OOOO ,_OOOO00000O0OOOOOO ,_OOOOOOOO0OOO0OOOO ,_OO00O000O0OOO000O ,_OOOOOOO0O00OOOOO0 )#line:1077
#     829 else :#line:1078
#     830     OO0O0O0O0OO00OO0O ['cedents'].pop ()#line:1079
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:711, in cleverminer._genvar(OOO00OOO0OOOOOO00, O00O0OO00O00OOOO0, O0O00OOOO000OO000, _OO000O00O0O0O00OO, _OOOO000O00OO0OO0O, _OOOOOOOOO00O0OO0O, _OOOOOOO00OO0OOO00, _O0O0O00OO0OOOO0O0)
#     709 _OOOO000O00OO0OO0O .append (_O0000O00O0OOO0O00 )#line:931
#     710 _OO0OO0OOO0O00OO00 =int (0 )#line:932
# --> 711 OOO00OOO0OOOOOO00 ._gencomb (O00O0OO00O00OOOO0 ,O0O00OOOO000OO000 ,_OO000O00O0O0O00OO ,_OOOO000O00OO0OO0O ,_O0000O00O0OOO0O00 ,_OOOOOOOOO00O0OO0O ,_OO0OO0OOO0O00OO00 ,OOOOO0O0O0000OOO0 ,_OO0000O0OO000OO0O ,_OOOOOOO00OO0OOO00 ,_O0O0O00OO0OOOO0O0 ,_O0O0O0OO00O00000O ,_OO0O0O0OOO00OO0OO )#line:933
#     712 _OOOO000O00OO0OO0O .pop ()#line:934
#     713 _OO000O00O0O0O00OO .pop ()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:828, in cleverminer._gencomb(O0O0OO0000O000OO0, OO0O0O0O0OO00OO0O, OOO0OOOOO00OO0OO0, _OOO000O00O000OOOO, _OOOO00000O0OOOOOO, _OOOOOOOOO00OOO00O, _OO00O0O0O00OO0O0O, _O00OOOO000OOO00OO, O000O00OOO0OO0OOO, _O0OOO0O0OOO00O0O0, _OO00O000O0OOO000O, _OOOOOOO0O00OOOOO0, _OO0OO00O0O0O0OOO0, _OO0O0000OOO000O0O)
#     826     OO0O0O0O0OO00OO0O ['cedents'].pop ()#line:1075
#     827     if (len (_OOO000O00O000OOOO )<_OOOOOOO0O00OOOOO0 ):#line:1076
# --> 828         O0O0OO0000O000OO0 ._genvar (OO0O0O0O0OO00OO0O ,OOO0OOOOO00OO0OO0 ,_OOO000O00O000OOOO ,_OOOO00000O0OOOOOO ,_OOOOOOOO0OOO0OOOO ,_OO00O000O0OOO000O ,_OOOOOOO0O00OOOOO0 )#line:1077
#     829 else :#line:1078
#     830     OO0O0O0O0OO00OO0O ['cedents'].pop ()#line:1079
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:711, in cleverminer._genvar(OOO00OOO0OOOOOO00, O00O0OO00O00OOOO0, O0O00OOOO000OO000, _OO000O00O0O0O00OO, _OOOO000O00OO0OO0O, _OOOOOOOOO00O0OO0O, _OOOOOOO00OO0OOO00, _O0O0O00OO0OOOO0O0)
#     709 _OOOO000O00OO0OO0O .append (_O0000O00O0OOO0O00 )#line:931
#     710 _OO0OO0OOO0O00OO00 =int (0 )#line:932
# --> 711 OOO00OOO0OOOOOO00 ._gencomb (O00O0OO00O00OOOO0 ,O0O00OOOO000OO000 ,_OO000O00O0O0O00OO ,_OOOO000O00OO0OO0O ,_O0000O00O0OOO0O00 ,_OOOOOOOOO00O0OO0O ,_OO0OO0OOO0O00OO00 ,OOOOO0O0O0000OOO0 ,_OO0000O0OO000OO0O ,_OOOOOOO00OO0OOO00 ,_O0O0O00OO0OOOO0O0 ,_O0O0O0OO00O00000O ,_OO0O0O0OOO00OO0OO )#line:933
#     712 _OOOO000O00OO0OO0O .pop ()#line:934
#     713 _OO000O00O0O0O00OO .pop ()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:825, in cleverminer._gencomb(O0O0OO0000O000OO0, OO0O0O0O0OO00OO0O, OOO0OOOOO00OO0OO0, _OOO000O00O000OOOO, _OOOO00000O0OOOOOO, _OOOOOOOOO00OOO00O, _OO00O0O0O00OO0O0O, _O00OOOO000OOO00OO, O000O00OOO0OO0OOO, _O0OOO0O0OOO00O0O0, _OO00O000O0OOO000O, _OOOOOOO0O00OOOOO0, _OO0OO00O0O0O0OOO0, _OO0O0000OOO000O0O)
#     823 if _OO00OOOOOOOOO0O00 >=0 :#line:1072
#     824     if len (OO0O0O0O0OO00OO0O ['cedents_to_do'])>len (OO0O0O0O0OO00OO0O ['cedents']):#line:1073
# --> 825         O0O0OO0000O000OO0 ._start_cedent (OO0O0O0O0OO00OO0O )#line:1074
#     826 OO0O0O0O0OO00OO0O ['cedents'].pop ()#line:1075
#     827 if (len (_OOO000O00O000OOOO )<_OOOOOOO0O00OOOOO0 ):#line:1076
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:850, in cleverminer._start_cedent(O00O0O0OO0O0OO0OO, OOO00OOO0OO0O00OO)
#     848 if (OOOO0O00OOO00OO00 ['defi'].get ('type')=='con'):#line:1103
#     849     _OOO0OOOOOO00OOOO0 =(1 <<O00O0O0OO0O0OO0OO .data ["rows_count"])-1 #line:1104
# --> 850 O00O0O0OO0O0OO0OO ._genvar (OOO00OOO0OO0O00OO ,OOOO0O00OOO00OO00 ,_OO000OOOOO0O0O000 ,_OOOO00OOO0O0O0O0O ,_OOO0OOOOOO00OOOO0 ,OOOO0O00OOO00OO00 ['defi'].get ('minlen'),OOOO0O00OOO00OO00 ['defi'].get ('maxlen'))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:711, in cleverminer._genvar(OOO00OOO0OOOOOO00, O00O0OO00O00OOOO0, O0O00OOOO000OO000, _OO000O00O0O0O00OO, _OOOO000O00OO0OO0O, _OOOOOOOOO00O0OO0O, _OOOOOOO00OO0OOO00, _O0O0O00OO0OOOO0O0)
#     709 _OOOO000O00OO0OO0O .append (_O0000O00O0OOO0O00 )#line:931
#     710 _OO0OO0OOO0O00OO00 =int (0 )#line:932
# --> 711 OOO00OOO0OOOOOO00 ._gencomb (O00O0OO00O00OOOO0 ,O0O00OOOO000OO000 ,_OO000O00O0O0O00OO ,_OOOO000O00OO0OO0O ,_O0000O00O0OOO0O00 ,_OOOOOOOOO00O0OO0O ,_OO0OO0OOO0O00OO00 ,OOOOO0O0O0000OOO0 ,_OO0000O0OO000OO0O ,_OOOOOOO00OO0OOO00 ,_O0O0O00OO0OOOO0O0 ,_O0O0O0OO00O00000O ,_OO0O0O0OOO00OO0OO )#line:933
#     712 _OOOO000O00OO0OO0O .pop ()#line:934
#     713 _OO000O00O0O0O00OO .pop ()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:787, in cleverminer._gencomb(O0O0OO0000O000OO0, OO0O0O0O0OO00OO0O, OOO0OOOOO00OO0OO0, _OOO000O00O000OOOO, _OOOO00000O0OOOOOO, _OOOOOOOOO00OOO00O, _OO00O0O0O00OO0O0O, _O00OOOO000OOO00OO, O000O00OOO0OO0OOO, _O0OOO0O0OOO00O0O0, _OO00O000O0OOO000O, _OOOOOOO0O00OOOOO0, _OO0OO00O0O0O0OOO0, _OO0O0000OOO000O0O)
#     785 OOO0OOOOO00OO0OO0 ['trace_cedent_asindata']=copy .deepcopy (OOO000OO00OO00000 )#line:1018
#     786 OO0O0O0O0OO00OO0O ['cedents'].append (OOO0OOOOO00OO0OO0 )#line:1020
# --> 787 O0O0OOOOOO0O0000O =O0O0OO0000O000OO0 ._verify_opt (OO0O0O0O0OO00OO0O ,OOO0OOOOO00OO0OO0 )#line:1021
#     788 if not (O0O0OOOOOO0O0000O ):#line:1027
#     789     if _OO00OOOOOOOOO0O00 ==1 :#line:1028
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:579, in cleverminer._verify_opt(O0O0O0OOOO0000OOO, OO00O0OOO0O00OO00, OO00OOO00O0O0O000)
#     577 O0O000OOO00000O00 =None #line:759
#     578 if (O0O0O0OOOO0000OOO .proc =='CFMiner')|(O0O0O0OOOO0000OOO .proc =='4ftMiner'):#line:784
# --> 579     OO0O0000OOO0OO00O =O0O0O0OOOO0000OOO ._bitcount (OO00000000O0O000O )#line:785
#     580     if not (O0O0O0OOOO0000OOO ._opt_base ==None ):#line:786
#     581         if not (O0O0O0OOOO0000OOO ._opt_base <=OO0O0000OOO0OO00O ):#line:787
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cleverminer/cleverminer.py:216, in cleverminer._bitcount(O000OO0O0000O0OO0, OOO000OO000OOO000)
#     214     OO0O0OO0O0O0O0000 =OOO000OO000OOO000 .bit_count ()#line:308
#     215 else :#line:309
# --> 216     OO0O0OO0O0O0O0000 =bin (OOO000OO000OOO000 ).count ("1")#line:310
#     217 return OO0O0OO0O0O0O0000
#
# KeyboardInterrupt:
